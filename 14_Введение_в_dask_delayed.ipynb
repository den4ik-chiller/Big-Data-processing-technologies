# %% [markdown]
# # Dask Delayed

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 13: Dask Delayed
# * https://docs.dask.org/en/latest/delayed.html
# * JESSE C. DANIEL. Data Science with Python and Dask.

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# ![](https://i.imgur.com/AwiN8y6.png)
# ![](https://i.imgur.com/ceY6guU.png)

# %% [markdown]
# 1. Напишите 2 функции, имитирующие CPU-bound задачу и IO-bound задачу:
#
# `cpu_task()`: генерирует 100 тыс. случайных чисел и возвращает их сумму (без использования `numpy`)
#
# `io_task()`: "спит" 0.1 сек, затем генерирует случайное число и возвращает его
#
# Замерьте время выполнения 100 последовательных вызовов каждой из этих функций. Распараллелив вычисления при помощи `dask.delayed`, сократите время выполнения. Исследуйте, как зависит время вычислений от выбранного планировщика `scheduler`.

# %%
import numpy as np
import dask.delayed as delayed
import dask
from time import sleep
import random
import time

# %%
# CPU-bound задача
def cpu_task():
    numbers = [random.randint(1, 100) for _ in range(100000)]
    return sum(numbers)

# IO-bound задача
def io_task():
    time.sleep(0.1)
    return random.randint(1, 100)

# %%
# %%time
for i in range(100):
    result = cpu_task()
# Out:
# Wall time: 25.2 s

# %%
# %%time
for i in range(100):
    result = io_task()
# Out:
# Wall time: 10.7 s

# %%
# %%time
dask.config.set(scheduler='threads')  # выбор планировщика
lazy_results = [delayed(cpu_task)() for i in range(100)]
results = dask.compute(*lazy_results)
# Out:
# Wall time: 28.5 s

# %%
# %%time
dask.config.set(scheduler='threads')  # выбор планировщика
lazy_results = [delayed(io_task)() for i in range(100)]
results = dask.compute(*lazy_results)
# Out:
# Wall time: 1.49 s

# %%
# %%time
dask.config.set(scheduler='multiprocessing')  # выбор планировщика
lazy_results = [delayed(cpu_task)() for i in range(100)]
results = dask.compute(*lazy_results)
# Out:
# Wall time: 7.55 s

# %%
# %%time
dask.config.set(scheduler='multiprocessing')  # выбор планировщика
lazy_results = [delayed(io_task)() for i in range(100)]
results = dask.compute(*lazy_results)
# Out:
# Wall time: 2.81 s

# %% [markdown]
# ## Лабораторная работа 14

# %% [markdown]
# 1. Напишите функцию, которая считывает файл формата xml из архива `reviewers_full.zip` и по данным этого файла формирует список словарей, содержащих следующие ключи: `username`, `name`, `sex`, `country`, `mail`, `registered`, `birthdate`, `name_prefix`, `country_code`. Часть из этих значений в исходном файле хранится в виде тэгов, часть - в виде атрибутов тэгов. Для конкретного человека какие-то из этих ключей могут отсутствовать.

# %%
import numpy as np
import dask.delayed as delayed
import dask
from time import sleep
import random
import time

# %%
import zipfile
from bs4 import BeautifulSoup

def parse_reviewers_zip(zip_path):
    with zipfile.ZipFile(zip_path) as z:
        xml_files = [f for f in z.namelist() if 'reviewers_full/reviewers_full_' in f]
        for xml_file in xml_files:
            with z.open(xml_file) as f:
                soup = BeautifulSoup(f, 'xml')
                reviewers = []
                for reviewer in soup.find_all("user"):
                    reviewer_dict = {}
                    reviewer_dict['id'] = reviewer.find('id').text
                    reviewer_dict['username'] = reviewer.find('username').text if reviewer.find('username') else None
                    reviewer_dict['name'] = reviewer.find('name').text if reviewer.find('name') else None
                    reviewer_dict['sex'] = reviewer.find('sex').text if reviewer.find('sex') else None
                    reviewer_dict['country'] = reviewer.find('country').text if reviewer.find('country') else None
                    reviewer_dict['mail'] = reviewer.find('mail').text if reviewer.find('mail') else None
                    reviewer_dict['registered'] = reviewer.find('registered').text if reviewer.find('registered') else None
                    reviewer_dict['birthdate'] = reviewer.find('birthdate').text if reviewer.find('birthdate') else None
                    reviewer_dict['name_prefix'] = reviewer.get('prefix')
                    reviewer_dict['country_code'] = reviewer.find('country').get('code') if reviewer.find('country') else None
                    reviewers.append(reviewer_dict)
    return reviewers
parse_reviewers_zip("reviewers_full.zip")
# Out:
# [{'id': '2214951',
#   'username': 'nancyharrison',
#   'name': None,
#   'sex': 'M',
#   'country': 'Mali',
#   'mail': None,
#   'registered': '2017-05-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ML'},
#  {'id': '133503',
#   'username': 'patrickbird',
#   'name': None,
#   'sex': None,
#   'country': 'Venezuela',
#   'mail': 'matthew29@yahoo.com',
#   'registered': '2005-03-22',
#   'birthdate': '1958-10-07',
#   'name_prefix': None,
#   'country_code': 'VE'},
#  {'id': '465229',
#   'username': 'xcamacho',
#   'name': 'Lisa Anderson',
#   'sex': 'F',
#   'country': 'Suriname',
#   'mail': 'david13@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SR'},
#  {'id': '2000340227',
#   'username': 'andersonshane',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'shermanterri@hotmail.com',
#   'registered': '2014-05-15',
#   'birthdate': '1982-12-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000070758',
#   'username': 'williamdelgado',
#   'name': 'Ryan Beasley',
#   'sex': None,
#   'country': 'Martinique',
#   'mail': 'mbrown@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MQ'},
#  {'id': '2184634',
#   'username': 'jasminelewis',
#   'name': 'William Hernandez',
#   'sex': None,
#   'country': 'Tuvalu',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1954-03-13',
#   'name_prefix': None,
#   'country_code': 'TV'},
#  {'id': '2001371918',
#   'username': 'stacysnyder',
#   'name': 'Evan Caldwell',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1984-06-19',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1803328795',
#   'username': 'wrightashley',
#   'name': 'Jeanette Griffin',
#   'sex': None,
#   'country': 'Solomon Islands',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1959-03-26',
#   'name_prefix': None,
#   'country_code': 'SB'},
#  {'id': '2001518157',
#   'username': 'jkim',
#   'name': 'Thomas Copeland',
#   'sex': None,
#   'country': None,
#   'mail': 'fhall@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001102305',
#   'username': 'christopher43',
#   'name': 'Timothy Salazar',
#   'sex': 'M',
#   'country': 'Montserrat',
#   'mail': None,
#   'registered': '2009-05-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MS'},
#  {'id': '2001513936',
#   'username': 'jermaine11',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1979-03-16',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1281143',
#   'username': 'christinahines',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'julie54@hotmail.com',
#   'registered': None,
#   'birthdate': '1999-08-22',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1772092',
#   'username': 'jessica41',
#   'name': 'Devin Romero',
#   'sex': None,
#   'country': 'Tunisia',
#   'mail': 'jacqueline34@yahoo.com',
#   'registered': '2018-12-07',
#   'birthdate': '1966-05-19',
#   'name_prefix': None,
#   'country_code': 'TN'},
#  {'id': '416021',
#   'username': 'angela99',
#   'name': 'Judy Wells',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-06-03',
#   'birthdate': '1970-03-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1934204',
#   'username': 'gary96',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'thomasnatasha@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002101923',
#   'username': 'cathy55',
#   'name': 'Ricky Brown',
#   'sex': None,
#   'country': 'Puerto Rico',
#   'mail': 'shari95@hotmail.com',
#   'registered': '2018-03-21',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PR'},
#  {'id': '185716',
#   'username': 'nashlisa',
#   'name': 'Michael Shea',
#   'sex': None,
#   'country': 'Norfolk Island',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1989-04-06',
#   'name_prefix': None,
#   'country_code': 'NF'},
#  {'id': '2001458570',
#   'username': 'johnsonandrew',
#   'name': 'Renee Stevens',
#   'sex': 'F',
#   'country': None,
#   'mail': 'austin09@hotmail.com',
#   'registered': '2002-07-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '223986',
#   'username': 'nicholasscott',
#   'name': 'Amanda Smith MD',
#   'sex': 'F',
#   'country': 'Antigua and Barbuda',
#   'mail': None,
#   'registered': '2006-07-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AG'},
#  {'id': '43634',
#   'username': 'whunt',
#   'name': 'Ryan Garcia',
#   'sex': 'M',
#   'country': None,
#   'mail': 'yjohnson@gmail.com',
#   'registered': '2014-05-09',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1803044776',
#   'username': 'bensonstephen',
#   'name': 'Elizabeth Smith',
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'sabrinajohnson@hotmail.com',
#   'registered': '2016-10-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1077239',
#   'username': 'wilsonmarie',
#   'name': 'Jerry Banks',
#   'sex': None,
#   'country': 'Dominican Republic',
#   'mail': None,
#   'registered': '2011-05-22',
#   'birthdate': '1965-12-19',
#   'name_prefix': None,
#   'country_code': 'DO'},
#  {'id': '889269',
#   'username': 'snydernathaniel',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2006-10-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '895323',
#   'username': 'joyce17',
#   'name': None,
#   'sex': None,
#   'country': 'Central African Republic',
#   'mail': 'rangeldarren@gmail.com',
#   'registered': '2002-12-16',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CF'},
#  {'id': '1016614',
#   'username': 'jeffrey71',
#   'name': None,
#   'sex': 'F',
#   'country': 'Turkey',
#   'mail': 'george44@hotmail.com',
#   'registered': '2005-10-13',
#   'birthdate': '1998-08-20',
#   'name_prefix': 'Dr.',
#   'country_code': 'TR'},
#  {'id': '828337',
#   'username': 'karenflores',
#   'name': None,
#   'sex': None,
#   'country': 'Namibia',
#   'mail': 'johnmcintyre@yahoo.com',
#   'registered': '2019-04-01',
#   'birthdate': '1977-05-07',
#   'name_prefix': None,
#   'country_code': 'nan'},
#  {'id': '794683',
#   'username': 'nataliesmith',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2957007',
#   'username': 'morsesarah',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2010-12-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '83655',
#   'username': 'emilywilliams',
#   'name': None,
#   'sex': None,
#   'country': 'Singapore',
#   'mail': None,
#   'registered': '2007-10-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SG'},
#  {'id': '1218686',
#   'username': 'tlarsen',
#   'name': 'Jimmy Roberts',
#   'sex': None,
#   'country': 'Nicaragua',
#   'mail': 'kimberly88@yahoo.com',
#   'registered': '2011-04-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NI'},
#  {'id': '1802940811',
#   'username': 'erinsnyder',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'lindsaywilliamson@yahoo.com',
#   'registered': '2008-07-02',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802425061',
#   'username': 'paul20',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'daniel42@hotmail.com',
#   'registered': '2003-12-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '803167',
#   'username': 'houstonarthur',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2007-12-20',
#   'birthdate': '1999-10-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001526127',
#   'username': 'randychaney',
#   'name': 'Mark Bell',
#   'sex': 'M',
#   'country': 'Sao Tome and Principe',
#   'mail': 'andersonsarah@gmail.com',
#   'registered': None,
#   'birthdate': '1963-09-27',
#   'name_prefix': 'Mr.',
#   'country_code': 'ST'},
#  {'id': '2001550502',
#   'username': 'awilliamson',
#   'name': None,
#   'sex': 'M',
#   'country': 'Romania',
#   'mail': 'jeffrey41@yahoo.com',
#   'registered': '2001-02-15',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'RO'},
#  {'id': '1503718',
#   'username': 'vanderson',
#   'name': 'Karen Hansen',
#   'sex': None,
#   'country': None,
#   'mail': 'garciaamy@hotmail.com',
#   'registered': None,
#   'birthdate': '2017-06-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1556217',
#   'username': 'thomas66',
#   'name': 'Heather Moore',
#   'sex': 'F',
#   'country': 'Equatorial Guinea',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1962-05-21',
#   'name_prefix': None,
#   'country_code': 'GQ'},
#  {'id': '1348760',
#   'username': 'rosswilliam',
#   'name': 'Joseph Evans',
#   'sex': 'M',
#   'country': None,
#   'mail': 'veronica90@yahoo.com',
#   'registered': '2017-12-24',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '555207',
#   'username': 'hendrixglenda',
#   'name': None,
#   'sex': 'M',
#   'country': 'Norfolk Island',
#   'mail': 'grahammatthew@yahoo.com',
#   'registered': None,
#   'birthdate': '2012-06-15',
#   'name_prefix': None,
#   'country_code': 'NF'},
#  {'id': '1131675',
#   'username': 'hernandezkevin',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'theresagarcia@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2000724854',
#   'username': 'weberjennifer',
#   'name': 'Ryan Elliott',
#   'sex': None,
#   'country': 'Belarus',
#   'mail': 'hmunoz@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BY'},
#  {'id': '1802448607',
#   'username': 'elizabethmorse',
#   'name': None,
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'ofischer@yahoo.com',
#   'registered': '2004-01-23',
#   'birthdate': '1954-02-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '399884',
#   'username': 'stephanie08',
#   'name': 'Pamela Hopkins',
#   'sex': 'F',
#   'country': 'Moldova',
#   'mail': None,
#   'registered': '2002-02-13',
#   'birthdate': '1956-06-22',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  {'id': '571595',
#   'username': 'kimdana',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-11-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1938165',
#   'username': 'robinbarton',
#   'name': None,
#   'sex': 'M',
#   'country': 'Qatar',
#   'mail': 'kingrachel@yahoo.com',
#   'registered': '2018-01-05',
#   'birthdate': '1988-09-10',
#   'name_prefix': 'Dr.',
#   'country_code': 'QA'},
#  {'id': '115889',
#   'username': 'jacksonmelissa',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2016-04-07',
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001306800',
#   'username': 'ryan06',
#   'name': 'Randy Brock',
#   'sex': None,
#   'country': 'Monaco',
#   'mail': None,
#   'registered': '2012-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '924670',
#   'username': 'tracy83',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'sandracollins@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1615918',
#   'username': 'kevin05',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2009-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2550731',
#   'username': 'zwilkinson',
#   'name': 'Carly Rodriguez',
#   'sex': 'F',
#   'country': 'Albania',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1961-07-01',
#   'name_prefix': 'Dr.',
#   'country_code': 'AL'},
#  {'id': '408915',
#   'username': 'rogerdavis',
#   'name': None,
#   'sex': 'M',
#   'country': 'Denmark',
#   'mail': None,
#   'registered': '2014-12-02',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'DK'},
#  {'id': '2000132968',
#   'username': 'chadlopez',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'wrightemily@gmail.com',
#   'registered': '2011-03-29',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '653728',
#   'username': 'moorejessica',
#   'name': None,
#   'sex': None,
#   'country': 'Ukraine',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1991-02-18',
#   'name_prefix': None,
#   'country_code': 'UA'},
#  {'id': '1784879',
#   'username': 'richardsdiane',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1988-01-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001765255',
#   'username': 'alexandracarrillo',
#   'name': 'Michael Lewis',
#   'sex': 'M',
#   'country': 'Yemen',
#   'mail': None,
#   'registered': '2004-10-14',
#   'birthdate': '2002-05-28',
#   'name_prefix': None,
#   'country_code': 'YE'},
#  {'id': '414879',
#   'username': 'youngstacey',
#   'name': 'Dustin Ward',
#   'sex': None,
#   'country': 'Belarus',
#   'mail': None,
#   'registered': '2011-12-11',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BY'},
#  {'id': '964574',
#   'username': 'deborahwhitehead',
#   'name': 'Bridget Jenkins',
#   'sex': None,
#   'country': 'Netherlands',
#   'mail': 'rachael79@yahoo.com',
#   'registered': '2011-06-20',
#   'birthdate': '2001-06-13',
#   'name_prefix': None,
#   'country_code': 'NL'},
#  {'id': '1512881',
#   'username': 'qlee',
#   'name': None,
#   'sex': 'M',
#   'country': 'Saudi Arabia',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1990-06-18',
#   'name_prefix': 'Mr.',
#   'country_code': 'SA'},
#  {'id': '2782242',
#   'username': 'ljohnson',
#   'name': None,
#   'sex': 'M',
#   'country': 'Venezuela',
#   'mail': 'williamholmes@yahoo.com',
#   'registered': '2006-02-11',
#   'birthdate': '1972-05-23',
#   'name_prefix': None,
#   'country_code': 'VE'},
#  {'id': '208551',
#   'username': 'alexarmstrong',
#   'name': 'Heather White',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1971-02-16',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2001603876',
#   'username': 'bobbyshaffer',
#   'name': None,
#   'sex': None,
#   'country': 'Belize',
#   'mail': 'sbrown@gmail.com',
#   'registered': '2002-06-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BZ'},
#  {'id': '1147024',
#   'username': 'brooksamy',
#   'name': None,
#   'sex': 'F',
#   'country': 'Norway',
#   'mail': 'fcochran@hotmail.com',
#   'registered': None,
#   'birthdate': '1982-02-23',
#   'name_prefix': 'Mrs.',
#   'country_code': 'NO'},
#  {'id': '2001830605',
#   'username': 'robinbaker',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2010-02-08',
#   'birthdate': '1966-03-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1689981',
#   'username': 'johnsonchristine',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2015-02-17',
#   'birthdate': '1989-06-07',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '154444',
#   'username': 'bhayes',
#   'name': None,
#   'sex': 'F',
#   'country': 'Faroe Islands',
#   'mail': 'chavezjohn@yahoo.com',
#   'registered': '2004-06-23',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'FO'},
#  {'id': '1063387',
#   'username': 'dianegreen',
#   'name': None,
#   'sex': 'F',
#   'country': 'Norfolk Island',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1950-12-04',
#   'name_prefix': 'Ms.',
#   'country_code': 'NF'},
#  {'id': '695667',
#   'username': 'andrew56',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2009-03-31',
#   'birthdate': '2016-01-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001288394',
#   'username': 'steven08',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'rebeccahall@gmail.com',
#   'registered': '2004-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '680685',
#   'username': 'mschmidt',
#   'name': 'Lisa Graham',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-01-27',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803469180',
#   'username': 'ghenry',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cambodia',
#   'mail': 'jacob11@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KH'},
#  {'id': '2171005',
#   'username': 'pruittdustin',
#   'name': 'Bobby Anderson',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1970-10-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001819258',
#   'username': 'kristinalee',
#   'name': None,
#   'sex': 'M',
#   'country': 'Indonesia',
#   'mail': 'tgonzales@gmail.com',
#   'registered': None,
#   'birthdate': '1962-03-29',
#   'name_prefix': None,
#   'country_code': 'ID'},
#  {'id': '2001464611',
#   'username': 'garrettisabel',
#   'name': 'Melissa Newton',
#   'sex': None,
#   'country': None,
#   'mail': 'susan54@hotmail.com',
#   'registered': '2010-08-14',
#   'birthdate': '1953-09-19',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001989158',
#   'username': 'kimberly62',
#   'name': 'Sarah Cordova',
#   'sex': 'F',
#   'country': 'Chile',
#   'mail': 'vaughnbruce@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': 'CL'},
#  {'id': '41914309',
#   'username': 'fromero',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1967-09-25',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2000267872',
#   'username': 'colemonica',
#   'name': 'Chelsea Walters',
#   'sex': 'F',
#   'country': None,
#   'mail': 'eriksimmons@gmail.com',
#   'registered': None,
#   'birthdate': '1972-08-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001918763',
#   'username': 'anthonymiranda',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Pierre and Miquelon',
#   'mail': 'jose40@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PM'},
#  {'id': '2001295337',
#   'username': 'murphybrenda',
#   'name': None,
#   'sex': None,
#   'country': 'Argentina',
#   'mail': None,
#   'registered': '2013-09-19',
#   'birthdate': '1993-11-15',
#   'name_prefix': None,
#   'country_code': 'AR'},
#  {'id': '1803726482',
#   'username': 'dyergeorge',
#   'name': None,
#   'sex': None,
#   'country': 'Isle of Man',
#   'mail': 'ortizcatherine@yahoo.com',
#   'registered': '2009-12-02',
#   'birthdate': '1989-09-17',
#   'name_prefix': None,
#   'country_code': 'IM'},
#  {'id': '1419516',
#   'username': 'alyssa72',
#   'name': 'Jennifer Brown',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1958-11-01',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1059343',
#   'username': 'kbowen',
#   'name': None,
#   'sex': None,
#   'country': 'Comoros',
#   'mail': 'john10@yahoo.com',
#   'registered': '2018-11-23',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KM'},
#  {'id': '2001358459',
#   'username': 'smoore',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2003-11-22',
#   'birthdate': '1966-09-03',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2213373',
#   'username': 'gwalter',
#   'name': None,
#   'sex': 'M',
#   'country': 'Comoros',
#   'mail': 'yharris@hotmail.com',
#   'registered': '2019-01-22',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KM'},
#  {'id': '900242',
#   'username': 'cvega',
#   'name': None,
#   'sex': None,
#   'country': 'United Kingdom',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GB'},
#  {'id': '2001633136',
#   'username': 'xdavid',
#   'name': 'Benjamin Payne',
#   'sex': None,
#   'country': None,
#   'mail': 'xmartin@hotmail.com',
#   'registered': '2004-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '131846',
#   'username': 'gtorres',
#   'name': 'Daniel Randall',
#   'sex': 'M',
#   'country': 'Iceland',
#   'mail': 'mhanson@hotmail.com',
#   'registered': '2003-05-01',
#   'birthdate': '1967-05-06',
#   'name_prefix': 'Mr.',
#   'country_code': 'IS'},
#  {'id': '2704845',
#   'username': 'moodywilliam',
#   'name': 'Sandra Allen',
#   'sex': 'F',
#   'country': None,
#   'mail': 'john09@yahoo.com',
#   'registered': '2009-05-29',
#   'birthdate': '1963-03-18',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1711046',
#   'username': 'theodore43',
#   'name': None,
#   'sex': None,
#   'country': 'Kazakhstan',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1986-07-26',
#   'name_prefix': None,
#   'country_code': 'KZ'},
#  {'id': '16727',
#   'username': 'qwilliams',
#   'name': 'Ariel Torres',
#   'sex': None,
#   'country': 'Cuba',
#   'mail': None,
#   'registered': '2017-08-16',
#   'birthdate': '2010-06-05',
#   'name_prefix': None,
#   'country_code': 'CU'},
#  {'id': '2262192',
#   'username': 'maria65',
#   'name': 'Daniel Gomez',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-04-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1852150',
#   'username': 'ecombs',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'shawn18@yahoo.com',
#   'registered': '2002-02-17',
#   'birthdate': '1954-03-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1902228',
#   'username': 'lopezjoshua',
#   'name': 'Hunter Andrade',
#   'sex': 'M',
#   'country': 'Uzbekistan',
#   'mail': None,
#   'registered': '2016-07-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'UZ'},
#  {'id': '1802411092',
#   'username': 'branchjustin',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'colonleslie@yahoo.com',
#   'registered': '2003-06-11',
#   'birthdate': '1950-05-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '313400',
#   'username': 'darrell92',
#   'name': None,
#   'sex': None,
#   'country': 'Cayman Islands',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1979-04-18',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'id': '1741988',
#   'username': 'riceaustin',
#   'name': 'Jacqueline Davis',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jackiepearson@hotmail.com',
#   'registered': None,
#   'birthdate': '2020-11-30',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001071395',
#   'username': 'qstevens',
#   'name': None,
#   'sex': None,
#   'country': 'Croatia',
#   'mail': 'pwelch@hotmail.com',
#   'registered': '2018-11-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'HR'},
#  {'id': '1107287',
#   'username': 'larnold',
#   'name': None,
#   'sex': None,
#   'country': 'Mexico',
#   'mail': 'jamesjacob@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MX'},
#  {'id': '2001253094',
#   'username': 'oreynolds',
#   'name': 'Daniel Scott',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2013-06-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001934718',
#   'username': 'millerbrandon',
#   'name': 'Charles Williams',
#   'sex': None,
#   'country': 'Yemen',
#   'mail': 'franklindennis@hotmail.com',
#   'registered': None,
#   'birthdate': '2001-01-10',
#   'name_prefix': None,
#   'country_code': 'YE'},
#  {'id': '129009',
#   'username': 'parkertim',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'ccampbell@gmail.com',
#   'registered': '2004-08-13',
#   'birthdate': '1996-01-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '229995',
#   'username': 'christineschultz',
#   'name': 'Emily Townsend',
#   'sex': None,
#   'country': None,
#   'mail': 'stevenwade@gmail.com',
#   'registered': '2016-10-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001919522',
#   'username': 'danielcox',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'vweaver@hotmail.com',
#   'registered': None,
#   'birthdate': '1979-08-29',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '696126',
#   'username': 'oconway',
#   'name': None,
#   'sex': None,
#   'country': 'Guernsey',
#   'mail': 'kathrynswanson@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GG'},
#  {'id': '1803126280',
#   'username': 'thomasspencer',
#   'name': 'Drew White',
#   'sex': None,
#   'country': 'Niger',
#   'mail': None,
#   'registered': '2008-02-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NE'},
#  {'id': '9061',
#   'username': 'robertschristopher',
#   'name': None,
#   'sex': 'F',
#   'country': 'Congo',
#   'mail': 'millertyler@hotmail.com',
#   'registered': None,
#   'birthdate': '2008-03-05',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1863645',
#   'username': 'barkerdenise',
#   'name': 'Sharon Burns',
#   'sex': None,
#   'country': 'Zimbabwe',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ZW'},
#  {'id': '2569219',
#   'username': 'dustinjones',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001525477',
#   'username': 'hoodalyssa',
#   'name': 'Michael Flores',
#   'sex': 'M',
#   'country': None,
#   'mail': 'zvaughan@gmail.com',
#   'registered': '2004-08-31',
#   'birthdate': '1963-01-19',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1737112',
#   'username': 'hlara',
#   'name': 'Jordan Lloyd',
#   'sex': None,
#   'country': None,
#   'mail': 'shernandez@yahoo.com',
#   'registered': None,
#   'birthdate': '1982-03-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '592565',
#   'username': 'xwilliams',
#   'name': 'Patrick Bennett',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2003-06-03',
#   'birthdate': '2014-05-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '4894725',
#   'username': 'robert50',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2017-02-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002323000',
#   'username': 'erios',
#   'name': 'Robert Daniels',
#   'sex': None,
#   'country': None,
#   'mail': 'nbrooks@yahoo.com',
#   'registered': '2005-02-11',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1369303',
#   'username': 'bakerandrew',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'danagonzalez@hotmail.com',
#   'registered': '2015-05-17',
#   'birthdate': '1967-03-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '164472',
#   'username': 'thomasaaron',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '648053',
#   'username': 'stephaniehunt',
#   'name': None,
#   'sex': None,
#   'country': 'Burundi',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BI'},
#  {'id': '1633640',
#   'username': 'anitacurry',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'mkidd@hotmail.com',
#   'registered': None,
#   'birthdate': '2012-03-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001289075',
#   'username': 'vwheeler',
#   'name': None,
#   'sex': None,
#   'country': 'Angola',
#   'mail': 'rachel88@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AO'},
#  {'id': '2002261007',
#   'username': 'jennifer26',
#   'name': 'Michelle Delacruz',
#   'sex': 'F',
#   'country': None,
#   'mail': 'imoss@yahoo.com',
#   'registered': '2017-01-28',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001592205',
#   'username': 'jasonchapman',
#   'name': 'Ashley Wood',
#   'sex': 'F',
#   'country': 'Bulgaria',
#   'mail': 'peterwebb@yahoo.com',
#   'registered': '2007-09-07',
#   'birthdate': '2011-09-30',
#   'name_prefix': 'Dr.',
#   'country_code': 'BG'},
#  {'id': '2001650873',
#   'username': 'simmonsdebra',
#   'name': 'Douglas Williams',
#   'sex': 'M',
#   'country': 'Faroe Islands',
#   'mail': 'patricia52@gmail.com',
#   'registered': '2001-11-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'FO'},
#  {'id': '1335705',
#   'username': 'amyjohnson',
#   'name': None,
#   'sex': None,
#   'country': 'Malaysia',
#   'mail': None,
#   'registered': '2013-09-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MY'},
#  {'id': '456677',
#   'username': 'kcraig',
#   'name': None,
#   'sex': None,
#   'country': 'Rwanda',
#   'mail': None,
#   'registered': '2002-03-12',
#   'birthdate': '2006-04-05',
#   'name_prefix': None,
#   'country_code': 'RW'},
#  {'id': '2002164644',
#   'username': 'brendacook',
#   'name': 'Sean Li',
#   'sex': 'M',
#   'country': 'Malta',
#   'mail': 'ramosrichard@gmail.com',
#   'registered': '2011-05-08',
#   'birthdate': '1990-08-03',
#   'name_prefix': 'Mr.',
#   'country_code': 'MT'},
#  {'id': '2512888',
#   'username': 'sarnold',
#   'name': None,
#   'sex': 'M',
#   'country': 'Tonga',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2002-06-01',
#   'name_prefix': None,
#   'country_code': 'TO'},
#  {'id': '2001326325',
#   'username': 'mmorris',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'christopherchristian@hotmail.com',
#   'registered': None,
#   'birthdate': '1968-11-07',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1655021',
#   'username': 'griffinangela',
#   'name': 'Gregory Rich',
#   'sex': 'M',
#   'country': None,
#   'mail': 'hannah06@gmail.com',
#   'registered': '2005-07-25',
#   'birthdate': '2001-09-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1080290',
#   'username': 'browncharles',
#   'name': 'Rhonda Zuniga',
#   'sex': 'F',
#   'country': 'Jamaica',
#   'mail': None,
#   'registered': '2011-10-19',
#   'birthdate': '2020-07-06',
#   'name_prefix': None,
#   'country_code': 'JM'},
#  {'id': '629957',
#   'username': 'lharris',
#   'name': 'Henry Hughes',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-06-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '515832',
#   'username': 'lori51',
#   'name': None,
#   'sex': None,
#   'country': 'Samoa',
#   'mail': None,
#   'registered': '2006-05-06',
#   'birthdate': '1992-01-17',
#   'name_prefix': None,
#   'country_code': 'WS'},
#  {'id': '2001921038',
#   'username': 'zwalter',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2007-03-13',
#   'birthdate': '1978-08-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '342031',
#   'username': 'michelle08',
#   'name': None,
#   'sex': 'M',
#   'country': 'Ecuador',
#   'mail': None,
#   'registered': '2012-01-10',
#   'birthdate': '2006-10-21',
#   'name_prefix': 'Dr.',
#   'country_code': 'EC'},
#  {'id': '1731223',
#   'username': 'patricia00',
#   'name': 'Elizabeth Kelly',
#   'sex': None,
#   'country': 'Malta',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MT'},
#  {'id': '988862',
#   'username': 'jeremiah42',
#   'name': None,
#   'sex': None,
#   'country': 'Slovenia',
#   'mail': None,
#   'registered': '2001-05-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SI'},
#  {'id': '2377724',
#   'username': 'edward64',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'pamela42@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '383972',
#   'username': 'storres',
#   'name': 'Mindy Wheeler',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2019-05-03',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1152480',
#   'username': 'floresmaria',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'heather24@yahoo.com',
#   'registered': None,
#   'birthdate': '1951-01-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1431830',
#   'username': 'stephaniemeadows',
#   'name': 'David Wheeler',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1803390159',
#   'username': 'jacksondavid',
#   'name': 'Robin Watson',
#   'sex': 'F',
#   'country': None,
#   'mail': 'anthonywong@gmail.com',
#   'registered': '2011-01-26',
#   'birthdate': '1989-04-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '546092',
#   'username': 'julie41',
#   'name': 'Timothy Garcia',
#   'sex': 'M',
#   'country': 'South Africa',
#   'mail': 'sanchezkristin@yahoo.com',
#   'registered': '2001-02-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ZA'},
#  {'id': '2002298070',
#   'username': 'mbrown',
#   'name': 'Linda Nielsen',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000326112',
#   'username': 'kyates',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'zcombs@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '513570',
#   'username': 'april74',
#   'name': None,
#   'sex': None,
#   'country': 'Malta',
#   'mail': 'wjimenez@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MT'},
#  {'id': '393102',
#   'username': 'fosterkimberly',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cape Verde',
#   'mail': 'alicia96@yahoo.com',
#   'registered': None,
#   'birthdate': '1986-09-18',
#   'name_prefix': None,
#   'country_code': 'CV'},
#  {'id': '1272121',
#   'username': 'zwilliams',
#   'name': None,
#   'sex': None,
#   'country': 'Guatemala',
#   'mail': 'tmaldonado@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GT'},
#  {'id': '495505',
#   'username': 'charlessoto',
#   'name': 'Andrea Miller',
#   'sex': 'F',
#   'country': 'Saint Helena',
#   'mail': 'jessicaritter@yahoo.com',
#   'registered': '2012-06-12',
#   'birthdate': '2002-08-29',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000279207',
#   'username': 'dianedavid',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2005-09-03',
#   'birthdate': '1986-09-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '976856',
#   'username': 'nobleshelly',
#   'name': 'Brian Flowers',
#   'sex': 'M',
#   'country': None,
#   'mail': 'nataliebrown@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2459090',
#   'username': 'jonesangela',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001827621',
#   'username': 'stephanie97',
#   'name': 'Elaine Griffin',
#   'sex': None,
#   'country': None,
#   'mail': 'bturner@gmail.com',
#   'registered': '2011-03-02',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803766108',
#   'username': 'ojohnson',
#   'name': 'Matthew Moss',
#   'sex': 'M',
#   'country': None,
#   'mail': 'shanefernandez@hotmail.com',
#   'registered': '2011-04-30',
#   'birthdate': '1971-08-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001386821',
#   'username': 'blloyd',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802916686',
#   'username': 'nicholas90',
#   'name': 'Heidi Lee',
#   'sex': None,
#   'country': None,
#   'mail': 'huntmanuel@hotmail.com',
#   'registered': '2001-05-05',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001229677',
#   'username': 'marvin14',
#   'name': 'Julie Holt',
#   'sex': 'F',
#   'country': 'Tonga',
#   'mail': 'debragreer@yahoo.com',
#   'registered': '2001-10-13',
#   'birthdate': '1981-01-16',
#   'name_prefix': None,
#   'country_code': 'TO'},
#  {'id': '1613992',
#   'username': 'stephanieroman',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cyprus',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CY'},
#  {'id': '1800534445',
#   'username': 'wwilliams',
#   'name': 'Emma Dorsey',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000172021',
#   'username': 'jamesmeyer',
#   'name': None,
#   'sex': 'M',
#   'country': 'Qatar',
#   'mail': 'williamsjennifer@gmail.com',
#   'registered': '2012-11-20',
#   'birthdate': '1988-05-30',
#   'name_prefix': 'Mr.',
#   'country_code': 'QA'},
#  {'id': '197917',
#   'username': 'diana85',
#   'name': 'Annette Walker',
#   'sex': None,
#   'country': None,
#   'mail': 'hsanchez@yahoo.com',
#   'registered': '2011-03-10',
#   'birthdate': '1956-05-07',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '170477',
#   'username': 'uboone',
#   'name': 'Matthew Smith',
#   'sex': None,
#   'country': 'Dominican Republic',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1975-01-31',
#   'name_prefix': None,
#   'country_code': 'DO'},
#  {'id': '2000320101',
#   'username': 'angela49',
#   'name': None,
#   'sex': None,
#   'country': 'Ukraine',
#   'mail': 'alexandrialucas@gmail.com',
#   'registered': '2016-02-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'UA'},
#  {'id': '2863874',
#   'username': 'rileystacey',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803676843',
#   'username': 'xdiaz',
#   'name': None,
#   'sex': 'F',
#   'country': 'Saint Barthelemy',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '673994',
#   'username': 'pchandler',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'lcrawford@hotmail.com',
#   'registered': '2001-12-12',
#   'birthdate': '1952-12-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001932921',
#   'username': 'cgarcia',
#   'name': 'Shannon Ferrell',
#   'sex': 'F',
#   'country': None,
#   'mail': 'weaverjason@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001138349',
#   'username': 'megan97',
#   'name': 'Valerie Scott DDS',
#   'sex': 'F',
#   'country': 'Mauritania',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1976-11-08',
#   'name_prefix': None,
#   'country_code': 'MR'},
#  {'id': '1666217',
#   'username': 'cannondavid',
#   'name': 'Amber Sanchez',
#   'sex': 'F',
#   'country': 'Switzerland',
#   'mail': None,
#   'registered': '2011-09-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CH'},
#  {'id': '2030257',
#   'username': 'emily63',
#   'name': 'Brian Brown',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-07-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1873879',
#   'username': 'roger33',
#   'name': 'Dale Larson',
#   'sex': 'M',
#   'country': 'Burundi',
#   'mail': None,
#   'registered': '2016-11-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BI'},
#  {'id': '2000798626',
#   'username': 'lorigray',
#   'name': 'Eric Santiago',
#   'sex': 'M',
#   'country': 'Czech Republic',
#   'mail': 'walterguzman@yahoo.com',
#   'registered': None,
#   'birthdate': '1966-06-28',
#   'name_prefix': 'Dr.',
#   'country_code': 'CZ'},
#  {'id': '1176705',
#   'username': 'michelle47',
#   'name': 'Micheal Richards',
#   'sex': 'M',
#   'country': 'Hong Kong',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1982-09-27',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '625069',
#   'username': 'allenmisty',
#   'name': None,
#   'sex': 'F',
#   'country': 'South Georgia and the South Sandwich Islands',
#   'mail': 'williamsmichelle@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Ms.',
#   'country_code': 'GS'},
#  {'id': '220778',
#   'username': 'hudsonchelsea',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-04-21',
#   'birthdate': '2007-09-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '998160',
#   'username': 'santoschristopher',
#   'name': 'Rodney Robinson',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1956-07-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000799446',
#   'username': 'stevenperry',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1959-08-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2744065',
#   'username': 'craigburns',
#   'name': None,
#   'sex': None,
#   'country': 'Egypt',
#   'mail': None,
#   'registered': '2016-05-09',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'EG'},
#  {'id': '1256651',
#   'username': 'rachelrose',
#   'name': None,
#   'sex': None,
#   'country': 'Uruguay',
#   'mail': 'beverlymiller@hotmail.com',
#   'registered': None,
#   'birthdate': '2008-08-05',
#   'name_prefix': None,
#   'country_code': 'UY'},
#  {'id': '2917875',
#   'username': 'michaelstephens',
#   'name': 'Deborah Wilson',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001265796',
#   'username': 'laura23',
#   'name': None,
#   'sex': None,
#   'country': 'Congo',
#   'mail': 'brose@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1674452',
#   'username': 'timothysosa',
#   'name': 'Richard Brennan',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2012-05-03',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '42674742',
#   'username': 'olivia20',
#   'name': 'Jon Rodriguez',
#   'sex': None,
#   'country': 'Cayman Islands',
#   'mail': 'kimmark@hotmail.com',
#   'registered': '2004-01-24',
#   'birthdate': '1965-04-17',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'id': '191406',
#   'username': 'stephanie48',
#   'name': None,
#   'sex': 'F',
#   'country': 'Monaco',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1966-02-12',
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '1209206',
#   'username': 'stephaniejackson',
#   'name': 'Christopher Luna',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '987097',
#   'username': 'powellchristina',
#   'name': 'Tonya White',
#   'sex': None,
#   'country': 'Japan',
#   'mail': 'calexander@yahoo.com',
#   'registered': '2017-07-16',
#   'birthdate': '1954-04-20',
#   'name_prefix': None,
#   'country_code': 'JP'},
#  {'id': '1803314861',
#   'username': 'edwardskara',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2004-10-18',
#   'birthdate': None,
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '177169',
#   'username': 'matthew52',
#   'name': 'Peter Morgan',
#   'sex': 'M',
#   'country': None,
#   'mail': 'qberg@hotmail.com',
#   'registered': None,
#   'birthdate': '1971-03-25',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '117707',
#   'username': 'ndavis',
#   'name': 'Megan Dunn',
#   'sex': None,
#   'country': None,
#   'mail': 'cindy78@yahoo.com',
#   'registered': None,
#   'birthdate': '1979-10-16',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001974990',
#   'username': 'jenkinsdustin',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'davidberry@hotmail.com',
#   'registered': None,
#   'birthdate': '1992-08-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '149577',
#   'username': 'gallaghercarol',
#   'name': 'Kristie Allen',
#   'sex': None,
#   'country': 'United States Minor Outlying Islands',
#   'mail': 'michael10@gmail.com',
#   'registered': '2017-09-23',
#   'birthdate': '1951-02-20',
#   'name_prefix': None,
#   'country_code': 'UM'},
#  {'id': '2002221947',
#   'username': 'jennifer76',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'garciamadeline@yahoo.com',
#   'registered': None,
#   'birthdate': '2003-04-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '161134',
#   'username': 'holmescory',
#   'name': None,
#   'sex': 'M',
#   'country': 'Gibraltar',
#   'mail': 'esmith@yahoo.com',
#   'registered': '2004-08-03',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': 'GI'},
#  {'id': '2000346721',
#   'username': 'irodriguez',
#   'name': 'Adam Matthews',
#   'sex': None,
#   'country': 'Nigeria',
#   'mail': 'bneal@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NG'},
#  {'id': '689431',
#   'username': 'lauramyers',
#   'name': 'Timothy Martin',
#   'sex': None,
#   'country': 'Suriname',
#   'mail': 'henry43@gmail.com',
#   'registered': '2008-02-12',
#   'birthdate': '1978-10-25',
#   'name_prefix': None,
#   'country_code': 'SR'},
#  {'id': '2001393179',
#   'username': 'anitajones',
#   'name': 'John Collins',
#   'sex': 'M',
#   'country': None,
#   'mail': 'brennantina@gmail.com',
#   'registered': None,
#   'birthdate': '1975-12-07',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1185599',
#   'username': 'garciajohn',
#   'name': 'Peggy Nelson',
#   'sex': 'F',
#   'country': 'Antigua and Barbuda',
#   'mail': None,
#   'registered': '2010-05-30',
#   'birthdate': '1972-12-12',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AG'},
#  {'id': '2369255',
#   'username': 'cortiz',
#   'name': 'Hannah Martin',
#   'sex': None,
#   'country': 'Papua New Guinea',
#   'mail': 'danielhernandez@hotmail.com',
#   'registered': '2006-02-05',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PG'},
#  {'id': '450198',
#   'username': 'thorn',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2017-09-20',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '413300',
#   'username': 'huntermontgomery',
#   'name': None,
#   'sex': None,
#   'country': 'Bulgaria',
#   'mail': 'perkinsmargaret@yahoo.com',
#   'registered': '2013-07-08',
#   'birthdate': '1997-10-19',
#   'name_prefix': None,
#   'country_code': 'BG'},
#  {'id': '2001270344',
#   'username': 'ayersjoshua',
#   'name': None,
#   'sex': 'F',
#   'country': 'Romania',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'RO'},
#  {'id': '2629862',
#   'username': 'carlosbautista',
#   'name': None,
#   'sex': 'F',
#   'country': 'Denmark',
#   'mail': 'xhurst@hotmail.com',
#   'registered': '2006-09-02',
#   'birthdate': '2016-07-29',
#   'name_prefix': 'Mrs.',
#   'country_code': 'DK'},
#  {'id': '2717582',
#   'username': 'smyers',
#   'name': 'Cynthia Perez',
#   'sex': None,
#   'country': 'Antarctica (the territory South of 60 deg S)',
#   'mail': None,
#   'registered': '2004-05-26',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1790143',
#   'username': 'bennettshawn',
#   'name': None,
#   'sex': 'F',
#   'country': 'Denmark',
#   'mail': 'collinsshawn@yahoo.com',
#   'registered': '2013-08-21',
#   'birthdate': '1968-06-27',
#   'name_prefix': 'Mrs.',
#   'country_code': 'DK'},
#  {'id': '1682018',
#   'username': 'william27',
#   'name': 'Nathan Brown',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '564587',
#   'username': 'cindy05',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2002-12-28',
#   'birthdate': '1972-03-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '4193438',
#   'username': 'fhayes',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'johnsonshane@yahoo.com',
#   'registered': '2010-10-26',
#   'birthdate': '2002-09-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803197046',
#   'username': 'billysanders',
#   'name': 'Emily Mckinney',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2008-07-04',
#   'birthdate': '1989-01-14',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '44862',
#   'username': 'gwilliams',
#   'name': 'Heather Frazier',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '244787',
#   'username': 'pkennedy',
#   'name': 'Samuel Mcbride',
#   'sex': None,
#   'country': None,
#   'mail': 'welchlarry@gmail.com',
#   'registered': '2018-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001078294',
#   'username': 'mirandathomas',
#   'name': None,
#   'sex': 'M',
# ...
#   'country_code': 'GH'},
#  {'id': '338523',
#   'username': 'marystewart',
#   'name': 'Kendra Murphy',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AW'},
#  {'id': '2002321970',
#   'username': 'teresa50',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000266492',
#   'username': 'casey39',
#   'name': 'Alejandro Foster',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2001-05-26',
#   'birthdate': '1952-05-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '315579',
#   'username': 'martinezalicia',
#   'name': 'Melissa Bennett',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jenniferwood@gmail.com',
#   'registered': '2002-01-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1681976',
#   'username': 'gperez',
#   'name': None,
#   'sex': None,
#   'country': 'Azerbaijan',
#   'mail': 'sullivantimothy@hotmail.com',
#   'registered': '2019-08-23',
#   'birthdate': '1963-05-10',
#   'name_prefix': None,
#   'country_code': 'AZ'},
#  {'id': '946597',
#   'username': 'kimberlygaines',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-02-29',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1960622',
#   'username': 'murrayamber',
#   'name': None,
#   'sex': None,
#   'country': 'French Guiana',
#   'mail': 'bethanyhickman@yahoo.com',
#   'registered': '2002-09-25',
#   'birthdate': '1989-11-18',
#   'name_prefix': None,
#   'country_code': 'GF'},
#  {'id': '1461064',
#   'username': 'walkertara',
#   'name': None,
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'mail': None,
#   'registered': '2002-12-12',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'LA'},
#  {'id': '796003',
#   'username': 'david15',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'jturner@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '463756',
#   'username': 'brian30',
#   'name': None,
#   'sex': 'M',
#   'country': 'American Samoa',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1952-05-12',
#   'name_prefix': 'Mr.',
#   'country_code': 'AS'},
#  {'id': '364655',
#   'username': 'valerieharris',
#   'name': None,
#   'sex': None,
#   'country': 'Brazil',
#   'mail': 'pbrown@yahoo.com',
#   'registered': '2018-08-13',
#   'birthdate': '1952-03-01',
#   'name_prefix': None,
#   'country_code': 'BR'},
#  {'id': '2002276763',
#   'username': 'xnorton',
#   'name': 'Joseph Rangel',
#   'sex': 'M',
#   'country': 'Kiribati',
#   'mail': 'phillip13@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': 'KI'},
#  {'id': '768565',
#   'username': 'lthompson',
#   'name': 'Shawna Soto',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2010-02-21',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001730787',
#   'username': 'gkelley',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'anthonypadilla@gmail.com',
#   'registered': '2004-03-23',
#   'birthdate': '2010-12-12',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2001165454',
#   'username': 'nhughes',
#   'name': None,
#   'sex': None,
#   'country': 'Moldova',
#   'mail': 'mreyes@gmail.com',
#   'registered': None,
#   'birthdate': '1965-09-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '412471',
#   'username': 'williamschristopher',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2010-11-12',
#   'birthdate': '1985-12-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '882329',
#   'username': 'jamesallen',
#   'name': 'Glen Keller',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2012-04-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2737118',
#   'username': 'nicolewilliams',
#   'name': 'Kevin West',
#   'sex': None,
#   'country': None,
#   'mail': 'steven98@gmail.com',
#   'registered': None,
#   'birthdate': '1999-03-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001833118',
#   'username': 'santanaalexa',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1955-06-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1564621',
#   'username': 'hortonmartin',
#   'name': 'Alexander Jackson',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1960-03-08',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2002053137',
#   'username': 'fsnyder',
#   'name': 'Kelly Perez',
#   'sex': 'F',
#   'country': 'Japan',
#   'mail': None,
#   'registered': '2014-09-16',
#   'birthdate': '2012-12-20',
#   'name_prefix': None,
#   'country_code': 'JP'},
#  {'id': '153270',
#   'username': 'leandrea',
#   'name': 'Douglas Nguyen',
#   'sex': None,
#   'country': None,
#   'mail': 'sonyaroberts@hotmail.com',
#   'registered': '2013-09-28',
#   'birthdate': '2020-08-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1706378',
#   'username': 'agarcia',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2015-08-21',
#   'birthdate': '1959-08-20',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2002045588',
#   'username': 'robertkim',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2011-10-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '747705',
#   'username': 'garciajeremy',
#   'name': 'Vicki Williams',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2019-01-17',
#   'birthdate': '1969-10-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2179227',
#   'username': 'avilataylor',
#   'name': 'Sherry Dillon',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001362866',
#   'username': 'josephsmith',
#   'name': 'Tiffany Luna',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2017-06-27',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1488508',
#   'username': 'msmith',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001833026',
#   'username': 'vbishop',
#   'name': None,
#   'sex': 'F',
#   'country': 'Maldives',
#   'mail': None,
#   'registered': '2016-11-15',
#   'birthdate': '1958-10-03',
#   'name_prefix': None,
#   'country_code': 'MV'},
#  {'id': '1762143',
#   'username': 'michael41',
#   'name': None,
#   'sex': None,
#   'country': 'Monaco',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2013-05-01',
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '2525133',
#   'username': 'nicole55',
#   'name': 'Shannon Smith',
#   'sex': None,
#   'country': 'Bolivia',
#   'mail': 'patriciasullivan@gmail.com',
#   'registered': None,
#   'birthdate': '1980-12-05',
#   'name_prefix': None,
#   'country_code': 'BO'},
#  {'id': '27034',
#   'username': 'chandlertina',
#   'name': 'Rick Coleman',
#   'sex': 'M',
#   'country': 'Vietnam',
#   'mail': 'johndelgado@hotmail.com',
#   'registered': '2015-10-04',
#   'birthdate': '1963-08-04',
#   'name_prefix': 'Mr.',
#   'country_code': 'VN'},
#  {'id': '1877133',
#   'username': 'sueray',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'cheryl64@yahoo.com',
#   'registered': '2019-01-31',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000141963',
#   'username': 'timothybenson',
#   'name': 'Richard Townsend',
#   'sex': 'M',
#   'country': None,
#   'mail': 'clarkscott@hotmail.com',
#   'registered': '2011-04-14',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2408562',
#   'username': 'ybarrera',
#   'name': 'Willie Williams',
#   'sex': 'M',
#   'country': 'Haiti',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-12-07',
#   'name_prefix': None,
#   'country_code': 'HT'},
#  {'id': '2001804074',
#   'username': 'frenchjulia',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1802504698',
#   'username': 'kristincurtis',
#   'name': None,
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'stephen69@hotmail.com',
#   'registered': '2009-12-12',
#   'birthdate': '1962-08-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '823664',
#   'username': 'ericdixon',
#   'name': 'Jerry Wade',
#   'sex': None,
#   'country': 'Albania',
#   'mail': 'tiffanypatterson@hotmail.com',
#   'registered': '2010-09-21',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AL'},
#  {'id': '388577',
#   'username': 'leslie82',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'tyler41@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '153695',
#   'username': 'evanvillegas',
#   'name': None,
#   'sex': 'F',
#   'country': 'Mayotte',
#   'mail': 'bbailey@yahoo.com',
#   'registered': None,
#   'birthdate': '1997-01-30',
#   'name_prefix': 'Mrs.',
#   'country_code': 'YT'},
#  {'id': '2718108',
#   'username': 'kmercado',
#   'name': 'Katherine Baker',
#   'sex': None,
#   'country': "Cote d'Ivoire",
#   'mail': 'smithjennifer@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001251106',
#   'username': 'kimberly15',
#   'name': None,
#   'sex': None,
#   'country': 'Grenada',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1964-03-03',
#   'name_prefix': None,
#   'country_code': 'GD'},
#  {'id': '207104',
#   'username': 'fdean',
#   'name': 'Tammy Thompson',
#   'sex': None,
#   'country': 'Poland',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1964-02-04',
#   'name_prefix': None,
#   'country_code': 'PL'},
#  {'id': '2001253391',
#   'username': 'annafleming',
#   'name': None,
#   'sex': None,
#   'country': 'Andorra',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1986-01-22',
#   'name_prefix': None,
#   'country_code': 'AD'},
#  {'id': '2001074670',
#   'username': 'samantha01',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'luis78@yahoo.com',
#   'registered': None,
#   'birthdate': '1975-05-22',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000172054',
#   'username': 'joshuafernandez',
#   'name': 'Lucas Flores',
#   'sex': None,
#   'country': 'Barbados',
#   'mail': 'hayesmelissa@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BB'},
#  {'id': '2759970',
#   'username': 'spetersen',
#   'name': None,
#   'sex': None,
#   'country': 'Holy See (Vatican City State)',
#   'mail': None,
#   'registered': '2012-05-24',
#   'birthdate': '1978-11-07',
#   'name_prefix': None,
#   'country_code': 'VA'},
#  {'id': '1762530',
#   'username': 'mholloway',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1963-04-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802922978',
#   'username': 'ricejessica',
#   'name': 'Ariel Gilmore',
#   'sex': None,
#   'country': None,
#   'mail': 'hector88@yahoo.com',
#   'registered': '2004-01-18',
#   'birthdate': '2005-08-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1325841',
#   'username': 'crosscharles',
#   'name': 'Steven Miranda',
#   'sex': 'M',
#   'country': 'Saint Kitts and Nevis',
#   'mail': None,
#   'registered': '2001-11-23',
#   'birthdate': '1994-04-21',
#   'name_prefix': None,
#   'country_code': 'KN'},
#  {'id': '1138259',
#   'username': 'jsmith',
#   'name': 'Amber Harrington',
#   'sex': 'F',
#   'country': None,
#   'mail': 'ydiaz@hotmail.com',
#   'registered': None,
#   'birthdate': '2010-07-27',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  {'id': '2001867356',
#   'username': 'beth31',
#   'name': 'Devin Wilson',
#   'sex': None,
#   'country': None,
#   'mail': 'nperez@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '176234',
#   'username': 'luisjimenez',
#   'name': 'Mrs. Ashley Holland',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1950-03-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '295453',
#   'username': 'johnsonmelissa',
#   'name': 'Kimberly Collins',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jennifer92@hotmail.com',
#   'registered': None,
#   'birthdate': '1984-10-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '195966',
#   'username': 'iperez',
#   'name': 'Jasmine Wood',
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'mail': 'hbell@yahoo.com',
#   'registered': '2018-12-06',
#   'birthdate': '2017-03-24',
#   'name_prefix': 'Dr.',
#   'country_code': 'LA'},
#  {'id': '278020',
#   'username': 'clintoncarpenter',
#   'name': 'Christopher Bowen',
#   'sex': None,
#   'country': 'Egypt',
#   'mail': 'glennbutler@gmail.com',
#   'registered': '2005-12-26',
#   'birthdate': '2001-11-22',
#   'name_prefix': None,
#   'country_code': 'EG'},
#  {'id': '2001700146',
#   'username': 'troy70',
#   'name': None,
#   'sex': 'M',
#   'country': 'Marshall Islands',
#   'mail': 'leslie55@yahoo.com',
#   'registered': None,
#   'birthdate': '1952-09-18',
#   'name_prefix': 'Mr.',
#   'country_code': 'MH'},
#  {'id': '2770874',
#   'username': 'browncarla',
#   'name': 'Jaime Ray',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1965-10-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '13153793',
#   'username': 'collinsmichael',
#   'name': 'Douglas Morales',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2017-12-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1477683',
#   'username': 'kelly68',
#   'name': 'Scott Cooper',
#   'sex': None,
#   'country': 'Botswana',
#   'mail': None,
#   'registered': '2011-10-26',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BW'},
#  {'id': '2001105370',
#   'username': 'linda06',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Helena',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1971-04-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1082961',
#   'username': 'debra93',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Vincent and the Grenadines',
#   'mail': 'james92@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'VC'},
#  {'id': '1800027635',
#   'username': 'michael28',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2349333',
#   'username': 'castrojoseph',
#   'name': 'Manuel Price',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002203670',
#   'username': 'marissawolf',
#   'name': None,
#   'sex': None,
#   'country': 'El Salvador',
#   'mail': 'cgeorge@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SV'},
#  {'id': '553115',
#   'username': 'gleblanc',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'duncanadam@yahoo.com',
#   'registered': '2018-02-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002106714',
#   'username': 'lisa38',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2003-11-16',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '709872',
#   'username': 'hoffmanjulie',
#   'name': 'Anthony Ellis',
#   'sex': 'M',
#   'country': 'Taiwan',
#   'mail': None,
#   'registered': '2012-11-11',
#   'birthdate': '1960-01-18',
#   'name_prefix': None,
#   'country_code': 'TW'},
#  {'id': '2000332934',
#   'username': 'mcdowellteresa',
#   'name': 'Taylor Mejia',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2011-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  ...]

# %% [markdown]
# 2. Измерьте время выполнения функции из задания 1 на всех файлах из архива. Ускорьте время выполнения, используя `dask.delayed`.

# %%
# %%time
parse_reviewers_zip("reviewers_full.zip")
# Out:
# Wall time: 5min 3s
# [{'id': '2214951',
#   'username': 'nancyharrison',
#   'name': None,
#   'sex': 'M',
#   'country': 'Mali',
#   'mail': None,
#   'registered': '2017-05-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ML'},
#  {'id': '133503',
#   'username': 'patrickbird',
#   'name': None,
#   'sex': None,
#   'country': 'Venezuela',
#   'mail': 'matthew29@yahoo.com',
#   'registered': '2005-03-22',
#   'birthdate': '1958-10-07',
#   'name_prefix': None,
#   'country_code': 'VE'},
#  {'id': '465229',
#   'username': 'xcamacho',
#   'name': 'Lisa Anderson',
#   'sex': 'F',
#   'country': 'Suriname',
#   'mail': 'david13@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SR'},
#  {'id': '2000340227',
#   'username': 'andersonshane',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'shermanterri@hotmail.com',
#   'registered': '2014-05-15',
#   'birthdate': '1982-12-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000070758',
#   'username': 'williamdelgado',
#   'name': 'Ryan Beasley',
#   'sex': None,
#   'country': 'Martinique',
#   'mail': 'mbrown@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MQ'},
#  {'id': '2184634',
#   'username': 'jasminelewis',
#   'name': 'William Hernandez',
#   'sex': None,
#   'country': 'Tuvalu',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1954-03-13',
#   'name_prefix': None,
#   'country_code': 'TV'},
#  {'id': '2001371918',
#   'username': 'stacysnyder',
#   'name': 'Evan Caldwell',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1984-06-19',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1803328795',
#   'username': 'wrightashley',
#   'name': 'Jeanette Griffin',
#   'sex': None,
#   'country': 'Solomon Islands',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1959-03-26',
#   'name_prefix': None,
#   'country_code': 'SB'},
#  {'id': '2001518157',
#   'username': 'jkim',
#   'name': 'Thomas Copeland',
#   'sex': None,
#   'country': None,
#   'mail': 'fhall@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001102305',
#   'username': 'christopher43',
#   'name': 'Timothy Salazar',
#   'sex': 'M',
#   'country': 'Montserrat',
#   'mail': None,
#   'registered': '2009-05-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MS'},
#  {'id': '2001513936',
#   'username': 'jermaine11',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1979-03-16',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1281143',
#   'username': 'christinahines',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'julie54@hotmail.com',
#   'registered': None,
#   'birthdate': '1999-08-22',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1772092',
#   'username': 'jessica41',
#   'name': 'Devin Romero',
#   'sex': None,
#   'country': 'Tunisia',
#   'mail': 'jacqueline34@yahoo.com',
#   'registered': '2018-12-07',
#   'birthdate': '1966-05-19',
#   'name_prefix': None,
#   'country_code': 'TN'},
#  {'id': '416021',
#   'username': 'angela99',
#   'name': 'Judy Wells',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-06-03',
#   'birthdate': '1970-03-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1934204',
#   'username': 'gary96',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'thomasnatasha@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002101923',
#   'username': 'cathy55',
#   'name': 'Ricky Brown',
#   'sex': None,
#   'country': 'Puerto Rico',
#   'mail': 'shari95@hotmail.com',
#   'registered': '2018-03-21',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PR'},
#  {'id': '185716',
#   'username': 'nashlisa',
#   'name': 'Michael Shea',
#   'sex': None,
#   'country': 'Norfolk Island',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1989-04-06',
#   'name_prefix': None,
#   'country_code': 'NF'},
#  {'id': '2001458570',
#   'username': 'johnsonandrew',
#   'name': 'Renee Stevens',
#   'sex': 'F',
#   'country': None,
#   'mail': 'austin09@hotmail.com',
#   'registered': '2002-07-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '223986',
#   'username': 'nicholasscott',
#   'name': 'Amanda Smith MD',
#   'sex': 'F',
#   'country': 'Antigua and Barbuda',
#   'mail': None,
#   'registered': '2006-07-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AG'},
#  {'id': '43634',
#   'username': 'whunt',
#   'name': 'Ryan Garcia',
#   'sex': 'M',
#   'country': None,
#   'mail': 'yjohnson@gmail.com',
#   'registered': '2014-05-09',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1803044776',
#   'username': 'bensonstephen',
#   'name': 'Elizabeth Smith',
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'sabrinajohnson@hotmail.com',
#   'registered': '2016-10-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1077239',
#   'username': 'wilsonmarie',
#   'name': 'Jerry Banks',
#   'sex': None,
#   'country': 'Dominican Republic',
#   'mail': None,
#   'registered': '2011-05-22',
#   'birthdate': '1965-12-19',
#   'name_prefix': None,
#   'country_code': 'DO'},
#  {'id': '889269',
#   'username': 'snydernathaniel',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2006-10-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '895323',
#   'username': 'joyce17',
#   'name': None,
#   'sex': None,
#   'country': 'Central African Republic',
#   'mail': 'rangeldarren@gmail.com',
#   'registered': '2002-12-16',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CF'},
#  {'id': '1016614',
#   'username': 'jeffrey71',
#   'name': None,
#   'sex': 'F',
#   'country': 'Turkey',
#   'mail': 'george44@hotmail.com',
#   'registered': '2005-10-13',
#   'birthdate': '1998-08-20',
#   'name_prefix': 'Dr.',
#   'country_code': 'TR'},
#  {'id': '828337',
#   'username': 'karenflores',
#   'name': None,
#   'sex': None,
#   'country': 'Namibia',
#   'mail': 'johnmcintyre@yahoo.com',
#   'registered': '2019-04-01',
#   'birthdate': '1977-05-07',
#   'name_prefix': None,
#   'country_code': 'nan'},
#  {'id': '794683',
#   'username': 'nataliesmith',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2957007',
#   'username': 'morsesarah',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2010-12-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '83655',
#   'username': 'emilywilliams',
#   'name': None,
#   'sex': None,
#   'country': 'Singapore',
#   'mail': None,
#   'registered': '2007-10-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SG'},
#  {'id': '1218686',
#   'username': 'tlarsen',
#   'name': 'Jimmy Roberts',
#   'sex': None,
#   'country': 'Nicaragua',
#   'mail': 'kimberly88@yahoo.com',
#   'registered': '2011-04-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NI'},
#  {'id': '1802940811',
#   'username': 'erinsnyder',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'lindsaywilliamson@yahoo.com',
#   'registered': '2008-07-02',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802425061',
#   'username': 'paul20',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'daniel42@hotmail.com',
#   'registered': '2003-12-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '803167',
#   'username': 'houstonarthur',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2007-12-20',
#   'birthdate': '1999-10-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001526127',
#   'username': 'randychaney',
#   'name': 'Mark Bell',
#   'sex': 'M',
#   'country': 'Sao Tome and Principe',
#   'mail': 'andersonsarah@gmail.com',
#   'registered': None,
#   'birthdate': '1963-09-27',
#   'name_prefix': 'Mr.',
#   'country_code': 'ST'},
#  {'id': '2001550502',
#   'username': 'awilliamson',
#   'name': None,
#   'sex': 'M',
#   'country': 'Romania',
#   'mail': 'jeffrey41@yahoo.com',
#   'registered': '2001-02-15',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'RO'},
#  {'id': '1503718',
#   'username': 'vanderson',
#   'name': 'Karen Hansen',
#   'sex': None,
#   'country': None,
#   'mail': 'garciaamy@hotmail.com',
#   'registered': None,
#   'birthdate': '2017-06-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1556217',
#   'username': 'thomas66',
#   'name': 'Heather Moore',
#   'sex': 'F',
#   'country': 'Equatorial Guinea',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1962-05-21',
#   'name_prefix': None,
#   'country_code': 'GQ'},
#  {'id': '1348760',
#   'username': 'rosswilliam',
#   'name': 'Joseph Evans',
#   'sex': 'M',
#   'country': None,
#   'mail': 'veronica90@yahoo.com',
#   'registered': '2017-12-24',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '555207',
#   'username': 'hendrixglenda',
#   'name': None,
#   'sex': 'M',
#   'country': 'Norfolk Island',
#   'mail': 'grahammatthew@yahoo.com',
#   'registered': None,
#   'birthdate': '2012-06-15',
#   'name_prefix': None,
#   'country_code': 'NF'},
#  {'id': '1131675',
#   'username': 'hernandezkevin',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'theresagarcia@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2000724854',
#   'username': 'weberjennifer',
#   'name': 'Ryan Elliott',
#   'sex': None,
#   'country': 'Belarus',
#   'mail': 'hmunoz@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BY'},
#  {'id': '1802448607',
#   'username': 'elizabethmorse',
#   'name': None,
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'ofischer@yahoo.com',
#   'registered': '2004-01-23',
#   'birthdate': '1954-02-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '399884',
#   'username': 'stephanie08',
#   'name': 'Pamela Hopkins',
#   'sex': 'F',
#   'country': 'Moldova',
#   'mail': None,
#   'registered': '2002-02-13',
#   'birthdate': '1956-06-22',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  {'id': '571595',
#   'username': 'kimdana',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-11-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1938165',
#   'username': 'robinbarton',
#   'name': None,
#   'sex': 'M',
#   'country': 'Qatar',
#   'mail': 'kingrachel@yahoo.com',
#   'registered': '2018-01-05',
#   'birthdate': '1988-09-10',
#   'name_prefix': 'Dr.',
#   'country_code': 'QA'},
#  {'id': '115889',
#   'username': 'jacksonmelissa',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2016-04-07',
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001306800',
#   'username': 'ryan06',
#   'name': 'Randy Brock',
#   'sex': None,
#   'country': 'Monaco',
#   'mail': None,
#   'registered': '2012-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '924670',
#   'username': 'tracy83',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'sandracollins@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '1615918',
#   'username': 'kevin05',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2009-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2550731',
#   'username': 'zwilkinson',
#   'name': 'Carly Rodriguez',
#   'sex': 'F',
#   'country': 'Albania',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1961-07-01',
#   'name_prefix': 'Dr.',
#   'country_code': 'AL'},
#  {'id': '408915',
#   'username': 'rogerdavis',
#   'name': None,
#   'sex': 'M',
#   'country': 'Denmark',
#   'mail': None,
#   'registered': '2014-12-02',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'DK'},
#  {'id': '2000132968',
#   'username': 'chadlopez',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'wrightemily@gmail.com',
#   'registered': '2011-03-29',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '653728',
#   'username': 'moorejessica',
#   'name': None,
#   'sex': None,
#   'country': 'Ukraine',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1991-02-18',
#   'name_prefix': None,
#   'country_code': 'UA'},
#  {'id': '1784879',
#   'username': 'richardsdiane',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1988-01-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001765255',
#   'username': 'alexandracarrillo',
#   'name': 'Michael Lewis',
#   'sex': 'M',
#   'country': 'Yemen',
#   'mail': None,
#   'registered': '2004-10-14',
#   'birthdate': '2002-05-28',
#   'name_prefix': None,
#   'country_code': 'YE'},
#  {'id': '414879',
#   'username': 'youngstacey',
#   'name': 'Dustin Ward',
#   'sex': None,
#   'country': 'Belarus',
#   'mail': None,
#   'registered': '2011-12-11',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BY'},
#  {'id': '964574',
#   'username': 'deborahwhitehead',
#   'name': 'Bridget Jenkins',
#   'sex': None,
#   'country': 'Netherlands',
#   'mail': 'rachael79@yahoo.com',
#   'registered': '2011-06-20',
#   'birthdate': '2001-06-13',
#   'name_prefix': None,
#   'country_code': 'NL'},
#  {'id': '1512881',
#   'username': 'qlee',
#   'name': None,
#   'sex': 'M',
#   'country': 'Saudi Arabia',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1990-06-18',
#   'name_prefix': 'Mr.',
#   'country_code': 'SA'},
#  {'id': '2782242',
#   'username': 'ljohnson',
#   'name': None,
#   'sex': 'M',
#   'country': 'Venezuela',
#   'mail': 'williamholmes@yahoo.com',
#   'registered': '2006-02-11',
#   'birthdate': '1972-05-23',
#   'name_prefix': None,
#   'country_code': 'VE'},
#  {'id': '208551',
#   'username': 'alexarmstrong',
#   'name': 'Heather White',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1971-02-16',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2001603876',
#   'username': 'bobbyshaffer',
#   'name': None,
#   'sex': None,
#   'country': 'Belize',
#   'mail': 'sbrown@gmail.com',
#   'registered': '2002-06-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BZ'},
#  {'id': '1147024',
#   'username': 'brooksamy',
#   'name': None,
#   'sex': 'F',
#   'country': 'Norway',
#   'mail': 'fcochran@hotmail.com',
#   'registered': None,
#   'birthdate': '1982-02-23',
#   'name_prefix': 'Mrs.',
#   'country_code': 'NO'},
#  {'id': '2001830605',
#   'username': 'robinbaker',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2010-02-08',
#   'birthdate': '1966-03-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1689981',
#   'username': 'johnsonchristine',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2015-02-17',
#   'birthdate': '1989-06-07',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '154444',
#   'username': 'bhayes',
#   'name': None,
#   'sex': 'F',
#   'country': 'Faroe Islands',
#   'mail': 'chavezjohn@yahoo.com',
#   'registered': '2004-06-23',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': 'FO'},
#  {'id': '1063387',
#   'username': 'dianegreen',
#   'name': None,
#   'sex': 'F',
#   'country': 'Norfolk Island',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1950-12-04',
#   'name_prefix': 'Ms.',
#   'country_code': 'NF'},
#  {'id': '695667',
#   'username': 'andrew56',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2009-03-31',
#   'birthdate': '2016-01-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001288394',
#   'username': 'steven08',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'rebeccahall@gmail.com',
#   'registered': '2004-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '680685',
#   'username': 'mschmidt',
#   'name': 'Lisa Graham',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-01-27',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803469180',
#   'username': 'ghenry',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cambodia',
#   'mail': 'jacob11@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KH'},
#  {'id': '2171005',
#   'username': 'pruittdustin',
#   'name': 'Bobby Anderson',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1970-10-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001819258',
#   'username': 'kristinalee',
#   'name': None,
#   'sex': 'M',
#   'country': 'Indonesia',
#   'mail': 'tgonzales@gmail.com',
#   'registered': None,
#   'birthdate': '1962-03-29',
#   'name_prefix': None,
#   'country_code': 'ID'},
#  {'id': '2001464611',
#   'username': 'garrettisabel',
#   'name': 'Melissa Newton',
#   'sex': None,
#   'country': None,
#   'mail': 'susan54@hotmail.com',
#   'registered': '2010-08-14',
#   'birthdate': '1953-09-19',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001989158',
#   'username': 'kimberly62',
#   'name': 'Sarah Cordova',
#   'sex': 'F',
#   'country': 'Chile',
#   'mail': 'vaughnbruce@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': 'CL'},
#  {'id': '41914309',
#   'username': 'fromero',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1967-09-25',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2000267872',
#   'username': 'colemonica',
#   'name': 'Chelsea Walters',
#   'sex': 'F',
#   'country': None,
#   'mail': 'eriksimmons@gmail.com',
#   'registered': None,
#   'birthdate': '1972-08-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001918763',
#   'username': 'anthonymiranda',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Pierre and Miquelon',
#   'mail': 'jose40@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PM'},
#  {'id': '2001295337',
#   'username': 'murphybrenda',
#   'name': None,
#   'sex': None,
#   'country': 'Argentina',
#   'mail': None,
#   'registered': '2013-09-19',
#   'birthdate': '1993-11-15',
#   'name_prefix': None,
#   'country_code': 'AR'},
#  {'id': '1803726482',
#   'username': 'dyergeorge',
#   'name': None,
#   'sex': None,
#   'country': 'Isle of Man',
#   'mail': 'ortizcatherine@yahoo.com',
#   'registered': '2009-12-02',
#   'birthdate': '1989-09-17',
#   'name_prefix': None,
#   'country_code': 'IM'},
#  {'id': '1419516',
#   'username': 'alyssa72',
#   'name': 'Jennifer Brown',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1958-11-01',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1059343',
#   'username': 'kbowen',
#   'name': None,
#   'sex': None,
#   'country': 'Comoros',
#   'mail': 'john10@yahoo.com',
#   'registered': '2018-11-23',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KM'},
#  {'id': '2001358459',
#   'username': 'smoore',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2003-11-22',
#   'birthdate': '1966-09-03',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2213373',
#   'username': 'gwalter',
#   'name': None,
#   'sex': 'M',
#   'country': 'Comoros',
#   'mail': 'yharris@hotmail.com',
#   'registered': '2019-01-22',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'KM'},
#  {'id': '900242',
#   'username': 'cvega',
#   'name': None,
#   'sex': None,
#   'country': 'United Kingdom',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GB'},
#  {'id': '2001633136',
#   'username': 'xdavid',
#   'name': 'Benjamin Payne',
#   'sex': None,
#   'country': None,
#   'mail': 'xmartin@hotmail.com',
#   'registered': '2004-08-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '131846',
#   'username': 'gtorres',
#   'name': 'Daniel Randall',
#   'sex': 'M',
#   'country': 'Iceland',
#   'mail': 'mhanson@hotmail.com',
#   'registered': '2003-05-01',
#   'birthdate': '1967-05-06',
#   'name_prefix': 'Mr.',
#   'country_code': 'IS'},
#  {'id': '2704845',
#   'username': 'moodywilliam',
#   'name': 'Sandra Allen',
#   'sex': 'F',
#   'country': None,
#   'mail': 'john09@yahoo.com',
#   'registered': '2009-05-29',
#   'birthdate': '1963-03-18',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '1711046',
#   'username': 'theodore43',
#   'name': None,
#   'sex': None,
#   'country': 'Kazakhstan',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1986-07-26',
#   'name_prefix': None,
#   'country_code': 'KZ'},
#  {'id': '16727',
#   'username': 'qwilliams',
#   'name': 'Ariel Torres',
#   'sex': None,
#   'country': 'Cuba',
#   'mail': None,
#   'registered': '2017-08-16',
#   'birthdate': '2010-06-05',
#   'name_prefix': None,
#   'country_code': 'CU'},
#  {'id': '2262192',
#   'username': 'maria65',
#   'name': 'Daniel Gomez',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-04-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1852150',
#   'username': 'ecombs',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'shawn18@yahoo.com',
#   'registered': '2002-02-17',
#   'birthdate': '1954-03-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1902228',
#   'username': 'lopezjoshua',
#   'name': 'Hunter Andrade',
#   'sex': 'M',
#   'country': 'Uzbekistan',
#   'mail': None,
#   'registered': '2016-07-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'UZ'},
#  {'id': '1802411092',
#   'username': 'branchjustin',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'colonleslie@yahoo.com',
#   'registered': '2003-06-11',
#   'birthdate': '1950-05-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '313400',
#   'username': 'darrell92',
#   'name': None,
#   'sex': None,
#   'country': 'Cayman Islands',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1979-04-18',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'id': '1741988',
#   'username': 'riceaustin',
#   'name': 'Jacqueline Davis',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jackiepearson@hotmail.com',
#   'registered': None,
#   'birthdate': '2020-11-30',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001071395',
#   'username': 'qstevens',
#   'name': None,
#   'sex': None,
#   'country': 'Croatia',
#   'mail': 'pwelch@hotmail.com',
#   'registered': '2018-11-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'HR'},
#  {'id': '1107287',
#   'username': 'larnold',
#   'name': None,
#   'sex': None,
#   'country': 'Mexico',
#   'mail': 'jamesjacob@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MX'},
#  {'id': '2001253094',
#   'username': 'oreynolds',
#   'name': 'Daniel Scott',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2013-06-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001934718',
#   'username': 'millerbrandon',
#   'name': 'Charles Williams',
#   'sex': None,
#   'country': 'Yemen',
#   'mail': 'franklindennis@hotmail.com',
#   'registered': None,
#   'birthdate': '2001-01-10',
#   'name_prefix': None,
#   'country_code': 'YE'},
#  {'id': '129009',
#   'username': 'parkertim',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'ccampbell@gmail.com',
#   'registered': '2004-08-13',
#   'birthdate': '1996-01-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '229995',
#   'username': 'christineschultz',
#   'name': 'Emily Townsend',
#   'sex': None,
#   'country': None,
#   'mail': 'stevenwade@gmail.com',
#   'registered': '2016-10-08',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001919522',
#   'username': 'danielcox',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'vweaver@hotmail.com',
#   'registered': None,
#   'birthdate': '1979-08-29',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '696126',
#   'username': 'oconway',
#   'name': None,
#   'sex': None,
#   'country': 'Guernsey',
#   'mail': 'kathrynswanson@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GG'},
#  {'id': '1803126280',
#   'username': 'thomasspencer',
#   'name': 'Drew White',
#   'sex': None,
#   'country': 'Niger',
#   'mail': None,
#   'registered': '2008-02-24',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NE'},
#  {'id': '9061',
#   'username': 'robertschristopher',
#   'name': None,
#   'sex': 'F',
#   'country': 'Congo',
#   'mail': 'millertyler@hotmail.com',
#   'registered': None,
#   'birthdate': '2008-03-05',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1863645',
#   'username': 'barkerdenise',
#   'name': 'Sharon Burns',
#   'sex': None,
#   'country': 'Zimbabwe',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ZW'},
#  {'id': '2569219',
#   'username': 'dustinjones',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001525477',
#   'username': 'hoodalyssa',
#   'name': 'Michael Flores',
#   'sex': 'M',
#   'country': None,
#   'mail': 'zvaughan@gmail.com',
#   'registered': '2004-08-31',
#   'birthdate': '1963-01-19',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1737112',
#   'username': 'hlara',
#   'name': 'Jordan Lloyd',
#   'sex': None,
#   'country': None,
#   'mail': 'shernandez@yahoo.com',
#   'registered': None,
#   'birthdate': '1982-03-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '592565',
#   'username': 'xwilliams',
#   'name': 'Patrick Bennett',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2003-06-03',
#   'birthdate': '2014-05-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '4894725',
#   'username': 'robert50',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2017-02-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002323000',
#   'username': 'erios',
#   'name': 'Robert Daniels',
#   'sex': None,
#   'country': None,
#   'mail': 'nbrooks@yahoo.com',
#   'registered': '2005-02-11',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1369303',
#   'username': 'bakerandrew',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'danagonzalez@hotmail.com',
#   'registered': '2015-05-17',
#   'birthdate': '1967-03-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '164472',
#   'username': 'thomasaaron',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '648053',
#   'username': 'stephaniehunt',
#   'name': None,
#   'sex': None,
#   'country': 'Burundi',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BI'},
#  {'id': '1633640',
#   'username': 'anitacurry',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'mkidd@hotmail.com',
#   'registered': None,
#   'birthdate': '2012-03-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001289075',
#   'username': 'vwheeler',
#   'name': None,
#   'sex': None,
#   'country': 'Angola',
#   'mail': 'rachel88@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AO'},
#  {'id': '2002261007',
#   'username': 'jennifer26',
#   'name': 'Michelle Delacruz',
#   'sex': 'F',
#   'country': None,
#   'mail': 'imoss@yahoo.com',
#   'registered': '2017-01-28',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001592205',
#   'username': 'jasonchapman',
#   'name': 'Ashley Wood',
#   'sex': 'F',
#   'country': 'Bulgaria',
#   'mail': 'peterwebb@yahoo.com',
#   'registered': '2007-09-07',
#   'birthdate': '2011-09-30',
#   'name_prefix': 'Dr.',
#   'country_code': 'BG'},
#  {'id': '2001650873',
#   'username': 'simmonsdebra',
#   'name': 'Douglas Williams',
#   'sex': 'M',
#   'country': 'Faroe Islands',
#   'mail': 'patricia52@gmail.com',
#   'registered': '2001-11-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'FO'},
#  {'id': '1335705',
#   'username': 'amyjohnson',
#   'name': None,
#   'sex': None,
#   'country': 'Malaysia',
#   'mail': None,
#   'registered': '2013-09-18',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MY'},
#  {'id': '456677',
#   'username': 'kcraig',
#   'name': None,
#   'sex': None,
#   'country': 'Rwanda',
#   'mail': None,
#   'registered': '2002-03-12',
#   'birthdate': '2006-04-05',
#   'name_prefix': None,
#   'country_code': 'RW'},
#  {'id': '2002164644',
#   'username': 'brendacook',
#   'name': 'Sean Li',
#   'sex': 'M',
#   'country': 'Malta',
#   'mail': 'ramosrichard@gmail.com',
#   'registered': '2011-05-08',
#   'birthdate': '1990-08-03',
#   'name_prefix': 'Mr.',
#   'country_code': 'MT'},
#  {'id': '2512888',
#   'username': 'sarnold',
#   'name': None,
#   'sex': 'M',
#   'country': 'Tonga',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2002-06-01',
#   'name_prefix': None,
#   'country_code': 'TO'},
#  {'id': '2001326325',
#   'username': 'mmorris',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'christopherchristian@hotmail.com',
#   'registered': None,
#   'birthdate': '1968-11-07',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1655021',
#   'username': 'griffinangela',
#   'name': 'Gregory Rich',
#   'sex': 'M',
#   'country': None,
#   'mail': 'hannah06@gmail.com',
#   'registered': '2005-07-25',
#   'birthdate': '2001-09-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1080290',
#   'username': 'browncharles',
#   'name': 'Rhonda Zuniga',
#   'sex': 'F',
#   'country': 'Jamaica',
#   'mail': None,
#   'registered': '2011-10-19',
#   'birthdate': '2020-07-06',
#   'name_prefix': None,
#   'country_code': 'JM'},
#  {'id': '629957',
#   'username': 'lharris',
#   'name': 'Henry Hughes',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-06-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '515832',
#   'username': 'lori51',
#   'name': None,
#   'sex': None,
#   'country': 'Samoa',
#   'mail': None,
#   'registered': '2006-05-06',
#   'birthdate': '1992-01-17',
#   'name_prefix': None,
#   'country_code': 'WS'},
#  {'id': '2001921038',
#   'username': 'zwalter',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2007-03-13',
#   'birthdate': '1978-08-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '342031',
#   'username': 'michelle08',
#   'name': None,
#   'sex': 'M',
#   'country': 'Ecuador',
#   'mail': None,
#   'registered': '2012-01-10',
#   'birthdate': '2006-10-21',
#   'name_prefix': 'Dr.',
#   'country_code': 'EC'},
#  {'id': '1731223',
#   'username': 'patricia00',
#   'name': 'Elizabeth Kelly',
#   'sex': None,
#   'country': 'Malta',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MT'},
#  {'id': '988862',
#   'username': 'jeremiah42',
#   'name': None,
#   'sex': None,
#   'country': 'Slovenia',
#   'mail': None,
#   'registered': '2001-05-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SI'},
#  {'id': '2377724',
#   'username': 'edward64',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'pamela42@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '383972',
#   'username': 'storres',
#   'name': 'Mindy Wheeler',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2019-05-03',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1152480',
#   'username': 'floresmaria',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'heather24@yahoo.com',
#   'registered': None,
#   'birthdate': '1951-01-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1431830',
#   'username': 'stephaniemeadows',
#   'name': 'David Wheeler',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1803390159',
#   'username': 'jacksondavid',
#   'name': 'Robin Watson',
#   'sex': 'F',
#   'country': None,
#   'mail': 'anthonywong@gmail.com',
#   'registered': '2011-01-26',
#   'birthdate': '1989-04-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '546092',
#   'username': 'julie41',
#   'name': 'Timothy Garcia',
#   'sex': 'M',
#   'country': 'South Africa',
#   'mail': 'sanchezkristin@yahoo.com',
#   'registered': '2001-02-10',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'ZA'},
#  {'id': '2002298070',
#   'username': 'mbrown',
#   'name': 'Linda Nielsen',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000326112',
#   'username': 'kyates',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'zcombs@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '513570',
#   'username': 'april74',
#   'name': None,
#   'sex': None,
#   'country': 'Malta',
#   'mail': 'wjimenez@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'MT'},
#  {'id': '393102',
#   'username': 'fosterkimberly',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cape Verde',
#   'mail': 'alicia96@yahoo.com',
#   'registered': None,
#   'birthdate': '1986-09-18',
#   'name_prefix': None,
#   'country_code': 'CV'},
#  {'id': '1272121',
#   'username': 'zwilliams',
#   'name': None,
#   'sex': None,
#   'country': 'Guatemala',
#   'mail': 'tmaldonado@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'GT'},
#  {'id': '495505',
#   'username': 'charlessoto',
#   'name': 'Andrea Miller',
#   'sex': 'F',
#   'country': 'Saint Helena',
#   'mail': 'jessicaritter@yahoo.com',
#   'registered': '2012-06-12',
#   'birthdate': '2002-08-29',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000279207',
#   'username': 'dianedavid',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2005-09-03',
#   'birthdate': '1986-09-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '976856',
#   'username': 'nobleshelly',
#   'name': 'Brian Flowers',
#   'sex': 'M',
#   'country': None,
#   'mail': 'nataliebrown@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2459090',
#   'username': 'jonesangela',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001827621',
#   'username': 'stephanie97',
#   'name': 'Elaine Griffin',
#   'sex': None,
#   'country': None,
#   'mail': 'bturner@gmail.com',
#   'registered': '2011-03-02',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803766108',
#   'username': 'ojohnson',
#   'name': 'Matthew Moss',
#   'sex': 'M',
#   'country': None,
#   'mail': 'shanefernandez@hotmail.com',
#   'registered': '2011-04-30',
#   'birthdate': '1971-08-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001386821',
#   'username': 'blloyd',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802916686',
#   'username': 'nicholas90',
#   'name': 'Heidi Lee',
#   'sex': None,
#   'country': None,
#   'mail': 'huntmanuel@hotmail.com',
#   'registered': '2001-05-05',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001229677',
#   'username': 'marvin14',
#   'name': 'Julie Holt',
#   'sex': 'F',
#   'country': 'Tonga',
#   'mail': 'debragreer@yahoo.com',
#   'registered': '2001-10-13',
#   'birthdate': '1981-01-16',
#   'name_prefix': None,
#   'country_code': 'TO'},
#  {'id': '1613992',
#   'username': 'stephanieroman',
#   'name': None,
#   'sex': 'M',
#   'country': 'Cyprus',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CY'},
#  {'id': '1800534445',
#   'username': 'wwilliams',
#   'name': 'Emma Dorsey',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000172021',
#   'username': 'jamesmeyer',
#   'name': None,
#   'sex': 'M',
#   'country': 'Qatar',
#   'mail': 'williamsjennifer@gmail.com',
#   'registered': '2012-11-20',
#   'birthdate': '1988-05-30',
#   'name_prefix': 'Mr.',
#   'country_code': 'QA'},
#  {'id': '197917',
#   'username': 'diana85',
#   'name': 'Annette Walker',
#   'sex': None,
#   'country': None,
#   'mail': 'hsanchez@yahoo.com',
#   'registered': '2011-03-10',
#   'birthdate': '1956-05-07',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '170477',
#   'username': 'uboone',
#   'name': 'Matthew Smith',
#   'sex': None,
#   'country': 'Dominican Republic',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1975-01-31',
#   'name_prefix': None,
#   'country_code': 'DO'},
#  {'id': '2000320101',
#   'username': 'angela49',
#   'name': None,
#   'sex': None,
#   'country': 'Ukraine',
#   'mail': 'alexandrialucas@gmail.com',
#   'registered': '2016-02-07',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'UA'},
#  {'id': '2863874',
#   'username': 'rileystacey',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803676843',
#   'username': 'xdiaz',
#   'name': None,
#   'sex': 'F',
#   'country': 'Saint Barthelemy',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '673994',
#   'username': 'pchandler',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'lcrawford@hotmail.com',
#   'registered': '2001-12-12',
#   'birthdate': '1952-12-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001932921',
#   'username': 'cgarcia',
#   'name': 'Shannon Ferrell',
#   'sex': 'F',
#   'country': None,
#   'mail': 'weaverjason@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001138349',
#   'username': 'megan97',
#   'name': 'Valerie Scott DDS',
#   'sex': 'F',
#   'country': 'Mauritania',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1976-11-08',
#   'name_prefix': None,
#   'country_code': 'MR'},
#  {'id': '1666217',
#   'username': 'cannondavid',
#   'name': 'Amber Sanchez',
#   'sex': 'F',
#   'country': 'Switzerland',
#   'mail': None,
#   'registered': '2011-09-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'CH'},
#  {'id': '2030257',
#   'username': 'emily63',
#   'name': 'Brian Brown',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-07-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1873879',
#   'username': 'roger33',
#   'name': 'Dale Larson',
#   'sex': 'M',
#   'country': 'Burundi',
#   'mail': None,
#   'registered': '2016-11-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BI'},
#  {'id': '2000798626',
#   'username': 'lorigray',
#   'name': 'Eric Santiago',
#   'sex': 'M',
#   'country': 'Czech Republic',
#   'mail': 'walterguzman@yahoo.com',
#   'registered': None,
#   'birthdate': '1966-06-28',
#   'name_prefix': 'Dr.',
#   'country_code': 'CZ'},
#  {'id': '1176705',
#   'username': 'michelle47',
#   'name': 'Micheal Richards',
#   'sex': 'M',
#   'country': 'Hong Kong',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1982-09-27',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '625069',
#   'username': 'allenmisty',
#   'name': None,
#   'sex': 'F',
#   'country': 'South Georgia and the South Sandwich Islands',
#   'mail': 'williamsmichelle@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Ms.',
#   'country_code': 'GS'},
#  {'id': '220778',
#   'username': 'hudsonchelsea',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-04-21',
#   'birthdate': '2007-09-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '998160',
#   'username': 'santoschristopher',
#   'name': 'Rodney Robinson',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1956-07-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000799446',
#   'username': 'stevenperry',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1959-08-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2744065',
#   'username': 'craigburns',
#   'name': None,
#   'sex': None,
#   'country': 'Egypt',
#   'mail': None,
#   'registered': '2016-05-09',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'EG'},
#  {'id': '1256651',
#   'username': 'rachelrose',
#   'name': None,
#   'sex': None,
#   'country': 'Uruguay',
#   'mail': 'beverlymiller@hotmail.com',
#   'registered': None,
#   'birthdate': '2008-08-05',
#   'name_prefix': None,
#   'country_code': 'UY'},
#  {'id': '2917875',
#   'username': 'michaelstephens',
#   'name': 'Deborah Wilson',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001265796',
#   'username': 'laura23',
#   'name': None,
#   'sex': None,
#   'country': 'Congo',
#   'mail': 'brose@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1674452',
#   'username': 'timothysosa',
#   'name': 'Richard Brennan',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2012-05-03',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '42674742',
#   'username': 'olivia20',
#   'name': 'Jon Rodriguez',
#   'sex': None,
#   'country': 'Cayman Islands',
#   'mail': 'kimmark@hotmail.com',
#   'registered': '2004-01-24',
#   'birthdate': '1965-04-17',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'id': '191406',
#   'username': 'stephanie48',
#   'name': None,
#   'sex': 'F',
#   'country': 'Monaco',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1966-02-12',
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '1209206',
#   'username': 'stephaniejackson',
#   'name': 'Christopher Luna',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '987097',
#   'username': 'powellchristina',
#   'name': 'Tonya White',
#   'sex': None,
#   'country': 'Japan',
#   'mail': 'calexander@yahoo.com',
#   'registered': '2017-07-16',
#   'birthdate': '1954-04-20',
#   'name_prefix': None,
#   'country_code': 'JP'},
#  {'id': '1803314861',
#   'username': 'edwardskara',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2004-10-18',
#   'birthdate': None,
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '177169',
#   'username': 'matthew52',
#   'name': 'Peter Morgan',
#   'sex': 'M',
#   'country': None,
#   'mail': 'qberg@hotmail.com',
#   'registered': None,
#   'birthdate': '1971-03-25',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '117707',
#   'username': 'ndavis',
#   'name': 'Megan Dunn',
#   'sex': None,
#   'country': None,
#   'mail': 'cindy78@yahoo.com',
#   'registered': None,
#   'birthdate': '1979-10-16',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001974990',
#   'username': 'jenkinsdustin',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'davidberry@hotmail.com',
#   'registered': None,
#   'birthdate': '1992-08-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '149577',
#   'username': 'gallaghercarol',
#   'name': 'Kristie Allen',
#   'sex': None,
#   'country': 'United States Minor Outlying Islands',
#   'mail': 'michael10@gmail.com',
#   'registered': '2017-09-23',
#   'birthdate': '1951-02-20',
#   'name_prefix': None,
#   'country_code': 'UM'},
#  {'id': '2002221947',
#   'username': 'jennifer76',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'garciamadeline@yahoo.com',
#   'registered': None,
#   'birthdate': '2003-04-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '161134',
#   'username': 'holmescory',
#   'name': None,
#   'sex': 'M',
#   'country': 'Gibraltar',
#   'mail': 'esmith@yahoo.com',
#   'registered': '2004-08-03',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': 'GI'},
#  {'id': '2000346721',
#   'username': 'irodriguez',
#   'name': 'Adam Matthews',
#   'sex': None,
#   'country': 'Nigeria',
#   'mail': 'bneal@yahoo.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'NG'},
#  {'id': '689431',
#   'username': 'lauramyers',
#   'name': 'Timothy Martin',
#   'sex': None,
#   'country': 'Suriname',
#   'mail': 'henry43@gmail.com',
#   'registered': '2008-02-12',
#   'birthdate': '1978-10-25',
#   'name_prefix': None,
#   'country_code': 'SR'},
#  {'id': '2001393179',
#   'username': 'anitajones',
#   'name': 'John Collins',
#   'sex': 'M',
#   'country': None,
#   'mail': 'brennantina@gmail.com',
#   'registered': None,
#   'birthdate': '1975-12-07',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1185599',
#   'username': 'garciajohn',
#   'name': 'Peggy Nelson',
#   'sex': 'F',
#   'country': 'Antigua and Barbuda',
#   'mail': None,
#   'registered': '2010-05-30',
#   'birthdate': '1972-12-12',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AG'},
#  {'id': '2369255',
#   'username': 'cortiz',
#   'name': 'Hannah Martin',
#   'sex': None,
#   'country': 'Papua New Guinea',
#   'mail': 'danielhernandez@hotmail.com',
#   'registered': '2006-02-05',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'PG'},
#  {'id': '450198',
#   'username': 'thorn',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2017-09-20',
#   'birthdate': None,
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '413300',
#   'username': 'huntermontgomery',
#   'name': None,
#   'sex': None,
#   'country': 'Bulgaria',
#   'mail': 'perkinsmargaret@yahoo.com',
#   'registered': '2013-07-08',
#   'birthdate': '1997-10-19',
#   'name_prefix': None,
#   'country_code': 'BG'},
#  {'id': '2001270344',
#   'username': 'ayersjoshua',
#   'name': None,
#   'sex': 'F',
#   'country': 'Romania',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'RO'},
#  {'id': '2629862',
#   'username': 'carlosbautista',
#   'name': None,
#   'sex': 'F',
#   'country': 'Denmark',
#   'mail': 'xhurst@hotmail.com',
#   'registered': '2006-09-02',
#   'birthdate': '2016-07-29',
#   'name_prefix': 'Mrs.',
#   'country_code': 'DK'},
#  {'id': '2717582',
#   'username': 'smyers',
#   'name': 'Cynthia Perez',
#   'sex': None,
#   'country': 'Antarctica (the territory South of 60 deg S)',
#   'mail': None,
#   'registered': '2004-05-26',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1790143',
#   'username': 'bennettshawn',
#   'name': None,
#   'sex': 'F',
#   'country': 'Denmark',
#   'mail': 'collinsshawn@yahoo.com',
#   'registered': '2013-08-21',
#   'birthdate': '1968-06-27',
#   'name_prefix': 'Mrs.',
#   'country_code': 'DK'},
#  {'id': '1682018',
#   'username': 'william27',
#   'name': 'Nathan Brown',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '564587',
#   'username': 'cindy05',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2002-12-28',
#   'birthdate': '1972-03-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '4193438',
#   'username': 'fhayes',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'johnsonshane@yahoo.com',
#   'registered': '2010-10-26',
#   'birthdate': '2002-09-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1803197046',
#   'username': 'billysanders',
#   'name': 'Emily Mckinney',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2008-07-04',
#   'birthdate': '1989-01-14',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'id': '44862',
#   'username': 'gwilliams',
#   'name': 'Heather Frazier',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '244787',
#   'username': 'pkennedy',
#   'name': 'Samuel Mcbride',
#   'sex': None,
#   'country': None,
#   'mail': 'welchlarry@gmail.com',
#   'registered': '2018-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001078294',
#   'username': 'mirandathomas',
#   'name': None,
# ...
#   'country_code': 'GH'},
#  {'id': '338523',
#   'username': 'marystewart',
#   'name': 'Kendra Murphy',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AW'},
#  {'id': '2002321970',
#   'username': 'teresa50',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000266492',
#   'username': 'casey39',
#   'name': 'Alejandro Foster',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2001-05-26',
#   'birthdate': '1952-05-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '315579',
#   'username': 'martinezalicia',
#   'name': 'Melissa Bennett',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jenniferwood@gmail.com',
#   'registered': '2002-01-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1681976',
#   'username': 'gperez',
#   'name': None,
#   'sex': None,
#   'country': 'Azerbaijan',
#   'mail': 'sullivantimothy@hotmail.com',
#   'registered': '2019-08-23',
#   'birthdate': '1963-05-10',
#   'name_prefix': None,
#   'country_code': 'AZ'},
#  {'id': '946597',
#   'username': 'kimberlygaines',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-02-29',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1960622',
#   'username': 'murrayamber',
#   'name': None,
#   'sex': None,
#   'country': 'French Guiana',
#   'mail': 'bethanyhickman@yahoo.com',
#   'registered': '2002-09-25',
#   'birthdate': '1989-11-18',
#   'name_prefix': None,
#   'country_code': 'GF'},
#  {'id': '1461064',
#   'username': 'walkertara',
#   'name': None,
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'mail': None,
#   'registered': '2002-12-12',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'LA'},
#  {'id': '796003',
#   'username': 'david15',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'jturner@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '463756',
#   'username': 'brian30',
#   'name': None,
#   'sex': 'M',
#   'country': 'American Samoa',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1952-05-12',
#   'name_prefix': 'Mr.',
#   'country_code': 'AS'},
#  {'id': '364655',
#   'username': 'valerieharris',
#   'name': None,
#   'sex': None,
#   'country': 'Brazil',
#   'mail': 'pbrown@yahoo.com',
#   'registered': '2018-08-13',
#   'birthdate': '1952-03-01',
#   'name_prefix': None,
#   'country_code': 'BR'},
#  {'id': '2002276763',
#   'username': 'xnorton',
#   'name': 'Joseph Rangel',
#   'sex': 'M',
#   'country': 'Kiribati',
#   'mail': 'phillip13@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': 'KI'},
#  {'id': '768565',
#   'username': 'lthompson',
#   'name': 'Shawna Soto',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2010-02-21',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '2001730787',
#   'username': 'gkelley',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'anthonypadilla@gmail.com',
#   'registered': '2004-03-23',
#   'birthdate': '2010-12-12',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2001165454',
#   'username': 'nhughes',
#   'name': None,
#   'sex': None,
#   'country': 'Moldova',
#   'mail': 'mreyes@gmail.com',
#   'registered': None,
#   'birthdate': '1965-09-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '412471',
#   'username': 'williamschristopher',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2010-11-12',
#   'birthdate': '1985-12-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '882329',
#   'username': 'jamesallen',
#   'name': 'Glen Keller',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2012-04-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2737118',
#   'username': 'nicolewilliams',
#   'name': 'Kevin West',
#   'sex': None,
#   'country': None,
#   'mail': 'steven98@gmail.com',
#   'registered': None,
#   'birthdate': '1999-03-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001833118',
#   'username': 'santanaalexa',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1955-06-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1564621',
#   'username': 'hortonmartin',
#   'name': 'Alexander Jackson',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1960-03-08',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '2002053137',
#   'username': 'fsnyder',
#   'name': 'Kelly Perez',
#   'sex': 'F',
#   'country': 'Japan',
#   'mail': None,
#   'registered': '2014-09-16',
#   'birthdate': '2012-12-20',
#   'name_prefix': None,
#   'country_code': 'JP'},
#  {'id': '153270',
#   'username': 'leandrea',
#   'name': 'Douglas Nguyen',
#   'sex': None,
#   'country': None,
#   'mail': 'sonyaroberts@hotmail.com',
#   'registered': '2013-09-28',
#   'birthdate': '2020-08-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1706378',
#   'username': 'agarcia',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2015-08-21',
#   'birthdate': '1959-08-20',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'id': '2002045588',
#   'username': 'robertkim',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2011-10-19',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '747705',
#   'username': 'garciajeremy',
#   'name': 'Vicki Williams',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2019-01-17',
#   'birthdate': '1969-10-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2179227',
#   'username': 'avilataylor',
#   'name': 'Sherry Dillon',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001362866',
#   'username': 'josephsmith',
#   'name': 'Tiffany Luna',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2017-06-27',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1488508',
#   'username': 'msmith',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001833026',
#   'username': 'vbishop',
#   'name': None,
#   'sex': 'F',
#   'country': 'Maldives',
#   'mail': None,
#   'registered': '2016-11-15',
#   'birthdate': '1958-10-03',
#   'name_prefix': None,
#   'country_code': 'MV'},
#  {'id': '1762143',
#   'username': 'michael41',
#   'name': None,
#   'sex': None,
#   'country': 'Monaco',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2013-05-01',
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'id': '2525133',
#   'username': 'nicole55',
#   'name': 'Shannon Smith',
#   'sex': None,
#   'country': 'Bolivia',
#   'mail': 'patriciasullivan@gmail.com',
#   'registered': None,
#   'birthdate': '1980-12-05',
#   'name_prefix': None,
#   'country_code': 'BO'},
#  {'id': '27034',
#   'username': 'chandlertina',
#   'name': 'Rick Coleman',
#   'sex': 'M',
#   'country': 'Vietnam',
#   'mail': 'johndelgado@hotmail.com',
#   'registered': '2015-10-04',
#   'birthdate': '1963-08-04',
#   'name_prefix': 'Mr.',
#   'country_code': 'VN'},
#  {'id': '1877133',
#   'username': 'sueray',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'cheryl64@yahoo.com',
#   'registered': '2019-01-31',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000141963',
#   'username': 'timothybenson',
#   'name': 'Richard Townsend',
#   'sex': 'M',
#   'country': None,
#   'mail': 'clarkscott@hotmail.com',
#   'registered': '2011-04-14',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2408562',
#   'username': 'ybarrera',
#   'name': 'Willie Williams',
#   'sex': 'M',
#   'country': 'Haiti',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-12-07',
#   'name_prefix': None,
#   'country_code': 'HT'},
#  {'id': '2001804074',
#   'username': 'frenchjulia',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '1802504698',
#   'username': 'kristincurtis',
#   'name': None,
#   'sex': None,
#   'country': 'United States of America',
#   'mail': 'stephen69@hotmail.com',
#   'registered': '2009-12-12',
#   'birthdate': '1962-08-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '823664',
#   'username': 'ericdixon',
#   'name': 'Jerry Wade',
#   'sex': None,
#   'country': 'Albania',
#   'mail': 'tiffanypatterson@hotmail.com',
#   'registered': '2010-09-21',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'AL'},
#  {'id': '388577',
#   'username': 'leslie82',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'tyler41@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'id': '153695',
#   'username': 'evanvillegas',
#   'name': None,
#   'sex': 'F',
#   'country': 'Mayotte',
#   'mail': 'bbailey@yahoo.com',
#   'registered': None,
#   'birthdate': '1997-01-30',
#   'name_prefix': 'Mrs.',
#   'country_code': 'YT'},
#  {'id': '2718108',
#   'username': 'kmercado',
#   'name': 'Katherine Baker',
#   'sex': None,
#   'country': "Cote d'Ivoire",
#   'mail': 'smithjennifer@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2001251106',
#   'username': 'kimberly15',
#   'name': None,
#   'sex': None,
#   'country': 'Grenada',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1964-03-03',
#   'name_prefix': None,
#   'country_code': 'GD'},
#  {'id': '207104',
#   'username': 'fdean',
#   'name': 'Tammy Thompson',
#   'sex': None,
#   'country': 'Poland',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1964-02-04',
#   'name_prefix': None,
#   'country_code': 'PL'},
#  {'id': '2001253391',
#   'username': 'annafleming',
#   'name': None,
#   'sex': None,
#   'country': 'Andorra',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1986-01-22',
#   'name_prefix': None,
#   'country_code': 'AD'},
#  {'id': '2001074670',
#   'username': 'samantha01',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'luis78@yahoo.com',
#   'registered': None,
#   'birthdate': '1975-05-22',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2000172054',
#   'username': 'joshuafernandez',
#   'name': 'Lucas Flores',
#   'sex': None,
#   'country': 'Barbados',
#   'mail': 'hayesmelissa@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BB'},
#  {'id': '2759970',
#   'username': 'spetersen',
#   'name': None,
#   'sex': None,
#   'country': 'Holy See (Vatican City State)',
#   'mail': None,
#   'registered': '2012-05-24',
#   'birthdate': '1978-11-07',
#   'name_prefix': None,
#   'country_code': 'VA'},
#  {'id': '1762530',
#   'username': 'mholloway',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1963-04-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1802922978',
#   'username': 'ricejessica',
#   'name': 'Ariel Gilmore',
#   'sex': None,
#   'country': None,
#   'mail': 'hector88@yahoo.com',
#   'registered': '2004-01-18',
#   'birthdate': '2005-08-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1325841',
#   'username': 'crosscharles',
#   'name': 'Steven Miranda',
#   'sex': 'M',
#   'country': 'Saint Kitts and Nevis',
#   'mail': None,
#   'registered': '2001-11-23',
#   'birthdate': '1994-04-21',
#   'name_prefix': None,
#   'country_code': 'KN'},
#  {'id': '1138259',
#   'username': 'jsmith',
#   'name': 'Amber Harrington',
#   'sex': 'F',
#   'country': None,
#   'mail': 'ydiaz@hotmail.com',
#   'registered': None,
#   'birthdate': '2010-07-27',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  {'id': '2001867356',
#   'username': 'beth31',
#   'name': 'Devin Wilson',
#   'sex': None,
#   'country': None,
#   'mail': 'nperez@gmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '176234',
#   'username': 'luisjimenez',
#   'name': 'Mrs. Ashley Holland',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1950-03-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '295453',
#   'username': 'johnsonmelissa',
#   'name': 'Kimberly Collins',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jennifer92@hotmail.com',
#   'registered': None,
#   'birthdate': '1984-10-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '195966',
#   'username': 'iperez',
#   'name': 'Jasmine Wood',
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'mail': 'hbell@yahoo.com',
#   'registered': '2018-12-06',
#   'birthdate': '2017-03-24',
#   'name_prefix': 'Dr.',
#   'country_code': 'LA'},
#  {'id': '278020',
#   'username': 'clintoncarpenter',
#   'name': 'Christopher Bowen',
#   'sex': None,
#   'country': 'Egypt',
#   'mail': 'glennbutler@gmail.com',
#   'registered': '2005-12-26',
#   'birthdate': '2001-11-22',
#   'name_prefix': None,
#   'country_code': 'EG'},
#  {'id': '2001700146',
#   'username': 'troy70',
#   'name': None,
#   'sex': 'M',
#   'country': 'Marshall Islands',
#   'mail': 'leslie55@yahoo.com',
#   'registered': None,
#   'birthdate': '1952-09-18',
#   'name_prefix': 'Mr.',
#   'country_code': 'MH'},
#  {'id': '2770874',
#   'username': 'browncarla',
#   'name': 'Jaime Ray',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1965-10-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '13153793',
#   'username': 'collinsmichael',
#   'name': 'Douglas Morales',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2017-12-25',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1477683',
#   'username': 'kelly68',
#   'name': 'Scott Cooper',
#   'sex': None,
#   'country': 'Botswana',
#   'mail': None,
#   'registered': '2011-10-26',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'BW'},
#  {'id': '2001105370',
#   'username': 'linda06',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Helena',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1971-04-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '1082961',
#   'username': 'debra93',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Vincent and the Grenadines',
#   'mail': 'james92@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'VC'},
#  {'id': '1800027635',
#   'username': 'michael28',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2349333',
#   'username': 'castrojoseph',
#   'name': 'Manuel Price',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002203670',
#   'username': 'marissawolf',
#   'name': None,
#   'sex': None,
#   'country': 'El Salvador',
#   'mail': 'cgeorge@hotmail.com',
#   'registered': None,
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': 'SV'},
#  {'id': '553115',
#   'username': 'gleblanc',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'duncanadam@yahoo.com',
#   'registered': '2018-02-17',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  {'id': '2002106714',
#   'username': 'lisa38',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2003-11-16',
#   'birthdate': None,
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'id': '709872',
#   'username': 'hoffmanjulie',
#   'name': 'Anthony Ellis',
#   'sex': 'M',
#   'country': 'Taiwan',
#   'mail': None,
#   'registered': '2012-11-11',
#   'birthdate': '1960-01-18',
#   'name_prefix': None,
#   'country_code': 'TW'},
#  {'id': '2000332934',
#   'username': 'mcdowellteresa',
#   'name': 'Taylor Mejia',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2011-02-06',
#   'birthdate': None,
#   'name_prefix': None,
#   'country_code': None},
#  ...]

# %%
from dask import delayed
@delayed
def parse_reviewers_file(xml_file):
        with open(xml_file) as f:
            soup = BeautifulSoup(f, 'xml')
            reviewers = []
            for reviewer in soup.find_all("user"):
                reviewer_dict = {}
                    reviewer_dict['id'] = reviewer.find('id').text
                    reviewer_dict['username'] = reviewer.find('username').text if reviewer.find('username') else None
                    reviewer_dict['name'] = reviewer.find('name').text if reviewer.find('name') else None
                    reviewer_dict['sex'] = reviewer.find('sex').text if reviewer.find('sex') else None
                    reviewer_dict['country'] = reviewer.find('country').text if reviewer.find('country') else None
                    reviewer_dict['mail'] = reviewer.find('mail').text if reviewer.find('mail') else None
                    reviewer_dict['registered'] = reviewer.find('registered').text if reviewer.find('registered') else None
                    reviewer_dict['birthdate'] = reviewer.find('birthdate').text if reviewer.find('birthdate') else None
                    reviewer_dict['name_prefix'] = reviewer.get('prefix')
                    reviewer_dict['country_code'] = reviewer.find('country').get('code') if reviewer.find('country') else None
                    reviewers.append(reviewer_dict)
        return reviewers

def parse_reviewers_zip(zip_path):
    with zipfile.ZipFile(zip_path) as z:
        xml_files = [f for f in z.namelist() if 'reviewers_full/reviewers_full_' in f]
        tasks = [parse_reviewers_file(f) for f in xml_files]
        reviewers = dask.compute(*tasks, scheduler='multiprocessing')
        return reviewers

# %%
# %%time
parse_reviewers_zip("reviewers_full.zip")
# Out:
# Wall time: 4min 21s
# ([{'username': 'gabrielacalhoun',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'birthdate': '1988-01-25'},
#   {'username': 'qbaxter',
#    'country': 'Norway',
#    'country_code': 'NO',
#    'mail': 'qware@gmail.com',
#    'birthdate': '1985-01-19'},
#   {'username': 'crosschristopher',
#    'name': 'Dana Moore',
#    'mail': 'stephaniestrong@yahoo.com',
#    'registered': '2018-11-21',
#    'birthdate': '1955-07-03'},
#   {'username': 'karen27',
#    'name': 'Jennifer Horne',
#    'country': 'Cuba',
#    'country_code': 'CU',
#    'mail': 'wjarvis@yahoo.com',
#    'registered': '2013-11-20',
#    'birthdate': '2007-04-30'},
#   {'username': 'gambledanielle',
#    'name': 'Henry Harris',
#    'country': 'Serbia',
#    'country_code': 'RS',
#    'registered': '2011-04-08'},
#   {'username': 'smullen',
#    'name_prefix': 'Miss',
#    'name': 'Cynthia Johnson',
#    'sex': 'F',
#    'birthdate': '2005-03-29'},
#   {'username': 'barrettmichael',
#    'name': 'Margaret Banks',
#    'mail': 'christinaday@hotmail.com',
#    'birthdate': '1971-11-15'},
#   {'username': 'morrischarles',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Zambia',
#    'country_code': 'ZM',
#    'registered': '2014-09-28'},
#   {'username': 'osalazar',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'justintyler@hotmail.com',
#    'registered': '2009-08-02'},
#   {'username': 'juanmontoya',
#    'sex': 'M',
#    'country': 'Aruba',
#    'country_code': 'AW',
#    'registered': '2016-07-16'},
#   {'username': 'villanuevafrank',
#    'name': 'Patrick Campos',
#    'country': 'Malaysia',
#    'country_code': 'MY',
#    'mail': 'stephanieshaw@gmail.com'},
#   {'username': 'amorales',
#    'sex': 'M',
#    'country': 'Dominican Republic',
#    'country_code': 'DO',
#    'mail': 'briannatrujillo@gmail.com',
#    'registered': '2004-11-24'},
#   {'username': 'josephrush',
#    'country': 'Guam',
#    'country_code': 'GU',
#    'registered': '2015-07-18',
#    'birthdate': '1976-07-05'},
#   {'username': 'gwheeler',
#    'sex': 'M',
#    'country': 'Solomon Islands',
#    'country_code': 'SB',
#    'mail': 'javery@hotmail.com'},
#   {'username': 'hughesabigail',
#    'name': 'Eric Garcia',
#    'mail': 'deborah17@yahoo.com',
#    'registered': '2006-04-02'},
#   {'username': 'ashleygrimes',
#    'name': 'Rebecca Bowers',
#    'country': 'Montserrat',
#    'country_code': 'MS',
#    'registered': '2001-08-26'},
#   {'username': 'george76',
#    'name_prefix': 'Mr.',
#    'name': 'Gregory Watts',
#    'sex': 'M'},
#   {'username': 'franklinhancock',
#    'name': 'Michele Richards',
#    'country': 'Namibia',
#    'country_code': 'nan',
#    'mail': 'claudiamccoy@gmail.com',
#    'registered': '2009-08-12',
#    'birthdate': '1983-02-20'},
#   {'username': 'jennifer31',
#    'name': 'Amber Martin',
#    'sex': 'F',
#    'mail': 'austin68@yahoo.com'},
#   {'username': 'alisonbell',
#    'sex': 'F',
#    'mail': 'micheal05@hotmail.com',
#    'registered': '2008-10-25'},
#   {'username': 'lisa10',
#    'sex': 'M',
#    'country': 'American Samoa',
#    'country_code': 'AS',
#    'mail': 'newtonalexander@hotmail.com'},
#   {'username': 'lovepeter',
#    'sex': 'M',
#    'country': 'Sierra Leone',
#    'country_code': 'SL',
#    'registered': '2006-09-26'},
#   {'username': 'amy93', 'name': 'Patricia Fox', 'mail': 'wbrooks@hotmail.com'},
#   {'username': 'fkhan',
#    'name_prefix': 'Dr.',
#    'sex': 'F',
#    'country': 'Kazakhstan',
#    'country_code': 'KZ',
#    'registered': '2009-02-10'},
#   {'username': 'cdavis',
#    'country': 'Qatar',
#    'country_code': 'QA',
#    'birthdate': '2015-09-29'},
#   {'username': 'ronaldgrimes',
#    'name_prefix': 'Mrs.',
#    'name': 'Rita Hodge',
#    'sex': 'F',
#    'registered': '2003-07-03',
#    'birthdate': '1996-02-07'},
#   {'username': 'shannonbender',
#    'name': 'Sandy Morales',
#    'sex': 'F',
#    'country': 'Yemen',
#    'country_code': 'YE',
#    'registered': '2019-06-23',
#    'birthdate': '2009-04-21'},
#   {'username': 'christinapeterson',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'mail': 'rwoods@hotmail.com',
#    'registered': '2009-04-15'},
#   {'username': 'elizabethvaldez',
#    'name': 'Heather Jones',
#    'birthdate': '1966-04-21'},
#   {'username': 'caseyjustin',
#    'name': 'Jose Taylor',
#    'mail': 'garretthaley@yahoo.com',
#    'registered': '2012-08-22',
#    'birthdate': '2017-12-20'},
#   {'username': 'williamsonjacqueline',
#    'name': 'Edward Norton',
#    'sex': 'M',
#    'country': 'Mexico',
#    'country_code': 'MX',
#    'mail': 'katrina72@yahoo.com'},
#   {'username': 'dtaylor',
#    'country': 'Andorra',
#    'country_code': 'AD',
#    'mail': 'schaefercharles@hotmail.com',
#    'birthdate': '2001-12-30'},
#   {'username': 'christian74',
#    'name_prefix': 'Dr.',
#    'name': 'Danielle Webster',
#    'sex': 'F',
#    'birthdate': '1984-04-14'},
#   {'username': 'christinegomez',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'country': 'Netherlands',
#    'country_code': 'NL',
#    'mail': 'xcrosby@yahoo.com',
#    'registered': '2016-07-01',
#    'birthdate': '1986-11-29'},
#   {'username': 'hwoods',
#    'name': 'Nichole Maynard',
#    'sex': 'F',
#    'mail': 'jamesgalloway@hotmail.com',
#    'birthdate': '1990-01-03'},
#   {'username': 'longjacob',
#    'country': 'Costa Rica',
#    'country_code': 'CR',
#    'mail': 'brittney36@yahoo.com'},
#   {'username': 'zrodgers',
#    'name': 'Angelica Mcfarland',
#    'country': 'United Arab Emirates',
#    'country_code': 'AE',
#    'mail': 'coreyparker@hotmail.com',
#    'registered': '2017-07-18',
#    'birthdate': '1955-01-13'},
#   {'username': 'elizabeth00',
#    'name': 'Edward Harper',
#    'mail': 'vrojas@hotmail.com'},
#   {'username': 'jenna30',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'country': 'Anguilla',
#    'country_code': 'AI',
#    'birthdate': '1996-09-04'},
#   {'username': 'gallen',
#    'country': 'Turkey',
#    'country_code': 'TR',
#    'mail': 'charlesholland@yahoo.com',
#    'registered': '2016-01-13',
#    'birthdate': '1963-11-29'},
#   {'username': 'stacykelly',
#    'name': 'Victor Owens',
#    'sex': 'M',
#    'country': 'Haiti',
#    'country_code': 'HT',
#    'mail': 'imccoy@yahoo.com',
#    'birthdate': '1955-06-20'},
#   {'username': 'beckricardo', 'registered': '2007-07-14'},
#   {'username': 'kristenchang',
#    'name': 'Ryan Washington',
#    'sex': 'M',
#    'country': 'Ethiopia',
#    'country_code': 'ET'},
#   {'username': 'abaldwin',
#    'mail': 'bridgesjanet@yahoo.com',
#    'registered': '2017-06-13'},
#   {'username': 'robert57',
#    'sex': 'M',
#    'country': 'Qatar',
#    'country_code': 'QA',
#    'registered': '2008-09-19',
#    'birthdate': '2020-03-28'},
#   {'username': 'rosebrooke',
#    'name': 'Nathan Evans',
#    'sex': 'M',
#    'mail': 'collinsbrittany@hotmail.com',
#    'registered': '2010-02-19'},
#   {'username': 'roberthoward',
#    'name_prefix': 'Dr.',
#    'name': 'John Schaefer',
#    'sex': 'M',
#    'mail': 'connieyang@yahoo.com',
#    'registered': '2014-05-09',
#    'birthdate': '2004-09-01'},
#   {'username': 'kristygreen'},
#   {'username': 'lorigreen',
#    'name_prefix': 'Dr.',
#    'name': 'Edward Clark',
#    'sex': 'M',
#    'mail': 'eallen@gmail.com'},
#   {'username': 'tyler05', 'mail': 'michael31@gmail.com'},
#   {'username': 'rturner',
#    'name_prefix': 'Dr.',
#    'name': 'Jason Williams',
#    'sex': 'M',
#    'country': 'Costa Rica',
#    'country_code': 'CR',
#    'registered': '2008-01-28'},
#   {'username': 'bryanfrazier',
#    'country': 'Kazakhstan',
#    'country_code': 'KZ',
#    'registered': '2011-02-01'},
#   {'username': 'katherinemays', 'birthdate': '1987-11-22'},
#   {'username': 'sheena36',
#    'sex': 'F',
#    'country': 'Mali',
#    'country_code': 'ML',
#    'mail': 'garzajill@hotmail.com',
#    'birthdate': '1965-05-06'},
#   {'username': 'mramos',
#    'name': 'Laura Cooper',
#    'mail': 'chavezsydney@hotmail.com',
#    'registered': '2014-08-16'},
#   {'username': 'ocarey',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'registered': '2017-02-14'},
#   {'username': 'clarkjennifer',
#    'country': 'Austria',
#    'country_code': 'AT',
#    'birthdate': '2001-08-26'},
#   {'username': 'johnsonrachel',
#    'sex': 'F',
#    'mail': 'oschwartz@gmail.com',
#    'registered': '2001-05-03'},
#   {'username': 'jasmine70',
#    'name': 'Megan Powell',
#    'mail': 'bphillips@hotmail.com'},
#   {'username': 'susanhoward',
#    'mail': 'michaelhernandez@gmail.com',
#    'birthdate': '1986-10-09'},
#   {'username': 'laurenjohnson',
#    'sex': 'M',
#    'mail': 'derrick15@hotmail.com',
#    'birthdate': '1995-12-07'},
#   {'username': 'williambrooks',
#    'registered': '2017-09-23',
#    'birthdate': '2004-03-15'},
#   {'username': 'carolyn39', 'sex': 'M', 'birthdate': '2009-05-25'},
#   {'username': 'shawmiranda',
#    'name_prefix': 'Mrs.',
#    'name': 'Tara Chambers',
#    'sex': 'F',
#    'mail': 'biancamartin@hotmail.com',
#    'registered': '2018-08-07'},
#   {'username': 'bvance', 'name_prefix': 'Mr.', 'sex': 'M'},
#   {'username': 'rodriguezstacey',
#    'sex': 'M',
#    'country': 'Ukraine',
#    'country_code': 'UA',
#    'mail': 'patrick12@yahoo.com'},
#   {'username': 'pwatts', 'name': 'Tasha Kennedy', 'birthdate': '2008-08-03'},
#   {'username': 'christopher55', 'mail': 'michael57@gmail.com'},
#   {'username': 'johnstontimothy',
#    'name': 'Mark Drake',
#    'sex': 'M',
#    'registered': '2009-11-03',
#    'birthdate': '1971-10-15'},
#   {'username': 'davidmckenzie',
#    'country': 'Isle of Man',
#    'country_code': 'IM'},
#   {'username': 'pdean',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Barbados',
#    'country_code': 'BB',
#    'mail': 'janet77@hotmail.com',
#    'birthdate': '1993-02-05'},
#   {'username': 'baileyrobert',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Czech Republic',
#    'country_code': 'CZ',
#    'registered': '2008-01-03'},
#   {'username': 'stephaniestevens',
#    'country': 'Antarctica (the territory South of 60 deg S)',
#    'registered': '2008-10-02'},
#   {'username': 'hunttrevor',
#    'name': 'Amber Bush',
#    'sex': 'F',
#    'country': 'Gambia',
#    'country_code': 'GM'},
#   {'username': 'heatheric',
#    'name': 'Michael Bentley',
#    'country': 'Svalbard & Jan Mayen Islands',
#    'registered': '2016-12-28',
#    'birthdate': '1998-12-21'},
#   {'username': 'jwhite',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Estonia',
#    'country_code': 'EE',
#    'registered': '2002-07-05',
#    'birthdate': '1950-08-26'},
#   {'username': 'james34', 'country': 'Uganda', 'country_code': 'UG'},
#   {'username': 'frankflores',
#    'name': 'Adam Contreras',
#    'mail': 'joneschristopher@yahoo.com',
#    'birthdate': '1977-10-23'},
#   {'username': 'nfitzgerald',
#    'name': 'Tiffany Hamilton',
#    'birthdate': '2016-02-19'},
#   {'username': 'norma44',
#    'name_prefix': 'Ms.',
#    'sex': 'F',
#    'registered': '2017-08-23',
#    'birthdate': '1982-05-08'},
#   {'username': 'audrey28',
#    'name_prefix': 'Mrs.',
#    'name': 'Jamie Harris',
#    'sex': 'F',
#    'mail': 'michelle59@hotmail.com',
#    'registered': '2018-01-03',
#    'birthdate': '2003-08-01'},
#   {'username': 'simsdan',
#    'name_prefix': 'Mr.',
#    'name': 'Andrew Phillips',
#    'sex': 'M',
#    'registered': '2018-10-29',
#    'birthdate': '2009-03-31'},
#   {'username': 'jsantana',
#    'name': 'Ian Valencia',
#    'sex': 'M',
#    'country': 'Oman',
#    'country_code': 'OM',
#    'mail': 'romeronicholas@gmail.com',
#    'registered': '2018-11-08'},
#   {'username': 'ptaylor',
#    'sex': 'F',
#    'country': 'United Kingdom',
#    'country_code': 'GB',
#    'mail': 'rcarr@gmail.com',
#    'registered': '2010-06-05',
#    'birthdate': '1958-09-05'},
#   {'username': 'hparker', 'name': 'Brian Gentry'},
#   {'username': 'dbarnett',
#    'name_prefix': 'Dr.',
#    'name': 'Stacey Gallagher',
#    'sex': 'F',
#    'country': 'Nepal',
#    'country_code': 'NP'},
#   {'username': 'mallory07',
#    'name': 'Matthew Farrell',
#    'country': 'Somalia',
#    'country_code': 'SO',
#    'registered': '2002-07-17'},
#   {'username': 'williamhorn',
#    'name_prefix': 'Mr.',
#    'name': 'Stephen Franco',
#    'sex': 'M',
#    'country': 'Liechtenstein',
#    'country_code': 'LI',
#    'mail': 'jeffreyfreeman@gmail.com',
#    'registered': '2011-09-16',
#    'birthdate': '2021-05-28'},
#   {'username': 'woodsroy',
#    'sex': 'M',
#    'mail': 'fsmith@gmail.com',
#    'registered': '2019-10-30'},
#   {'username': 'kaylarobinson', 'registered': '2005-07-29'},
#   {'username': 'karengutierrez',
#    'name_prefix': 'Dr.',
#    'sex': 'F',
#    'country': 'Saint Barthelemy',
#    'mail': 'rhonda94@hotmail.com',
#    'registered': '2004-10-12',
#    'birthdate': '1979-04-15'},
#   {'username': 'nreese', 'country': 'Pitcairn Islands'},
#   {'username': 'pfox',
#    'name': 'Amy Conley',
#    'sex': 'F',
#    'registered': '2016-09-03'},
#   {'username': 'aaron85', 'name': 'Katie Miller', 'birthdate': '2018-08-08'},
#   {'username': 'zmontes',
#    'name': 'Michelle Chapman',
#    'sex': 'F',
#    'country': 'Bermuda',
#    'country_code': 'BM',
#    'mail': 'lisa40@hotmail.com',
#    'birthdate': '2005-10-29'},
#   {'username': 'katherinelopez',
#    'country': 'Indonesia',
#    'country_code': 'ID',
#    'registered': '2016-03-03',
#    'birthdate': '2009-05-31'},
#   {'username': 'travis31',
#    'country': 'Slovakia (Slovak Republic)',
#    'registered': '2013-07-13'},
#   {'username': 'matthew57',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Norfolk Island',
#    'country_code': 'NF',
#    'mail': 'johnbenton@gmail.com',
#    'birthdate': '1968-08-14'},
#   {'username': 'amyadkins',
#    'name': 'Kim Kelly',
#    'country': 'Uruguay',
#    'country_code': 'UY',
#    'registered': '2012-10-11'},
#   {'username': 'dunnamanda',
#    'name': 'Yolanda Bailey',
#    'sex': 'F',
#    'country': 'Swaziland',
#    'country_code': 'SZ',
#    'birthdate': '1957-11-20'},
#   {'username': 'jnichols',
#    'name': 'George Green',
#    'sex': 'M',
#    'registered': '2006-11-21',
#    'birthdate': '1950-01-19'},
#   {'username': 'mejiashannon',
#    'name_prefix': 'Dr.',
#    'name': 'Chelsea Ortega',
#    'sex': 'F',
#    'mail': 'bentonbryan@gmail.com'},
#   {'username': 'andersonlaura',
#    'name': 'Scott Clay',
#    'country': 'Saint Martin',
#    'country_code': 'MF',
#    'mail': 'thaynes@yahoo.com'},
#   {'username': 'david09',
#    'sex': 'F',
#    'country': 'United States Minor Outlying Islands',
#    'country_code': 'UM',
#    'registered': '2005-05-03'},
#   {'username': 'sean85',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Haiti',
#    'country_code': 'HT',
#    'mail': 'stephaniebradley@yahoo.com'},
#   {'username': 'jennifercarter',
#    'name': 'Brittany Smith',
#    'country': 'Djibouti',
#    'country_code': 'DJ',
#    'birthdate': '1989-08-20'},
#   {'username': 'coltoncarter',
#    'mail': 'donnamurphy@yahoo.com',
#    'registered': '2003-02-14',
#    'birthdate': '1993-08-28'},
#   {'username': 'obuckley',
#    'name': 'Audrey Russell',
#    'mail': 'christopher36@hotmail.com',
#    'registered': '2001-02-25',
#    'birthdate': '1967-01-24'},
#   {'username': 'amy70', 'sex': 'F', 'birthdate': '1996-05-17'},
#   {'username': 'cvillarreal',
#    'name': 'Jose Shea',
#    'mail': 'mark86@yahoo.com',
#    'birthdate': '2021-07-09'},
#   {'username': 'rhonda49',
#    'mail': 'james36@gmail.com',
#    'registered': '2017-01-06',
#    'birthdate': '1961-01-24'},
#   {'username': 'mitchellabigail', 'country': 'Ireland', 'country_code': 'IE'},
#   {'username': 'matthewsmelissa',
#    'name_prefix': 'Mrs.',
#    'name': 'Michelle Mathews',
#    'sex': 'F',
#    'mail': 'bbaker@gmail.com',
#    'birthdate': '1999-02-23'},
#   {'username': 'nataliecarroll',
#    'name': 'Ricardo Schroeder',
#    'mail': 'rmccarty@hotmail.com',
#    'registered': '2019-01-02',
#    'birthdate': '1978-09-17'},
#   {'username': 'zperez',
#    'name': 'Amber Fisher',
#    'sex': 'F',
#    'mail': 'racheljarvis@gmail.com',
#    'birthdate': '1977-10-31'},
#   {'username': 'erodriguez',
#    'country': 'Spain',
#    'country_code': 'ES',
#    'registered': '2018-02-09'},
#   {'username': 'youngoscar',
#    'name_prefix': 'Mrs.',
#    'name': 'Kayla Moreno',
#    'sex': 'F',
#    'country': 'Cape Verde',
#    'country_code': 'CV',
#    'registered': '2009-11-27',
#    'birthdate': '2001-01-03'},
#   {'username': 'josewagner', 'name_prefix': 'Dr.', 'sex': 'M'},
#   {'username': 'montgomeryanthony',
#    'mail': 'jsolis@hotmail.com',
#    'birthdate': '2016-08-26'},
#   {'username': 'mfischer',
#    'name': 'Craig Barnes',
#    'sex': 'M',
#    'mail': 'stephenwheeler@yahoo.com',
#    'registered': '2015-02-15'},
#   {'username': 'toddherrera',
#    'name': 'Nicholas King',
#    'country': 'India',
#    'country_code': 'IN'},
#   {'username': 'eroberts',
#    'country': 'Hungary',
#    'country_code': 'HU',
#    'registered': '2006-12-20'},
#   {'username': 'johnsonjennifer', 'mail': 'belinda89@yahoo.com'},
#   {'username': 'susan32',
#    'name': 'Heather Wilson',
#    'country': 'Northern Mariana Islands',
#    'country_code': 'MP',
#    'mail': 'yschultz@yahoo.com',
#    'registered': '2003-10-12',
#    'birthdate': '1969-07-20'},
#   {'username': 'eric60', 'name': 'Anthony Perkins', 'birthdate': '1967-12-19'},
#   {'username': 'batesmichael',
#    'country': 'Cook Islands',
#    'country_code': 'CK',
#    'mail': 'johnbennett@yahoo.com',
#    'registered': '2008-02-18',
#    'birthdate': '1996-01-25'},
#   {'username': 'kristin82', 'registered': '2017-09-30'},
#   {'username': 'justinlong',
#    'name': 'Jason Rasmussen',
#    'mail': 'jeffrey59@gmail.com',
#    'registered': '2011-09-30'},
#   {'username': 'kennethgregory',
#    'name': 'Melissa Frank',
#    'country': 'Uzbekistan',
#    'country_code': 'UZ',
#    'mail': 'hunter46@yahoo.com',
#    'birthdate': '1995-06-08'},
#   {'username': 'brichard',
#    'mail': 'shellyalvarado@gmail.com',
#    'registered': '2007-03-31',
#    'birthdate': '1976-02-08'},
#   {'username': 'james18',
#    'sex': 'F',
#    'mail': 'alex28@gmail.com',
#    'registered': '2015-08-08'},
#   {'username': 'dillon44',
#    'name': 'Julie Pena',
#    'country': 'Botswana',
#    'country_code': 'BW',
#    'registered': '2007-08-11'},
#   {'username': 'harrisroger',
#    'name': 'Timothy Jones',
#    'sex': 'M',
#    'country': 'Isle of Man',
#    'country_code': 'IM',
#    'registered': '2008-08-18'},
#   {'username': 'paul76',
#    'name_prefix': 'Mr.',
#    'name': 'Vincent Baker',
#    'sex': 'M',
#    'birthdate': '1977-04-23'},
#   {'username': 'francesburke',
#    'name_prefix': 'Dr.',
#    'name': 'Shawn Meyers',
#    'sex': 'M',
#    'country': 'Papua New Guinea',
#    'country_code': 'PG',
#    'mail': 'juliebailey@yahoo.com',
#    'registered': '2011-09-01',
#    'birthdate': '1968-12-09'},
#   {'username': 'stephen62',
#    'country': 'Lithuania',
#    'country_code': 'LT',
#    'mail': 'samuel54@gmail.com'},
#   {'username': 'katherine86',
#    'mail': 'matthew84@yahoo.com',
#    'birthdate': '1960-01-20'},
#   {'username': 'sarahmiller', 'mail': 'salazaranthony@yahoo.com'},
#   {'username': 'lunaashley', 'birthdate': '2019-12-02'},
#   {'username': 'gmorrow',
#    'sex': 'M',
#    'mail': 'brownjoseph@gmail.com',
#    'registered': '2014-05-14',
#    'birthdate': '1988-01-17'},
#   {'username': 'barnesmichael',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Cameroon',
#    'country_code': 'CM',
#    'mail': 'samuelbarnes@hotmail.com',
#    'birthdate': '1978-10-23'},
#   {'username': 'williamayala', 'name': 'Casey Sullivan', 'sex': 'F'},
#   {'username': 'jerry48',
#    'name': 'David Schneider',
#    'mail': 'hullmichelle@gmail.com',
#    'registered': '2010-01-02'},
#   {'username': 'hernandezhector', 'registered': '2016-11-20'},
#   {'username': 'amber17',
#    'name_prefix': 'Dr.',
#    'name': 'Keith Tran',
#    'sex': 'M',
#    'country': 'French Guiana',
#    'country_code': 'GF',
#    'birthdate': '1951-06-05'},
#   {'username': 'andrew19',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'registered': '2001-12-09'},
#   {'username': 'michelledouglas',
#    'name': 'Cameron Fuller',
#    'sex': 'M',
#    'registered': '2010-01-09'},
#   {'username': 'manthony',
#    'sex': 'M',
#    'country': 'Guyana',
#    'country_code': 'GY',
#    'registered': '2011-01-07',
#    'birthdate': '1963-07-30'},
#   {'username': 'ipope',
#    'country': 'Germany',
#    'country_code': 'DE',
#    'birthdate': '1956-05-12'},
#   {'username': 'sean83',
#    'country': 'Bermuda',
#    'country_code': 'BM',
#    'mail': 'robert33@gmail.com',
#    'birthdate': '1958-11-25'},
#   {'username': 'raymondcharles',
#    'name_prefix': 'Mr.',
#    'name': 'Robert Martin',
#    'sex': 'M',
#    'country': 'Paraguay',
#    'country_code': 'PY',
#    'registered': '2011-01-13'},
#   {'username': 'powerssteven', 'mail': 'jamesfernandez@yahoo.com'},
#   {'username': 'williamgarcia',
#    'name_prefix': 'Mrs.',
#    'name': 'Margaret Lopez',
#    'sex': 'F',
#    'mail': 'jenningsamy@hotmail.com',
#    'birthdate': '1988-03-19'},
#   {'username': 'bking',
#    'country': 'Niue',
#    'country_code': 'NU',
#    'mail': 'xjones@gmail.com',
#    'birthdate': '2019-03-26'},
#   {'username': 'vcox',
#    'name': 'Cynthia Henderson PhD',
#    'sex': 'F',
#    'country': 'Liechtenstein',
#    'country_code': 'LI',
#    'registered': '2015-07-10',
#    'birthdate': '1954-05-16'},
#   {'username': 'nsweeney',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'country': 'French Southern Territories',
#    'country_code': 'TF',
#    'mail': 'edwardgay@hotmail.com'},
#   {'username': 'ahurst',
#    'registered': '2012-05-12',
#    'birthdate': '2011-04-08'},
#   {'username': 'davidgraham',
#    'name': 'Walter Mayer',
#    'sex': 'M',
#    'mail': 'blake27@hotmail.com',
#    'birthdate': '1959-04-01'},
#   {'username': 'barbara83',
#    'name_prefix': 'Mr.',
#    'name': 'Daniel Blair',
#    'sex': 'M',
#    'country': 'Saint Helena',
#    'mail': 'danielle55@gmail.com',
#    'registered': '2011-05-05'},
#   {'username': 'kmiller',
#    'name_prefix': 'Mrs.',
#    'name': 'Melissa Morrison',
#    'sex': 'F',
#    'country': 'Comoros',
#    'country_code': 'KM',
#    'mail': 'josephmiller@hotmail.com',
#    'registered': '2010-02-05'},
#   {'username': 'heidi86',
#    'name': 'Anthony Carson',
#    'country': 'United States Virgin Islands',
#    'registered': '2018-08-25'},
#   {'username': 'sara99',
#    'name_prefix': 'Mr.',
#    'name': 'Ralph Hunt',
#    'sex': 'M',
#    'registered': '2008-09-10'},
#   {'username': 'collin85',
#    'registered': '2009-04-13',
#    'birthdate': '2014-01-17'},
#   {'username': 'parkerrichard',
#    'sex': 'M',
#    'mail': 'tonyabenjamin@gmail.com',
#    'birthdate': '1962-10-28'},
#   {'username': 'feliciahenry',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Greece',
#    'country_code': 'GR',
#    'registered': '2013-05-24',
#    'birthdate': '2018-11-21'},
#   {'username': 'hboyle',
#    'country': 'Norway',
#    'country_code': 'NO',
#    'birthdate': '1953-01-08'},
#   {'username': 'michaelcraig',
#    'name_prefix': 'Ms.',
#    'name': 'Victoria Graham',
#    'sex': 'F',
#    'registered': '2013-12-12'},
#   {'username': 'vhopkins',
#    'mail': 'jonathon51@yahoo.com',
#    'registered': '2012-05-11'},
#   {'username': 'rogerstina',
#    'name': 'Caitlin West',
#    'country': 'Colombia',
#    'country_code': 'CO',
#    'mail': 'edwardhenry@gmail.com'},
#   {'username': 'pateljennifer',
#    'country': 'Mexico',
#    'country_code': 'MX',
#    'registered': '2017-02-03',
#    'birthdate': '2013-02-02'},
#   {'username': 'nicolelong',
#    'name_prefix': 'Mr.',
#    'name': 'Colin Mccarty',
#    'sex': 'M',
#    'country': 'Bouvet Island (Bouvetoya)',
#    'mail': 'amandamonroe@yahoo.com',
#    'registered': '2019-05-18'},
#   {'username': 'christydavis',
#    'sex': 'M',
#    'mail': 'huntangela@hotmail.com',
#    'registered': '2012-05-26',
#    'birthdate': '1995-06-14'},
#   {'username': 'johnwright',
#    'country': 'Iraq',
#    'country_code': 'IQ',
#    'birthdate': '1994-10-04'},
#   {'username': 'davidsonalexander',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'mark13@gmail.com'},
#   {'username': 'sblack', 'name': 'Dakota Reyes'},
#   {'username': 'jerry71',
#    'country': 'Sao Tome and Principe',
#    'country_code': 'ST',
#    'mail': 'rbridges@yahoo.com',
#    'registered': '2015-04-18',
#    'birthdate': '1971-11-08'},
#   {'username': 'theodore44',
#    'name': 'Samantha Harris',
#    'sex': 'F',
#    'country': 'Jamaica',
#    'country_code': 'JM',
#    'registered': '2013-05-19'},
#   {'username': 'hernandezzachary',
#    'name_prefix': 'Mrs.',
#    'name': 'Brenda Williams',
#    'sex': 'F',
#    'country': 'Holy See (Vatican City State)',
#    'country_code': 'VA',
#    'mail': 'morrisongail@hotmail.com',
#    'registered': '2002-02-11',
#    'birthdate': '1995-07-30'},
#   {'username': 'nconley',
#    'name': 'Ronald Henry',
#    'mail': 'lewiswilliam@hotmail.com',
#    'registered': '2019-08-22'},
#   {'username': 'charles22',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'country': 'Heard Island and McDonald Islands',
#    'country_code': 'HM',
#    'registered': '2008-11-23',
#    'birthdate': '1983-07-06'},
#   {'username': 'sharonmichael',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'mail': 'jonathangardner@yahoo.com'},
#   {'username': 'renee37',
#    'name_prefix': 'Dr.',
#    'name': 'Rachel Johnson',
#    'sex': 'F',
#    'registered': '2012-02-24'},
#   {'username': 'ujones', 'mail': 'ggray@hotmail.com'},
#   {'username': 'webbsamuel', 'name_prefix': 'Dr.', 'sex': 'F'},
#   {'username': 'martinezamber',
#    'country': 'New Caledonia',
#    'country_code': 'NC',
#    'mail': 'ggonzalez@gmail.com',
#    'registered': '2007-06-22'},
#   {'username': 'kayla45',
#    'country': 'France',
#    'country_code': 'FR',
#    'mail': 'cheryl23@yahoo.com'},
#   {'username': 'smiller',
#    'name_prefix': 'Mr.',
#    'name': 'Zachary Hickman',
#    'sex': 'M',
#    'registered': '2016-11-21'},
#   {'username': 'elizabeth05', 'country': 'Uruguay', 'country_code': 'UY'},
#   {'username': 'hgreen',
#    'name_prefix': 'Miss',
#    'name': 'Lisa Pruitt',
#    'sex': 'F',
#    'country': 'Qatar',
#    'country_code': 'QA',
#    'mail': 'hudsonsusan@hotmail.com',
#    'registered': '2001-07-13'},
#   {'username': 'burgesschristopher',
#    'name': 'Natalie Harrell',
#    'birthdate': '2019-02-03'},
#   {'username': 'kara39',
#    'country': 'Eritrea',
#    'country_code': 'ER',
#    'mail': 'myersmary@yahoo.com',
#    'registered': '2018-08-23'},
#   {'username': 'chelseaali',
#    'name': 'William Wang',
#    'sex': 'M',
#    'mail': 'clintonmccormick@yahoo.com'},
#   {'username': 'greeneshannon',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'yvette19@yahoo.com',
#    'registered': '2007-01-28',
#    'birthdate': '2004-10-19'},
#   {'username': 'johnsonbrandon',
#    'sex': 'M',
#    'country': 'Guyana',
#    'country_code': 'GY',
#    'birthdate': '2021-02-27'},
#   {'username': 'marksmith',
#    'name_prefix': 'Mrs.',
#    'name': 'Kristen Thomas',
#    'sex': 'F',
#    'country': 'Lebanon',
#    'country_code': 'LB',
#    'birthdate': '1950-11-20'},
#   {'username': 'pnavarro',
#    'name_prefix': 'Mr.',
#    'name': 'Evan Elliott',
#    'sex': 'M',
#    'mail': 'jrussell@yahoo.com',
#    'registered': '2010-02-13',
#    'birthdate': '1991-09-04'},
#   {'username': 'gina76',
#    'mail': 'stephenskatherine@gmail.com',
#    'birthdate': '1980-01-21'},
#   {'username': 'rasmussencarrie', 'sex': 'M', 'registered': '2006-01-09'},
#   {'username': 'michealjones',
#    'name': 'Kristina Barnes',
#    'country': 'Sri Lanka',
#    'country_code': 'LK'},
#   {'username': 'george64',
#    'name_prefix': 'Mr.',
#    'name': 'George Mcbride',
#    'sex': 'M',
#    'country': 'Ghana',
#    'country_code': 'GH',
#    'birthdate': '1968-08-23'},
#   {'username': 'icox',
#    'name_prefix': 'Mr.',
#    'name': 'Justin Smith',
#    'sex': 'M',
#    'registered': '2012-04-05',
#    'birthdate': '1985-05-20'},
#   {'username': 'hollandrobert',
#    'country': 'Liberia',
#    'country_code': 'LR',
#    'mail': 'anita08@yahoo.com',
#    'birthdate': '2011-04-30'},
#   {'username': 'vterrell', 'birthdate': '1971-12-26'},
#   {'username': 'tamara09',
#    'name_prefix': 'Dr.',
#    'name': 'Carol Stone',
#    'sex': 'F',
#    'country': 'Saint Helena',
#    'mail': 'greenashley@yahoo.com',
#    'birthdate': '1981-04-12'},
#   {'username': 'melaniejensen',
#    'mail': 'amandajenkins@yahoo.com',
#    'registered': '2019-11-26'},
#   {'username': 'meltonmary',
#    'name': 'Russell Brown',
#    'country': 'Uzbekistan',
#    'country_code': 'UZ',
#    'mail': 'eric40@gmail.com'},
#   {'username': 'qlopez',
#    'name_prefix': 'Miss',
#    'name': 'Hannah Brown',
#    'sex': 'F',
#    'country': 'Cape Verde',
#    'country_code': 'CV',
#    'mail': 'gbutler@hotmail.com',
#    'birthdate': '1979-08-01'},
#   {'username': 'amandafox',
#    'name': 'Leslie Lewis',
#    'sex': 'F',
#    'birthdate': '2000-05-26'},
#   {'username': 'debbiewhite',
#    'sex': 'F',
#    'mail': 'ldavis@yahoo.com',
#    'registered': '2011-05-09'},
#   {'username': 'kelleysherri',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'brownfelicia@yahoo.com',
#    'registered': '2004-11-09',
#    'birthdate': '1961-05-14'},
#   {'username': 'zgreen',
#    'sex': 'M',
#    'country': 'Bhutan',
#    'country_code': 'BT',
#    'registered': '2006-12-19',
#    'birthdate': '2009-08-07'},
#   {'username': 'jill67',
#    'country': 'South Africa',
#    'country_code': 'ZA',
#    'registered': '2001-02-27'},
#   {'username': 'jesusbrown',
#    'name': 'Lisa Burgess',
#    'country': 'Zimbabwe',
#    'country_code': 'ZW',
#    'mail': 'ayersbrooke@yahoo.com'},
#   {'username': 'kelly99',
#    'country': 'Dominica',
#    'country_code': 'DM',
#    'mail': 'cabrerajames@yahoo.com'},
#   {'username': 'kpayne',
#    'name': 'Brian Cain',
#    'sex': 'M',
#    'mail': 'faith12@hotmail.com',
#    'birthdate': '1971-09-22'},
#   {'username': 'perezlaura',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'registered': '2019-07-28',
#    'birthdate': '1999-11-04'},
#   {'username': 'knightdeanna',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'ortizisabel@gmail.com',
#    'registered': '2013-06-11',
#    'birthdate': '1969-07-07'},
#   {'username': 'eburke',
#    'mail': 'vgibbs@hotmail.com',
#    'birthdate': '2017-07-13'},
#   {'username': 'sherrymiller',
#    'name': 'Andrew Berg',
#    'country': 'Bahrain',
#    'country_code': 'BH',
#    'registered': '2011-04-23',
#    'birthdate': '1996-12-10'},
#   {'username': 'richardbell',
#    'name': 'Mr. James Mclean DDS',
#    'sex': 'M',
#    'mail': 'martinezchristopher@gmail.com'},
#   {'username': 'martinezkendra',
#    'name': 'David Morrison',
#    'country': 'Tokelau',
#    'country_code': 'TK',
#    'mail': 'thomasthomas@yahoo.com',
#    'registered': '2003-07-20',
#    'birthdate': '2017-12-08'},
#   {'username': 'johnny87', 'name': 'Allen Oconnell'},
#   {'username': 'devin80',
#    'name': 'Nancy Mcintosh',
#    'country': 'Croatia',
#    'country_code': 'HR',
#    'mail': 'kristymartin@yahoo.com',
#    'registered': '2010-11-16'},
#   {'username': 'dtaylor',
#    'name': 'Karen Clay',
#    'mail': 'chapmanaudrey@gmail.com',
#    'registered': '2011-02-24'},
#   {'username': 'joshuamunoz',
#    'name_prefix': 'Dr.',
#    'name': 'Bobby Cohen',
#    'sex': 'M',
#    'mail': 'xduncan@gmail.com',
#    'registered': '2005-05-28',
#    'birthdate': '1965-02-22'},
#   {'username': 'deborah80',
#    'mail': 'ericmccormick@yahoo.com',
#    'registered': '2001-11-14',
#    'birthdate': '1957-05-01'},
#   {'username': 'clarkkimberly',
#    'sex': 'M',
#    'country': 'Nicaragua',
#    'country_code': 'NI'},
#   {'username': 'angela19', 'sex': 'F', 'registered': '2013-11-29'},
#   {'username': 'greenegabrielle',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'birthdate': '1999-12-25'},
#   {'username': 'manuel61',
#    'name': 'Melissa Richardson',
#    'country': 'Uruguay',
#    'country_code': 'UY',
#    'registered': '2015-07-05'},
#   {'username': 'mistyrice',
#    'name': 'Melanie Gonzalez',
#    'mail': 'kevin43@hotmail.com'},
#   {'username': 'jamessimpson',
#    'name': 'Randy Ruiz',
#    'sex': 'M',
#    'country': 'Dominican Republic',
#    'country_code': 'DO',
#    'mail': 'stonekevin@hotmail.com',
#    'registered': '2007-04-20'},
#   {'username': 'powersmark',
#    'name': 'Elizabeth Reed',
#    'mail': 'mjohnson@yahoo.com'},
#   {'username': 'davidpearson', 'name': 'Andrew Price', 'sex': 'M'},
#   {'username': 'buckjennifer', 'name': 'Steven Wilson'},
#   {'username': 'nicolereynolds',
#    'name': 'Heather Cole',
#    'registered': '2017-06-03'},
#   {'username': 'deborah94', 'name': 'Kimberly Dunn', 'sex': 'F'},
#   {'username': 'juliacochran',
#    'name': 'Patricia King',
#    'mail': 'james67@yahoo.com',
#    'birthdate': '2007-12-13'},
#   {'username': 'leecompton',
#    'registered': '2003-06-21',
#    'birthdate': '2003-03-27'},
#   {'username': 'christopher68',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'birthdate': '1952-11-10'},
#   {'username': 'kempandrea',
#    'name': 'Heather Cox',
#    'mail': 'david00@yahoo.com',
#    'registered': '2003-07-29'},
#   {'username': 'fowlercarolyn',
#    'name': 'Michael Barnes',
#    'sex': 'M',
#    'country': 'Japan',
#    'country_code': 'JP',
#    'mail': 'khawkins@yahoo.com',
#    'birthdate': '2020-11-06'},
#   {'username': 'maynardtracie',
#    'name_prefix': 'Dr.',
#    'sex': 'F',
#    'mail': 'michaelwalker@hotmail.com'},
#   {'username': 'darrellwilliams', 'sex': 'F', 'registered': '2004-03-02'},
#   {'username': 'monica16',
#    'name': 'Julian Hernandez',
#    'country': 'Jordan',
#    'country_code': 'JO',
#    'mail': 'fostertimothy@gmail.com',
#    'birthdate': '2004-04-18'},
#   {'username': 'fischermargaret'},
#   {'username': 'eric09',
#    'name': 'Stephen Soto',
#    'sex': 'M',
#    'country': 'Rwanda',
#    'country_code': 'RW',
#    'registered': '2002-11-17',
#    'birthdate': '1978-07-24'},
#   {'username': 'harrisdeborah',
#    'country': 'Vietnam',
#    'country_code': 'VN',
#    'mail': 'george85@hotmail.com'},
#   {'username': 'wjackson',
#    'name_prefix': 'Mr.',
#    'name': 'Mr. Scott Kemp',
#    'sex': 'M',
#    'country': 'Pitcairn Islands',
#    'mail': 'rubioanne@yahoo.com',
#    'registered': '2010-12-25'},
#   {'username': 'qtucker',
#    'name': 'Charles Gates',
#    'sex': 'M',
#    'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#    'mail': 'michelle52@yahoo.com',
#    'birthdate': '1957-01-31'},
#   {'username': 'mathewslauren', 'name': 'Aaron Kelly'},
#   {'username': 'hvaldez', 'name': 'Michael Bailey', 'birthdate': '1987-05-27'},
#   {'username': 'kmorales',
#    'name': 'Leslie Miller',
#    'mail': 'mckeemichael@hotmail.com'},
#   {'username': 'jeffrey90',
#    'mail': 'griffintrevor@gmail.com',
#    'birthdate': '1973-08-08'},
#   {'username': 'blakepatrick',
#    'mail': 'rwood@gmail.com',
#    'birthdate': '1974-11-07'},
#   {'username': 'rhonda61',
#    'mail': 'manningjonathan@gmail.com',
#    'birthdate': '1974-06-22'},
#   {'username': 'dananewton',
#    'name': 'Thomas Montes',
#    'country': 'Ecuador',
#    'country_code': 'EC',
#    'mail': 'istewart@yahoo.com',
#    'registered': '2006-09-25'},
#   {'username': 'jeannesummers',
#    'name': 'Stephen Mckee',
#    'country': "Cote d'Ivoire",
#    'birthdate': '2017-02-13'},
#   {'username': 'nicholasthomas', 'sex': 'M', 'registered': '2018-05-06'},
#   {'username': 'taraalvarez',
#    'sex': 'M',
#    'country': 'Cambodia',
#    'country_code': 'KH',
#    'mail': 'gibsonnathan@yahoo.com',
#    'birthdate': '1954-11-10'},
#   {'username': 'wrichards',
#    'name_prefix': 'Dr.',
#    'name': 'David Anderson',
#    'sex': 'M',
#    'birthdate': '1970-10-09'},
#   {'username': 'dominic41',
#    'name': 'Robert Butler',
#    'sex': 'M',
#    'mail': 'monicamolina@gmail.com'},
#   {'username': 'glewis',
#    'name': 'Samantha Flores',
#    'sex': 'F',
#    'mail': 'tjones@hotmail.com',
#    'birthdate': '1970-01-01'},
#   {'username': 'hannahdelgado', 'mail': 'patricia57@yahoo.com'},
#   {'username': 'torrestammy',
#    'name': 'Michele House',
#    'birthdate': '1997-09-09'},
#   {'username': 'natashalawrence', 'name': 'Kathleen Chapman'},
#   {'username': 'justinedwards', 'mail': 'charlesdavis@hotmail.com'},
#   {'username': 'thompsonjames',
#    'name': 'Michelle Gaines',
#    'country': 'Cayman Islands',
#    'country_code': 'KY',
#    'registered': '2017-07-08',
#    'birthdate': '2008-03-10'},
#   {'username': 'stanleywright',
#    'country': 'United Arab Emirates',
#    'country_code': 'AE',
#    'registered': '2013-02-23',
#    'birthdate': '2017-04-08'},
#   {'username': 'gnelson',
#    'name_prefix': 'Ms.',
#    'sex': 'F',
#    'mail': 'pattersonisaac@yahoo.com',
#    'birthdate': '1952-05-02'},
#   {'username': 'marybrown',
#    'country': 'Hungary',
#    'country_code': 'HU',
#    'registered': '2014-04-30'},
#   {'username': 'hansonamy',
#    'sex': 'M',
#    'country': 'Turks and Caicos Islands',
#    'mail': 'sullivankaren@yahoo.com',
#    'birthdate': '1960-04-06'},
#   {'username': 'mcfarlandjoshua',
#    'name_prefix': 'Mr.',
#    'name': 'Gerald Wilson',
#    'sex': 'M',
#    'mail': 'carlsonlaura@hotmail.com',
#    'birthdate': '1965-03-28'},
#   {'username': 'kevin41',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#    'registered': '2018-07-20'},
#   {'username': 'amanda76',
#    'sex': 'M',
#    'country': 'Korea',
#    'registered': '2006-07-01'},
#   {'username': 'xmurray',
#    'mail': 'patrickmelissa@hotmail.com',
#    'birthdate': '1996-05-16'},
#   {'username': 'yangstacy',
#    'registered': '2012-05-14',
#    'birthdate': '1977-03-09'},
#   {'username': 'kjones',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'birthdate': '2020-09-11'},
#   {'username': 'pneal', 'sex': 'F', 'country': 'Chad', 'country_code': 'TD'},
#   {'username': 'thomasdixon',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'birthdate': '1954-08-23'},
#   {'username': 'zmcdowell',
#    'country': 'Kyrgyz Republic',
#    'registered': '2001-02-14'},
#   {'username': 'david67', 'sex': 'M'},
#   {'username': 'samuel50',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Kuwait',
#    'country_code': 'KW',
#    'mail': 'perryamber@yahoo.com'},
#   {'username': 'meadowspriscilla', 'name': 'Laurie Delacruz'},
#   {'username': 'rachelberry',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Saint Pierre and Miquelon',
#    'country_code': 'PM',
#    'mail': 'dtorres@gmail.com',
#    'registered': '2007-12-01'},
#   {'username': 'mstrickland',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Malawi',
#    'country_code': 'MW',
#    'registered': '2017-01-11'},
#   {'username': 'brianroberson',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Korea',
#    'mail': 'rclark@yahoo.com',
#    'registered': '2007-12-19',
#    'birthdate': '1965-10-04'},
#   {'username': 'michael72',
#    'sex': 'M',
#    'mail': 'eparrish@yahoo.com',
#    'registered': '2006-08-06',
#    'birthdate': '1984-09-17'},
#   {'username': 'barbara14',
#    'name_prefix': 'Mr.',
#    'name': 'Christopher Robbins',
#    'sex': 'M',
#    'birthdate': '1981-11-26'},
#   {'username': 'joseph34',
#    'name': 'Katherine Lee',
#    'country': 'Belize',
#    'country_code': 'BZ',
#    'registered': '2014-06-21'},
#   {'username': 'sclark',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'smithjesse@hotmail.com',
#    'registered': '2006-10-11',
#    'birthdate': '1961-03-30'},
#   {'username': 'jessica45',
#    'registered': '2001-04-27',
#    'birthdate': '1974-03-15'},
#   {'username': 'gcontreras', 'country': 'Montserrat', 'country_code': 'MS'},
#   {'username': 'weaveranthony',
#    'registered': '2012-11-07',
#    'birthdate': '1997-04-17'},
#   {'username': 'melindajohnson',
#    'name': 'Melissa Duncan',
#    'country': 'France',
#    'country_code': 'FR'},
#   {'username': 'sanderstimothy',
#    'country': 'Israel',
#    'country_code': 'IL',
#    'mail': 'ntaylor@gmail.com',
#    'registered': '2012-12-15'},
#   {'username': 'pweaver', 'mail': 'egriffin@gmail.com'},
#   {'username': 'melissa43',
#    'name_prefix': 'Miss',
#    'name': 'Amanda Lucas',
#    'sex': 'F',
#    'mail': 'laurenwilliams@yahoo.com'},
#   {'username': 'scarpenter',
#    'name': 'Kenneth Nichols',
#    'country': 'Anguilla',
#    'country_code': 'AI',
#    'registered': '2013-01-09'},
#   {'username': 'matthewgreer',
#    'name': 'Jason Davis',
#    'country': 'Andorra',
#    'country_code': 'AD',
#    'registered': '2010-11-05'},
#   {'username': 'bellmaria',
#    'name': 'Kimberly Wilson',
#    'country': 'Brazil',
#    'country_code': 'BR',
#    'mail': 'yjohnson@yahoo.com',
#    'registered': '2010-02-16'},
#   {'username': 'robertsonlisa',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'birthdate': '1954-02-17'},
#   {'username': 'joshuawebb',
#    'name': 'Michael Cross',
#    'registered': '2009-06-22',
#    'birthdate': '1996-06-20'},
#   {'username': 'dennis88',
#    'name_prefix': 'Mr.',
#    'name': 'Joshua Smith',
#    'sex': 'M',
#    'mail': 'stephenburch@yahoo.com',
#    'birthdate': '1994-10-01'},
#   {'username': 'gregorymolly',
#    'registered': '2008-11-25',
#    'birthdate': '2003-11-09'},
#   {'username': 'ujohnston',
#    'name': 'Kevin Moore',
#    'registered': '2005-04-20',
#    'birthdate': '2021-04-09'},
#   {'username': 'wrightsean',
#    'name': 'Kimberly English',
#    'sex': 'F',
#    'mail': 'carteralfred@gmail.com'},
#   {'username': 'david66',
#    'mail': 'osantana@gmail.com',
#    'registered': '2011-04-20',
#    'birthdate': '1951-08-22'},
#   {'username': 'richardchaney',
#    'name': 'Ronald Norris',
#    'mail': 'martinsarah@gmail.com',
#    'birthdate': '2007-10-24'},
#   {'username': 'martinstephen',
#    'name': 'Danielle Nichols',
#    'mail': 'uwalsh@hotmail.com',
#    'registered': '2009-01-25'},
#   {'username': 'mflores', 'mail': 'wagnerlori@gmail.com'},
#   {'username': 'jay75',
#    'name': 'Jennifer Williams',
#    'country': 'Afghanistan',
#    'country_code': 'AF',
#    'mail': 'jonesroger@gmail.com'},
#   {'username': 'kperkins',
#    'name': 'Nicholas Reeves',
#    'country': 'Algeria',
#    'country_code': 'DZ',
#    'birthdate': '1973-04-16'},
#   {'username': 'cherylkim',
#    'sex': 'M',
#    'mail': 'carlahart@yahoo.com',
#    'registered': '2008-11-17'},
#   {'username': 'kharris',
#    'mail': 'campbellpaul@hotmail.com',
#    'registered': '2016-09-01',
#    'birthdate': '2010-08-11'},
#   {'username': 'anne46',
#    'name': 'Ashley Horne',
#    'sex': 'F',
#    'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#    'registered': '2015-06-19',
#    'birthdate': '1991-11-15'},
#   {'username': 'webstercarol',
#    'name_prefix': 'Miss',
#    'name': 'Amber Mcbride DVM',
#    'sex': 'F',
#    'birthdate': '1993-07-03'},
#   {'username': 'rjohnston',
#    'name': 'Ronald Flores',
#    'country': 'Mauritius',
#    'country_code': 'MU',
#    'registered': '2002-05-30',
#    'birthdate': '2009-05-25'},
#   {'username': 'anthonypowell',
#    'name': 'Ray Hodges',
#    'country': 'Montserrat',
#    'country_code': 'MS',
#    'mail': 'shortraymond@yahoo.com'},
#   {'username': 'joshuahernandez',
#    'name_prefix': 'Ms.',
#    'sex': 'F',
#    'country': 'Nigeria',
#    'country_code': 'NG',
#    'mail': 'matthewphillips@hotmail.com',
#    'birthdate': '1966-01-20'},
#   {'username': 'ewells', 'country': 'Kyrgyz Republic'},
#   {'username': 'danielletrujillo',
#    'name': 'Dustin Edwards',
#    'country': 'Taiwan',
#    'country_code': 'TW',
#    'mail': 'nmacdonald@hotmail.com'},
#   {'username': 'williamswilliam', 'name': 'Garrett Quinn'},
#   {'username': 'tiffany01',
#    'name_prefix': 'Mrs.',
#    'name': 'Crystal Murray',
#    'sex': 'F',
#    'country': 'Russian Federation'},
#   {'username': 'qsanders',
#    'name': 'Jennifer Preston',
#    'sex': 'F',
#    'birthdate': '2003-10-23'},
#   {'username': 'zcalhoun',
#    'name_prefix': 'Dr.',
#    'name': 'Mr. Roger Phelps DVM',
#    'sex': 'M',
#    'registered': '2001-09-12',
#    'birthdate': '1987-07-17'},
#   {'username': 'josereyes',
#    'name': 'Sean Werner',
#    'country': 'Uganda',
#    'country_code': 'UG',
#    'mail': 'travis72@gmail.com'},
#   {'username': 'qpayne',
#    'name_prefix': 'Mr.',
#    'name': 'Steve Harris',
#    'sex': 'M',
#    'country': 'Thailand',
#    'country_code': 'TH',
#    'mail': 'yflores@yahoo.com',
#    'registered': '2012-01-30',
#    'birthdate': '1963-09-30'},
#   {'username': 'tbennett',
#    'name': 'James Garza',
#    'sex': 'M',
#    'mail': 'duranjames@gmail.com',
#    'registered': '2019-07-03'},
#   {'username': 'christopherdavis',
#    'country': 'Denmark',
#    'country_code': 'DK',
#    'registered': '2006-03-29',
#    'birthdate': '1978-09-14'},
#   {'username': 'joseph55',
#    'name': 'Matthew Davis',
#    'sex': 'M',
#    'country': 'Burkina Faso',
#    'country_code': 'BF',
#    'registered': '2015-09-28',
#    'birthdate': '2009-07-27'},
#   {'username': 'contrerasjoseph',
#    'sex': 'M',
#    'mail': 'rebecca24@hotmail.com',
#    'registered': '2011-10-05'},
#   {'username': 'lharrell',
#    'name': 'Kayla Hardin',
#    'registered': '2004-11-02',
#    'birthdate': '1953-08-10'},
#   {'username': 'robertagay',
#    'sex': 'M',
#    'country': 'Italy',
#    'country_code': 'IT',
#    'mail': 'rodriguezralph@gmail.com',
#    'birthdate': '1994-07-31'},
#   {'username': 'smithamber',
#    'mail': 'justinmeyers@gmail.com',
#    'birthdate': '2002-03-23'},
#   {'username': 'gbrown',
#    'name': 'Selena Kim',
#    'sex': 'F',
#    'registered': '2013-10-13'},
#   {'username': 'jennifer82',
#    'name': 'Michelle Gonzales',
#    'birthdate': '2008-04-12'},
#   {'username': 'sanchezjulie',
#    'name_prefix': 'Mr.',
#    'name': 'Jeremiah Brooks',
#    'sex': 'M',
#    'mail': 'daviskevin@hotmail.com'},
#   {'username': 'xhill',
#    'mail': 'santiagotiffany@yahoo.com',
#    'birthdate': '2016-05-19'},
#   {'username': 'stewartmichael',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'jasoncarroll@hotmail.com',
#    'birthdate': '2012-01-29'},
#   {'username': 'jnunez', 'country': 'Guam', 'country_code': 'GU'},
#   {'username': 'mgarcia', 'birthdate': '1996-09-22'},
#   {'username': 'kelsey58',
#    'sex': 'F',
#    'mail': 'jennifer23@gmail.com',
#    'registered': '2002-12-15',
#    'birthdate': '1982-09-08'},
#   {'username': 'jamesdominguez',
#    'name': 'Angela Kline',
#    'country': 'Slovenia',
#    'country_code': 'SI',
#    'mail': 'phillip39@gmail.com',
#    'registered': '2006-06-20',
#    'birthdate': '1998-07-20'},
#   {'username': 'andrewcooper',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'littlejeffrey@yahoo.com'},
#   {'username': 'austinmcdaniel',
#    'country': 'Ecuador',
#    'country_code': 'EC',
#    'mail': 'jeremy32@hotmail.com',
#    'registered': '2018-03-14'},
#   {'username': 'zellis', 'registered': '2005-09-09'},
#   {'username': 'jamesadam',
#    'sex': 'M',
#    'mail': 'jparsons@hotmail.com',
#    'registered': '2018-10-27',
#    'birthdate': '1951-01-30'},
#   {'username': 'heidiwagner',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'mail': 'mary63@hotmail.com',
#    'birthdate': '2007-08-06'},
#   {'username': 'smithclinton',
#    'name': 'Anthony Davis',
#    'sex': 'M',
#    'country': 'Colombia',
#    'country_code': 'CO'},
#   {'username': 'jacksonheidi',
#    'name_prefix': 'Mr.',
#    'name': 'James Wood',
#    'sex': 'M',
#    'country': 'Austria',
#    'country_code': 'AT',
#    'birthdate': '2016-04-14'},
#   {'username': 'ryan21',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'vmontoya@gmail.com'},
#   {'username': 'deborah82',
#    'name_prefix': 'Mrs.',
#    'name': 'Tammy Daniels',
#    'sex': 'F',
#    'birthdate': '2006-04-28'},
#   {'username': 'benjaminfrost',
#    'country': 'Gabon',
#    'country_code': 'GA',
#    'birthdate': '1980-11-09'},
#   {'username': 'wilsonkevin',
#    'sex': 'M',
#    'mail': 'stephanie65@hotmail.com',
#    'registered': '2019-04-11'},
#   {'username': 'turnerjames',
#    'name_prefix': 'Mr.',
#    'name': 'Dr. Preston Mccoy',
#    'sex': 'M',
#    'mail': 'randyrodgers@hotmail.com'},
#   {'username': 'prose', 'birthdate': '1971-12-13'},
#   {'username': 'arodriguez', 'sex': 'M', 'registered': '2016-03-25'},
#   {'username': 'casey47',
#    'name': 'Aaron Olson',
#    'country': 'Swaziland',
#    'country_code': 'SZ',
#    'mail': 'jennifersmith@yahoo.com',
#    'registered': '2001-12-27',
#    'birthdate': '2006-11-10'},
#   {'username': 'reevessharon',
#    'country': 'Christmas Island',
#    'country_code': 'CX',
#    'birthdate': '1951-12-19'},
#   {'username': 'onelson',
#    'name': 'Ashley Clark',
#    'country': 'Barbados',
#    'country_code': 'BB',
#    'mail': 'sarah68@yahoo.com',
#    'registered': '2017-08-07'},
#   {'username': 'ktran', 'name': 'Anthony Horne', 'birthdate': '2016-11-21'},
#   {'username': 'mstewart',
#    'country': 'Burkina Faso',
#    'country_code': 'BF',
#    'registered': '2010-01-17',
#    'birthdate': '1980-08-16'},
#   {'username': 'curryheather',
#    'mail': 'simpsonpam@yahoo.com',
#    'registered': '2009-05-15',
#    'birthdate': '2013-05-17'},
#   {'username': 'jessestanley',
#    'name': 'Suzanne Gilmore',
#    'mail': 'matthewchandler@hotmail.com',
#    'registered': '2004-12-27'},
#   {'username': 'yblack',
#    'name': 'Jessica Cordova',
#    'sex': 'F',
#    'mail': 'harrisfrank@yahoo.com',
#    'registered': '2011-08-22',
#    'birthdate': '1990-11-09'},
#   {'username': 'martinpeter',
#    'name': 'Deborah Lewis',
#    'sex': 'F',
#    'country': 'Benin',
#    'country_code': 'BJ'},
#   {'username': 'timothy53',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Austria',
#    'country_code': 'AT',
#    'registered': '2011-03-10'},
#   {'username': 'baldwinjoshua', 'registered': '2014-11-03'},
#   {'username': 'strongbarbara',
#    'country': 'Oman',
#    'country_code': 'OM',
#    'mail': 'lnunez@yahoo.com',
#    'registered': '2002-10-22'},
#   {'username': 'lawrence24',
#    'mail': 'spark@hotmail.com',
#    'birthdate': '2016-07-11'},
#   {'username': 'williamswilliam',
#    'name': 'Maria Baker',
#    'country': 'Sweden',
#    'country_code': 'SE',
#    'registered': '2015-07-02'},
#   {'username': 'kellynunez',
#    'mail': 'thomas80@gmail.com',
#    'registered': '2018-04-15',
# ...
#   {'username': 'bsalazar',
#    'country': 'Congo',
#    'mail': 'nicolehayes@yahoo.com',
#    'registered': '2002-01-18',
#    'birthdate': '1958-07-31'},
#   {'username': 'carterhannah',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'birthdate': '1967-08-07'},
#   {'username': 'kelly58',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Uzbekistan',
#    'country_code': 'UZ',
#    'mail': 'hhartman@gmail.com',
#    'birthdate': '1964-10-16'},
#   {'username': 'kathleen49',
#    'name': 'Richard Bartlett',
#    'mail': 'prodriguez@hotmail.com',
#    'registered': '2009-09-03',
#    'birthdate': '1987-04-11'},
#   {'username': 'erica01',
#    'sex': 'F',
#    'country': 'Holy See (Vatican City State)',
#    'country_code': 'VA',
#    'birthdate': '2012-02-08'},
#   {'username': 'ana90', 'sex': 'F', 'mail': 'hannah71@yahoo.com'},
#   {'username': 'joannaadams', 'name': 'Raymond Daniels'},
#   {'username': 'thorntonjessica',
#    'mail': 'petersonshelby@gmail.com',
#    'birthdate': '1999-03-18'},
#   {'username': 'amandahughes',
#    'sex': 'M',
#    'mail': 'mjones@gmail.com',
#    'registered': '2011-02-12'},
#   {'username': 'plopez',
#    'sex': 'M',
#    'country': 'Bouvet Island (Bouvetoya)',
#    'mail': 'mreed@gmail.com'},
#   {'username': 'renee54',
#    'name': 'Tracy Olsen',
#    'registered': '2019-02-08',
#    'birthdate': '2002-02-23'},
#   {'username': 'lovebrian',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'birthdate': '2003-12-01'},
#   {'username': 'bclarke',
#    'country': 'Nauru',
#    'country_code': 'NR',
#    'registered': '2015-12-15'},
#   {'username': 'jsexton',
#    'name': 'Linda Cunningham',
#    'sex': 'F',
#    'country': 'Namibia',
#    'country_code': 'nan',
#    'mail': 'englishdavid@gmail.com',
#    'birthdate': '2011-03-23'},
#   {'username': 'mendezlisa',
#    'country': 'Tonga',
#    'country_code': 'TO',
#    'registered': '2005-01-14',
#    'birthdate': '1955-12-18'},
#   {'username': 'harrellbrooke',
#    'country': 'Benin',
#    'country_code': 'BJ',
#    'mail': 'bethanymurphy@hotmail.com',
#    'registered': '2016-02-15',
#    'birthdate': '2014-06-08'},
#   {'username': 'keithsolomon',
#    'country': 'Afghanistan',
#    'country_code': 'AF',
#    'mail': 'annettewhite@hotmail.com'},
#   {'username': 'onolan', 'registered': '2018-03-06'},
#   {'username': 'burkesydney',
#    'country': 'New Caledonia',
#    'country_code': 'NC',
#    'registered': '2016-04-27',
#    'birthdate': '1959-12-06'},
#   {'username': 'srichardson',
#    'name_prefix': 'Ms.',
#    'sex': 'F',
#    'registered': '2007-07-14',
#    'birthdate': '1968-10-19'},
#   {'username': 'veronica77',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'sarahburns@hotmail.com',
#    'registered': '2010-07-10',
#    'birthdate': '1960-08-09'},
#   {'username': 'catherine78',
#    'name_prefix': 'Dr.',
#    'name': 'Donald Nicholson',
#    'sex': 'M',
#    'country': 'Equatorial Guinea',
#    'country_code': 'GQ',
#    'mail': 'nicoleclark@yahoo.com',
#    'registered': '2005-05-05',
#    'birthdate': '2010-04-30'},
#   {'username': 'thompsonwesley',
#    'name_prefix': 'Mr.',
#    'name': 'Carlos Perez',
#    'sex': 'M',
#    'mail': 'aliciaholt@yahoo.com',
#    'registered': '2009-04-16'},
#   {'username': 'xpeck',
#    'country': 'Bolivia',
#    'country_code': 'BO',
#    'mail': 'johnsonaaron@yahoo.com',
#    'birthdate': '1984-02-04'},
#   {'username': 'jonathanwilson',
#    'name': 'Tyler Howard',
#    'country': 'American Samoa',
#    'country_code': 'AS',
#    'registered': '2009-07-25',
#    'birthdate': '1998-11-11'},
#   {'username': 'tstone', 'registered': '2015-10-20'},
#   {'username': 'erikgeorge',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'scottlewis@hotmail.com',
#    'birthdate': '2015-01-10'},
#   {'username': 'barbara39', 'mail': 'mariepowell@gmail.com'},
#   {'username': 'ctaylor',
#    'name': 'Lisa Greene',
#    'sex': 'F',
#    'mail': 'patricia40@hotmail.com',
#    'registered': '2001-04-25'},
#   {'username': 'garyfowler',
#    'name_prefix': 'Mrs.',
#    'name': 'Rebecca Baker',
#    'sex': 'F',
#    'registered': '2005-05-30'},
#   {'username': 'padillaroger',
#    'name': 'Cheryl Hansen',
#    'registered': '2014-04-25'},
#   {'username': 'seththomas',
#    'name': 'Lucas Morgan',
#    'country': 'New Zealand',
#    'country_code': 'NZ',
#    'birthdate': '1989-12-25'},
#   {'username': 'kyle43',
#    'mail': 'nancy31@hotmail.com',
#    'birthdate': '2000-10-31'},
#   {'username': 'pittmancatherine',
#    'name_prefix': 'Ms.',
#    'name': 'Chelsea Martin',
#    'sex': 'F',
#    'mail': 'griffithmichael@yahoo.com',
#    'birthdate': '1987-11-05'},
#   {'username': 'valdezdavid',
#    'sex': 'M',
#    'country': 'Faroe Islands',
#    'country_code': 'FO',
#    'birthdate': '1960-07-30'},
#   {'username': 'lindseyclark',
#    'mail': 'sarah77@yahoo.com',
#    'registered': '2004-10-23',
#    'birthdate': '1988-10-25'},
#   {'username': 'lindawatson',
#    'name': 'Bradley Neal',
#    'mail': 'zjones@hotmail.com',
#    'registered': '2015-08-11'},
#   {'username': 'kristine40',
#    'country': 'Kuwait',
#    'country_code': 'KW',
#    'mail': 'ysmith@yahoo.com',
#    'birthdate': '1959-10-31'},
#   {'username': 'moorejames',
#    'name': 'Ashley Conner',
#    'sex': 'F',
#    'registered': '2018-06-09'},
#   {'username': 'brownryan',
#    'mail': 'jacquelinepace@gmail.com',
#    'registered': '2017-03-06',
#    'birthdate': '2005-11-27'},
#   {'username': 'twoods',
#    'country': 'Saudi Arabia',
#    'country_code': 'SA',
#    'mail': 'aramos@yahoo.com',
#    'registered': '2009-04-02',
#    'birthdate': '1969-08-20'},
#   {'username': 'campbellgabriel',
#    'sex': 'M',
#    'country': 'Suriname',
#    'country_code': 'SR',
#    'mail': 'madeline35@gmail.com',
#    'registered': '2012-06-01'},
#   {'username': 'xbowen',
#    'name_prefix': 'Mr.',
#    'name': 'Eric Davis',
#    'sex': 'M',
#    'country': 'Belarus',
#    'country_code': 'BY',
#    'birthdate': '2019-08-29'},
#   {'username': 'rrodriguez',
#    'name_prefix': 'Dr.',
#    'name': 'Danielle Melton',
#    'sex': 'F',
#    'mail': 'njones@gmail.com',
#    'registered': '2009-10-19'},
#   {'username': 'williamsteresa',
#    'name': 'Laura Bird',
#    'sex': 'F',
#    'country': 'Niger',
#    'country_code': 'NE',
#    'mail': 'uthomas@hotmail.com',
#    'registered': '2007-08-03'},
#   {'username': 'markwoods',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Macao',
#    'country_code': 'MO',
#    'birthdate': '1986-01-21'},
#   {'username': 'tyronekeller',
#    'name': 'Peter Kelley',
#    'country': 'Aruba',
#    'country_code': 'AW',
#    'registered': '2016-07-04',
#    'birthdate': '1976-04-28'},
#   {'username': 'mckayjohn', 'birthdate': '2002-01-04'},
#   {'username': 'richard18',
#    'name_prefix': 'Miss',
#    'sex': 'F',
#    'birthdate': '2004-10-03'},
#   {'username': 'ppowers', 'name': 'Donna West', 'registered': '2008-11-28'},
#   {'username': 'katherine85',
#    'name_prefix': 'Mr.',
#    'name': 'Robert Green',
#    'sex': 'M',
#    'mail': 'shelley74@hotmail.com',
#    'registered': '2019-05-10'},
#   {'username': 'maria78',
#    'name': 'Kerry Morris',
#    'sex': 'M',
#    'registered': '2004-01-09'},
#   {'username': 'onealjeremy',
#    'sex': 'F',
#    'country': 'Chile',
#    'country_code': 'CL',
#    'mail': 'melissa49@gmail.com'},
#   {'username': 'msalazar',
#    'name_prefix': 'Dr.',
#    'name': 'Jonathan Conrad',
#    'sex': 'M',
#    'country': 'Ghana',
#    'country_code': 'GH',
#    'registered': '2004-01-17'},
#   {'username': 'marystewart',
#    'name': 'Kendra Murphy',
#    'sex': 'F',
#    'country': 'Aruba',
#    'country_code': 'AW'},
#   {'username': 'teresa50', 'sex': 'M'},
#   {'username': 'casey39',
#    'name': 'Alejandro Foster',
#    'registered': '2001-05-26',
#    'birthdate': '1952-05-24'},
#   {'username': 'martinezalicia',
#    'name': 'Melissa Bennett',
#    'sex': 'F',
#    'mail': 'jenniferwood@gmail.com',
#    'registered': '2002-01-25'},
#   {'username': 'gperez',
#    'country': 'Azerbaijan',
#    'country_code': 'AZ',
#    'mail': 'sullivantimothy@hotmail.com',
#    'registered': '2019-08-23',
#    'birthdate': '1963-05-10'},
#   {'username': 'kimberlygaines', 'sex': 'M', 'birthdate': '2016-02-29'},
#   {'username': 'murrayamber',
#    'country': 'French Guiana',
#    'country_code': 'GF',
#    'mail': 'bethanyhickman@yahoo.com',
#    'registered': '2002-09-25',
#    'birthdate': '1989-11-18'},
#   {'username': 'walkertara',
#    'sex': 'F',
#    'country': "Lao People's Democratic Republic",
#    'country_code': 'LA',
#    'registered': '2002-12-12'},
#   {'username': 'david15',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'mail': 'jturner@hotmail.com'},
#   {'username': 'brian30',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'American Samoa',
#    'country_code': 'AS',
#    'birthdate': '1952-05-12'},
#   {'username': 'valerieharris',
#    'country': 'Brazil',
#    'country_code': 'BR',
#    'mail': 'pbrown@yahoo.com',
#    'registered': '2018-08-13',
#    'birthdate': '1952-03-01'},
#   {'username': 'xnorton',
#    'name_prefix': 'Mr.',
#    'name': 'Joseph Rangel',
#    'sex': 'M',
#    'country': 'Kiribati',
#    'country_code': 'KI',
#    'mail': 'phillip13@gmail.com'},
#   {'username': 'lthompson',
#    'name_prefix': 'Mrs.',
#    'name': 'Shawna Soto',
#    'sex': 'F',
#    'birthdate': '2010-02-21'},
#   {'username': 'gkelley',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'mail': 'anthonypadilla@gmail.com',
#    'registered': '2004-03-23',
#    'birthdate': '2010-12-12'},
#   {'username': 'nhughes',
#    'country': 'Moldova',
#    'mail': 'mreyes@gmail.com',
#    'birthdate': '1965-09-17'},
#   {'username': 'williamschristopher',
#    'sex': 'F',
#    'registered': '2010-11-12',
#    'birthdate': '1985-12-13'},
#   {'username': 'jamesallen', 'name': 'Glen Keller', 'birthdate': '2012-04-15'},
#   {'username': 'nicolewilliams',
#    'name': 'Kevin West',
#    'mail': 'steven98@gmail.com',
#    'birthdate': '1999-03-26'},
#   {'username': 'santanaalexa', 'birthdate': '1955-06-18'},
#   {'username': 'hortonmartin',
#    'name_prefix': 'Mr.',
#    'name': 'Alexander Jackson',
#    'sex': 'M',
#    'birthdate': '1960-03-08'},
#   {'username': 'fsnyder',
#    'name': 'Kelly Perez',
#    'sex': 'F',
#    'country': 'Japan',
#    'country_code': 'JP',
#    'registered': '2014-09-16',
#    'birthdate': '2012-12-20'},
#   {'username': 'leandrea',
#    'name': 'Douglas Nguyen',
#    'mail': 'sonyaroberts@hotmail.com',
#    'registered': '2013-09-28',
#    'birthdate': '2020-08-25'},
#   {'username': 'agarcia',
#    'name_prefix': 'Dr.',
#    'sex': 'M',
#    'registered': '2015-08-21',
#    'birthdate': '1959-08-20'},
#   {'username': 'robertkim', 'registered': '2011-10-19'},
#   {'username': 'garciajeremy',
#    'name': 'Vicki Williams',
#    'registered': '2019-01-17',
#    'birthdate': '1969-10-01'},
#   {'username': 'avilataylor', 'name': 'Sherry Dillon'},
#   {'username': 'josephsmith',
#    'name': 'Tiffany Luna',
#    'sex': 'F',
#    'registered': '2017-06-27'},
#   {'username': 'msmith', 'sex': 'M'},
#   {'username': 'vbishop',
#    'sex': 'F',
#    'country': 'Maldives',
#    'country_code': 'MV',
#    'registered': '2016-11-15',
#    'birthdate': '1958-10-03'},
#   {'username': 'michael41',
#    'country': 'Monaco',
#    'country_code': 'MC',
#    'birthdate': '2013-05-01'},
#   {'username': 'nicole55',
#    'name': 'Shannon Smith',
#    'country': 'Bolivia',
#    'country_code': 'BO',
#    'mail': 'patriciasullivan@gmail.com',
#    'birthdate': '1980-12-05'},
#   {'username': 'chandlertina',
#    'name_prefix': 'Mr.',
#    'name': 'Rick Coleman',
#    'sex': 'M',
#    'country': 'Vietnam',
#    'country_code': 'VN',
#    'mail': 'johndelgado@hotmail.com',
#    'registered': '2015-10-04',
#    'birthdate': '1963-08-04'},
#   {'username': 'sueray',
#    'mail': 'cheryl64@yahoo.com',
#    'registered': '2019-01-31'},
#   {'username': 'timothybenson',
#    'name': 'Richard Townsend',
#    'sex': 'M',
#    'mail': 'clarkscott@hotmail.com',
#    'registered': '2011-04-14'},
#   {'username': 'ybarrera',
#    'name': 'Willie Williams',
#    'sex': 'M',
#    'country': 'Haiti',
#    'country_code': 'HT',
#    'birthdate': '2016-12-07'},
#   {'username': 'frenchjulia', 'name_prefix': 'Mr.', 'sex': 'M'},
#   {'username': 'kristincurtis',
#    'country': 'United States of America',
#    'mail': 'stephen69@hotmail.com',
#    'registered': '2009-12-12',
#    'birthdate': '1962-08-23'},
#   {'username': 'ericdixon',
#    'name': 'Jerry Wade',
#    'country': 'Albania',
#    'country_code': 'AL',
#    'mail': 'tiffanypatterson@hotmail.com',
#    'registered': '2010-09-21'},
#   {'username': 'leslie82',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'mail': 'tyler41@gmail.com'},
#   {'username': 'evanvillegas',
#    'name_prefix': 'Mrs.',
#    'sex': 'F',
#    'country': 'Mayotte',
#    'country_code': 'YT',
#    'mail': 'bbailey@yahoo.com',
#    'birthdate': '1997-01-30'},
#   {'username': 'kmercado',
#    'name': 'Katherine Baker',
#    'country': "Cote d'Ivoire",
#    'mail': 'smithjennifer@hotmail.com'},
#   {'username': 'kimberly15',
#    'country': 'Grenada',
#    'country_code': 'GD',
#    'birthdate': '1964-03-03'},
#   {'username': 'fdean',
#    'name': 'Tammy Thompson',
#    'country': 'Poland',
#    'country_code': 'PL',
#    'birthdate': '1964-02-04'},
#   {'username': 'annafleming',
#    'country': 'Andorra',
#    'country_code': 'AD',
#    'birthdate': '1986-01-22'},
#   {'username': 'samantha01',
#    'mail': 'luis78@yahoo.com',
#    'birthdate': '1975-05-22'},
#   {'username': 'joshuafernandez',
#    'name': 'Lucas Flores',
#    'country': 'Barbados',
#    'country_code': 'BB',
#    'mail': 'hayesmelissa@gmail.com'},
#   {'username': 'spetersen',
#    'country': 'Holy See (Vatican City State)',
#    'country_code': 'VA',
#    'registered': '2012-05-24',
#    'birthdate': '1978-11-07'},
#   {'username': 'mholloway', 'birthdate': '1963-04-14'},
#   {'username': 'ricejessica',
#    'name': 'Ariel Gilmore',
#    'mail': 'hector88@yahoo.com',
#    'registered': '2004-01-18',
#    'birthdate': '2005-08-12'},
#   {'username': 'crosscharles',
#    'name': 'Steven Miranda',
#    'sex': 'M',
#    'country': 'Saint Kitts and Nevis',
#    'country_code': 'KN',
#    'registered': '2001-11-23',
#    'birthdate': '1994-04-21'},
#   {'username': 'jsmith',
#    'name_prefix': 'Ms.',
#    'name': 'Amber Harrington',
#    'sex': 'F',
#    'mail': 'ydiaz@hotmail.com',
#    'birthdate': '2010-07-27'},
#   {'username': 'beth31', 'name': 'Devin Wilson', 'mail': 'nperez@gmail.com'},
#   {'username': 'luisjimenez',
#    'name': 'Mrs. Ashley Holland',
#    'birthdate': '1950-03-08'},
#   {'username': 'johnsonmelissa',
#    'name': 'Kimberly Collins',
#    'sex': 'F',
#    'mail': 'jennifer92@hotmail.com',
#    'birthdate': '1984-10-12'},
#   {'username': 'iperez',
#    'name_prefix': 'Dr.',
#    'name': 'Jasmine Wood',
#    'sex': 'F',
#    'country': "Lao People's Democratic Republic",
#    'country_code': 'LA',
#    'mail': 'hbell@yahoo.com',
#    'registered': '2018-12-06',
#    'birthdate': '2017-03-24'},
#   {'username': 'clintoncarpenter',
#    'name': 'Christopher Bowen',
#    'country': 'Egypt',
#    'country_code': 'EG',
#    'mail': 'glennbutler@gmail.com',
#    'registered': '2005-12-26',
#    'birthdate': '2001-11-22'},
#   {'username': 'troy70',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'country': 'Marshall Islands',
#    'country_code': 'MH',
#    'mail': 'leslie55@yahoo.com',
#    'birthdate': '1952-09-18'},
#   {'username': 'browncarla', 'name': 'Jaime Ray', 'birthdate': '1965-10-06'},
#   {'username': 'collinsmichael',
#    'name': 'Douglas Morales',
#    'registered': '2017-12-25'},
#   {'username': 'kelly68',
#    'name': 'Scott Cooper',
#    'country': 'Botswana',
#    'country_code': 'BW',
#    'registered': '2011-10-26'},
#   {'username': 'linda06',
#    'country': 'Saint Helena',
#    'birthdate': '1971-04-26'},
#   {'username': 'debra93',
#    'country': 'Saint Vincent and the Grenadines',
#    'country_code': 'VC',
#    'mail': 'james92@hotmail.com'},
#   {'username': 'michael28', 'sex': 'M'},
#   {'username': 'castrojoseph', 'name': 'Manuel Price'},
#   {'username': 'marissawolf',
#    'country': 'El Salvador',
#    'country_code': 'SV',
#    'mail': 'cgeorge@hotmail.com'},
#   {'username': 'gleblanc',
#    'sex': 'F',
#    'mail': 'duncanadam@yahoo.com',
#    'registered': '2018-02-17'},
#   {'username': 'lisa38',
#    'name_prefix': 'Mr.',
#    'sex': 'M',
#    'registered': '2003-11-16'},
#   {'username': 'hoffmanjulie',
#    'name': 'Anthony Ellis',
#    'sex': 'M',
#    'country': 'Taiwan',
#    'country_code': 'TW',
#    'registered': '2012-11-11',
#    'birthdate': '1960-01-18'},
#   {'username': 'mcdowellteresa',
#    'name': 'Taylor Mejia',
#    'sex': 'M',
#    'registered': '2011-02-06'},
#   ...])

# %% [markdown]
# 3. Задекорируйте функцию из задания 1 при помощи `dask.delayed` и создайте список `reviewers`, состоящий из 5 объектов `delayed` (по одному объекту на файл). Из списка объектов `delayed`, создайте `dask.bag` при помощи метода `db.from_delayed`. Добавьте ключ `birth_year`, в котором хранится год рождения человека. Оставьте в выборке только тех людей, которые __наверняка__ моложе 1980 года. Преобразуйте поле `id` к целому типу.

# %%
import dask.bag as db

@delayed
def parse_reviewers_file(xml_file):
    with open(xml_file) as f:
        soup = BeautifulSoup(f, 'xml')
        reviewers = []
        for reviewer in soup.find_all("user"):
            reviewer_dict = {}
            reviewer_dict['id'] = int(reviewer.find('id').text)
            reviewer_dict['username'] = reviewer.find('username').text if reviewer.find('username') else None
            reviewer_dict['name'] = reviewer.find('name').text if reviewer.find('name') else None
            reviewer_dict['sex'] = reviewer.find('sex').text if reviewer.find('sex') else None
            reviewer_dict['country'] = reviewer.find('country').text if reviewer.find('country') else None
            reviewer_dict['mail'] = reviewer.find('mail').text if reviewer.find('mail') else None
            reviewer_dict['registered'] = reviewer.find('registered').text if reviewer.find('registered') else None
            reviewer_dict['birthdate'] = reviewer.find('birthdate').text if reviewer.find('birthdate') else None
            reviewer_dict['birth_year'] = int(reviewer.find('birthdate').text.split('-')[0]) if reviewer.find('birthdate') else None
            reviewer_dict['name_prefix'] = reviewer.get('prefix')
            reviewer_dict['country_code'] = reviewer.find('country').get('code') if reviewer.find('country') else None
            reviewers.append(reviewer_dict)
        return reviewers


def parse_reviewers_zip(zip_path):
    with zipfile.ZipFile(zip_path) as z:
        xml_files = [f for f in z.namelist() if 'reviewers_full/reviewers_full_' in f]
        delayed_results = [parse_reviewers_file(f) for f in xml_files]
        b = db.from_delayed(delayed_results)
        b = b.filter(lambda x: x['birth_year'] != None and x['birth_year'] >= 1980)
        return b

# %%
# %%time
revs = parse_reviewers_zip('reviewers_full.zip')
# Out:
# Wall time: 772 ms

# %% [markdown]
# 4. Из `dask.bag`, полученного в задании 3, создайте `dask.dataframe` при помощи метода `bag.to_dataframe`. Укажите столбец `id` в качестве индекса.

# %%
df = revs.to_dataframe()
df = df.set_index('id')
df
# Out:
# Dask DataFrame Structure:
#               username    name     sex country    mail registered birthdate birth_year name_prefix country_code
# npartitions=5
# 1676            object  object  object  object  object     object    object      int64      object       object
# 367646             ...     ...     ...     ...     ...        ...       ...        ...         ...          ...
# ...                ...     ...     ...     ...     ...        ...       ...        ...         ...          ...
# 2000355109         ...     ...     ...     ...     ...        ...       ...        ...         ...          ...
# 2002372706         ...     ...     ...     ...     ...        ...       ...        ...         ...          ...
# Dask Name: sort_index, 7 graph layers

# %%
df.compute()
# Out:
#                  username              name   sex               country  \
# id
# 1676              lgeorge              None     M                  None
# 1792               qbeard              None     F                Guinea
# 1938            adambrown    William Fisher  None         New Caledonia
# 2046            vthompson     Emily Sanford     F  United Arab Emirates
# 2095             djohnson  Jennifer Hawkins     F               Jamaica
# ...                   ...               ...   ...                   ...
# 2002370648      wbradford              None  None                  None
# 2002371420  walkershirley     Travis Harris     M               Vietnam
# 2002371627    travisbrown              None  None                  None
# 2002371716          greid         Jose Mata  None             Lithuania
# 2002372706  gibbsnicholas    Jeffrey Rivera     M             Greenland
#
#                             mail  registered   birthdate  birth_year  \
# id
# 1676                        None        None  1983-06-24        1983
# 1792        rachel20@hotmail.com        None  1986-03-12        1986
# 1938                        None  2019-05-03  1991-11-11        1991
# 2046         omelendez@yahoo.com  2001-10-30  1981-11-27        1981
# 2095                        None        None  1984-09-23        1984
# ...                          ...         ...         ...         ...
# 2002370648                  None        None  2010-07-14        2010
# 2002371420                  None  2009-08-15  1994-02-16        1994
# 2002371627      kdoyle@gmail.com  2005-03-10  2000-06-11        2000
# 2002371716                  None  2002-01-06  2007-07-01        2007
# 2002372706    thomas67@gmail.com  2018-07-25  2007-05-20        2007
#
#            name_prefix country_code
# id
# 1676              None         None
# 1792              None           GN
# 1938              None           NC
# 2046              None           AE
# 2095              Mrs.           JM
# ...                ...          ...
# 2002370648        None         None
# 2002371420         Mr.           VN
# 2002371627        None         None
# 2002371716        None           LT
# 2002372706        None           GL
#
# [65706 rows x 10 columns]

# %% [markdown]
# 5. Назовем отзыв негативным, если оценка равна 0, 1 или 2. Загрузите данные о негативных отзывах из файлов архива `reviews_full` (__ЛР12__) в виде `dask.DataFrame`. Посчитайте количество отзывов с группировкой по пользователю, оставившему отзыв. Объедините результат с таблицей, полученной в задаче 4.

# %%
import json
import glob
import re

def parse_review_json_with_rating(json_string, include_path):
    json_obj = json.loads(json_string)
    match = re.search(r'reviews_(\d+)\.json', include_path)
    if match:
        rating = int(match.group(1))
        json_obj['rating'] = rating
    return json_obj

# %%
# Читаем все файлы в список
files = glob.glob('reviews_full/reviews_*.json')
print(files)
# Создаем первый dask.bag
b_ratings = db.read_text(files[0]).map(parse_review_json_with_rating, include_path=files[0]).filter(lambda x: x['rating'] < 3)

#Объединяем остальные dask.bag
for file in files[1:]:
    cur = db.read_text(file).map(parse_review_json_with_rating, include_path=file).filter(lambda x: x['rating'] < 3)
    b_ratings = db.concat([b_ratings, cur])
# Out:
# ['reviews_full\\reviews_0.json', 'reviews_full\\reviews_1.json', 'reviews_full\\reviews_2.json', 'reviews_full\\reviews_3.json', 'reviews_full\\reviews_4.json', 'reviews_full\\reviews_5.json']

# %%
dask_dataframe_revs = b_ratings.to_dataframe()

# %%
dask_dataframe_revs.compute()
# Out:
#         user_id  recipe_id        date  \
# 0        452355     292657  2016-05-08
# 1        329304     433404  2006-06-14
# 2        227932    2008187  1985-11-19
# 3        171468     270716  2019-05-21
# 4         91392    1159916  1972-09-18
# ...         ...        ...         ...
# 112556   383346      45919  2016-08-21
# 112557   353659     253948  2015-04-24
# 112558    50969     304989  2017-12-20
# 112559   666723    1792397  2021-06-08
# 112560    89831    1365716  2015-11-19
#
#                                                    review  rating
# 0       WOW!!! This is the best. I have never been abl...       0
# 1       This was good but the dressing needed somethin...       0
# 2       Very good,it was a hit for my family. I used 6...       0
# 3       Made for ZWT-8 Family Picks after I saw these ...       0
# 4       Very nice slaw. I especially like that it does...       0
# ...                                                   ...     ...
# 112556  This made a wonderful and delicious breakfast!...       2
# 112557  I made this over the weekend, I filled it with...       2
# 112558  A solid introduction to a grand Mediterranean ...       2
# 112559  I absolutely LOVE your recipe and I have made ...       2
# 112560  Great, easy recipe.  Delicious fall dinner.  I...       2
#
# [702627 rows x 5 columns]

# %%
revs_by_user = dask_dataframe_revs.groupby('user_id')['review'].count()
revs_by_user.compute()
# Out:
# user_id
# 1533           64
# 1535          441
# 1634           36
# 1676           29
# 1755            4
#              ...
# 2002366476      1
# 2002368940      1
# 2002369279      1
# 2002369650      1
# 2002372706      1
# Name: review, Length: 145069, dtype: int64

# %%
dask_dataframe_revs_join = df.join(revs_by_user.compute())

# %%
dask_dataframe_revs_join.compute()
# Out:
#                  username              name   sex               country  \
# id
# 1676              lgeorge              None     M                  None
# 1792               qbeard              None     F                Guinea
# 1938            adambrown    William Fisher  None         New Caledonia
# 2046            vthompson     Emily Sanford     F  United Arab Emirates
# 2095             djohnson  Jennifer Hawkins     F               Jamaica
# ...                   ...               ...   ...                   ...
# 2002370648      wbradford              None  None                  None
# 2002371420  walkershirley     Travis Harris     M               Vietnam
# 2002371627    travisbrown              None  None                  None
# 2002371716          greid         Jose Mata  None             Lithuania
# 2002372706  gibbsnicholas    Jeffrey Rivera     M             Greenland
#
#                             mail  registered   birthdate  birth_year  \
# id
# 1676                        None        None  1983-06-24        1983
# 1792        rachel20@hotmail.com        None  1986-03-12        1986
# 1938                        None  2019-05-03  1991-11-11        1991
# 2046         omelendez@yahoo.com  2001-10-30  1981-11-27        1981
# 2095                        None        None  1984-09-23        1984
# ...                          ...         ...         ...         ...
# 2002370648                  None        None  2010-07-14        2010
# 2002371420                  None  2009-08-15  1994-02-16        1994
# 2002371627      kdoyle@gmail.com  2005-03-10  2000-06-11        2000
# 2002371716                  None  2002-01-06  2007-07-01        2007
# 2002372706    thomas67@gmail.com  2018-07-25  2007-05-20        2007
#
#            name_prefix country_code  review
# id
# 1676              None         None    29.0
# 1792              None           GN    14.0
# 1938              None           NC     3.0
# 2046              None           AE     3.0
# 2095              Mrs.           JM     NaN
# ...                ...          ...     ...
# 2002370648        None         None     1.0
# 2002371420         Mr.           VN     1.0
# 2002371627        None         None     2.0
# 2002371716        None           LT     1.0
# 2002372706        None           GL     1.0
#
# [65706 rows x 11 columns]
