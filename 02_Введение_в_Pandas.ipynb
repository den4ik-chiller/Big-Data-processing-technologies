# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
import pandas as pd
dataset = pd.read_table("sp500hst.txt", delimiter=',')
dataset.columns = ["date", "ticker", "open", "high", "low", "close", "volume"]
dataset
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090824      A  25.64  25.7400  25.330  25.50   22247
# 1       20090825      A  25.50  25.7000  25.225  25.34   30891
# 2       20090826      A  25.32  25.6425  25.145  25.48   33334
# 3       20090827      A  25.50  25.5700  25.230  25.54   70176
# 4       20090828      A  25.67  26.0500  25.630  25.83   39694
# ...          ...    ...    ...      ...     ...    ...     ...
# 122568  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122569  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122570  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122571  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122572  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122573 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
a = pd.Series([1, 3, 5])
a.index = ['a', 'b', 77]
b = pd.Series({'a': [1, 2, 4], 'b':[3,4]})
c = pd.DataFrame({'st1': a, 'st2': b})
d = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
display(d)
d['B'][0]
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 4

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2.1

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
import pandas as pd
recipes_sample_data = pd.read_csv('recipes_sample.csv', delimiter=',', parse_dates=['submitted'])
reviews_sample_data = pd.read_csv('reviews_sample.csv', delimiter=',', parse_dates=['date'], index_col = 0)
display(recipes_sample_data, reviews_sample_data)
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f'Информация о таблице recipes_sample: {recipes_sample_data.info()}\n')
print(f'Информация о таблице reviews_sample: {reviews_sample_data.info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB
# Информация о таблице recipes_sample: None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126696 entries, 370476 to 691207
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    126696 non-null  int64
#  1   recipe_id  126696 non-null  int64
# ...

# %%
print(f'Число строк в таблице recipes_sample: {len(recipes_sample_data.index)}')
print(f'Число столбцов в таблице recipes_sample: {len(recipes_sample_data.columns)}')
print(f'Тип данных каждого столбца таблицы recipes_sample:\n{recipes_sample_data.dtypes}\n')
print(f'Число строк в таблице reviews_sample: {len(reviews_sample_data.index)}')
print(f'Число столбцов в таблице reviews_sample: {len(reviews_sample_data.columns)}')
print(f'Тип данных каждого столбца таблицы reviews_sample:\n{reviews_sample_data.dtypes}')
# Out:
# Число строк в таблице recipes_sample: 30000
# Число столбцов в таблице recipes_sample: 8
# Тип данных каждого столбца таблицы recipes_sample:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object
#
# Число строк в таблице reviews_sample: 126696
# Число столбцов в таблице reviews_sample: 5
# Тип данных каждого столбца таблицы reviews_sample:
# user_id               int64
# recipe_id             int64
# date         datetime64[ns]
# rating                int64
# review               object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
# исследовать столбцы с пропусками можно используя .info() (в 1 n_steps, description, n_ingrediens)
# во 2 пропуски только в столбце review
display(recipes_sample_data)
print(30000-len(recipes_sample_data.dropna()))
print(f'Информация о таблице recipes_sample: {recipes_sample_data.info()}\n')
print(f'Доля строк с пропусками в таблице recipes_sample: {1-len(recipes_sample_data.dropna())/len(recipes_sample_data.index)}')
display(reviews_sample_data)
print(f'Информация о таблице reviews_sample: {reviews_sample_data.info()}\n\n')
print(f'Доля строк с пропусками в таблице reviews_sample: {1-len(reviews_sample_data.dropna())/len(reviews_sample_data.index)}')
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
display(recipes_sample_data)
print(f'Среднее значение столбца minutes: {recipes_sample_data["minutes"].mean(axis=0)}')
print(f'Среднее значение столбца n_steps: {recipes_sample_data["n_steps"].mean()}')
print(f'Среднее значение столбца n_ingredients: {recipes_sample_data["n_ingredients"].mean()}')
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
display(reviews_sample_data)
print(f'Среднее значение столбца rating: {reviews_sample_data["rating"].mean()}')
# Out:
#             user_id  recipe_id       date  rating  \
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# 312179   Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
random_name = recipes_sample_data["name"].sample(10)
random_name
# Out:
# 6146     chickpea and spinach with fresh figs and black...
# 9474                          dinner for two  please james
# 14532                                   iran chicken pilaf
# 14570                              irish whiskey fruitcake
# 18207                    mrs  dash garlic and herb chicken
# 13603                        hennessy tavern chopped salad
# 9604                                 downeast crabmeat pie
# 16960                                    maple spoon bread
# 8567                                 crock pot baked beans
# 15620                               lancer s spinach salad
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
# reviews_sample_data.index = [i for i in range(len(reviews_sample_data))]
# reviews_sample_data
reviews_sample_data.reset_index(inplace=True)
reviews_sample_data
# Out:
#           index     user_id  recipe_id       date  rating  \
# 0        370476       21752      57993 2003-05-01       5
# 1        624300      431813     142201 2007-09-16       5
# 2        187037      400708     252013 2008-01-10       4
# 3        706134  2001852463     404716 2017-12-11       5
# 4        312179       95810     129396 2008-03-14       5
# ...         ...         ...        ...        ...     ...
# 126691  1013457     1270706     335534 2009-05-17       4
# 126692   158736     2282344       8701 2012-06-03       0
# 126693  1059834      689540     222001 2008-04-08       5
# 126694   453285  2000242659     354979 2015-06-02       5
# 126695   691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
short_recipes = recipes_sample_data[(recipes_sample_data['minutes'] <= 20) & (recipes_sample_data['n_ingredients'] <= 5)]
print(type((recipes_sample_data['minutes'] <= 20) & (recipes_sample_data['n_ingredients'] <= 5)))
short_recipes
# Out:
# <class 'pandas.core.series.Series'>
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes_sample_data['submitted'] = pd.to_datetime(recipes_sample_data['submitted'])
recipes_sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
not_early_recipes_2010 = recipes_sample_data[recipes_sample_data['submitted'] <= '2010']
print(type(recipes_sample_data['submitted'] <= '2010'))
not_early_reviews_2010 = reviews_sample_data[reviews_sample_data['date'] <= '2010']
display(not_early_recipes_2010, not_early_reviews_2010)
# Out:
# <class 'pandas.core.series.Series'>
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes_sample_data_1 = recipes_sample_data.copy()
recipes_sample_data_1['description_length'] = recipes_sample_data_1['description'].str.len()
recipes_sample_data_1
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes_sample_data_1['name'] = recipes_sample_data_1['name'].str.title()
recipes_sample_data_1
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes_sample_data_1['name_word_count'] = recipes_sample_data_1['name'].apply(lambda x: len(x.split()))
# recipes_sample_data_1['name_word_count'] = recipes_sample_data_1['name'].str.split().str.len()
recipes_sample_data_1
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ## Лабораторная работа №2.2

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
display(recipes_sample_data['contributor_id'].value_counts())
print(type(recipes_sample_data["contributor_id"].value_counts().index[0]))
print(f'Максимальное число рецептов добавил участник: {recipes_sample_data["contributor_id"].value_counts().index[0]}')
# Out:
# 89831      421
# 37449      346
# 37779      345
# 1533       186
# 169430     183
#           ...
# 188243       1
# 1951568      1
# 842696       1
# 259021       1
# 432131       1
# Name: contributor_id, Length: 8404, dtype: int64
# <class 'numpy.int64'>
# Максимальное число рецептов добавил участник: 89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
print(f'Для {sum(reviews_sample_data["review"].isna())} рецептов отсутствуют отзывы')
display(reviews_sample_data.groupby('recipe_id').mean()[['rating']])
# Out:
# Для 17 рецептов отсутствуют отзывы
#              rating
# recipe_id
# 48         1.000000
# 55         4.750000
# 66         4.944444
# 91         4.750000
# 94         5.000000
# ...             ...
# 536547     5.000000
# 536610     0.000000
# 536728     4.000000
# 536729     4.750000
# 536747     0.000000
#
# [28100 rows x 1 columns]

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
display(recipes_sample_data.groupby(pd.Grouper(key='submitted', freq='Y')).count()[['id']],
        reviews_sample_data.groupby(pd.Grouper(key='date', freq='Y')).count()[['recipe_id']])
# Out:
#               id
# submitted
# 1999-12-31   275
# 2000-12-31   104
# 2001-12-31   589
# 2002-12-31  2644
# 2003-12-31  2334
# 2004-12-31  2153
# 2005-12-31  3130
# 2006-12-31  3473
# 2007-12-31  4429
# 2008-12-31  4029
# 2009-12-31  2963
# 2010-12-31  1538
# 2011-12-31   922
# 2012-12-31   659
# 2013-12-31   490
# 2014-12-31   139
# 2015-12-31    42
# 2016-12-31    24
# 2017-12-31    39
# 2018-12-31    24
#             recipe_id
# date
# 2000-12-31         13
# 2001-12-31        305
# 2002-12-31       2494
# 2003-12-31       3879
# 2004-12-31       5070
# 2005-12-31       7577
# 2006-12-31       9964
# 2007-12-31      15634
# 2008-12-31      18614
# 2009-12-31      17672
# 2010-12-31      12094
# 2011-12-31       8118
# 2012-12-31       6095
# 2013-12-31       5679
# 2014-12-31       3445
# 2015-12-31       2715
# 2016-12-31       2071
# 2017-12-31       2926
# 2018-12-31       2331

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
recipes_group = pd.merge(recipes_sample_data, reviews_sample_data, left_on="id", right_on="recipe_id")[['id', 'name', 'user_id', 'rating', 'review']]
display(recipes_group[recipes_group['review'].isna()])
# Out:
#             id                                               name     user_id  \
# 13806   107786      beth s melt in your mouth barbecue ribs  oven  2002060663
# 17294   335709                                 breaded pork chops  2001959957
# 30956    15553                             clove and cinnamon tea  2002299388
# 32840    86868                corned beef and cabbage in guinness  1803237930
# 52165     3662                   german chocolate sauerkraut cake  2001779476
# 67420    89207               kittencal s chocolate frosting icing  2002057405
# 70385     9054                    leftover mashed potato pancakes  2001567544
# 70392     9054                    leftover mashed potato pancakes  2001508809
# 70422     9054                    leftover mashed potato pancakes  2001826405
# 75469    25190  meal in a bowl   noodle soup   for 1 double fo...  2002252901
# 82967   522925                           one banana bread muffins  2001346906
# ...

# %%
recipes_group = recipes_group.dropna()
display(recipes_group)
print(recipes_sample_data[recipes_sample_data['id'] == '107786'])
# Out:
#             id                                    name  user_id  rating  \
# 0        44123   george s at the cove  black bean soup   743566       5
# 1        44123   george s at the cove  black bean soup    76503       5
# 2        44123   george s at the cove  black bean soup    34206       5
# 3        67664      healthy for them  yogurt popsicles   494084       5
# 4        67664      healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             zydeco soup   305531       5
# 126692  486161                             zydeco soup  1271506       5
# 126693  486161                             zydeco soup   724631       5
# 126694  486161                             zydeco soup   133174       5
# 126695  298512  cookies by design   cookies on a stick   804234       1
#
#                                                    review
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
display(reviews_sample_data)
r_c = reviews_sample_data.groupby('recipe_id')['review'].count()
print(r_c)
review_count = pd.merge(recipes_sample_data, reviews_sample_data, left_on='id', right_on='recipe_id')[['recipe_id', 'name']]
review_count = pd.merge(review_count, r_c, on='recipe_id')
review_count = review_count.rename(columns={'review': 'review_count'})
review_count = review_count.drop_duplicates().sort_values(by='review_count')
display(review_count)
# Out:
#           index     user_id  recipe_id       date  rating  \
# 0        370476       21752      57993 2003-05-01       5
# 1        624300      431813     142201 2007-09-16       5
# 2        187037      400708     252013 2008-01-10       4
# 3        706134  2001852463     404716 2017-12-11       5
# 4        312179       95810     129396 2008-03-14       5
# ...         ...         ...        ...        ...     ...
# 126691  1013457     1270706     335534 2009-05-17       4
# 126692   158736     2282344       8701 2012-06-03       0
# 126693  1059834      689540     222001 2008-04-08       5
# 126694   453285  2000242659     354979 2015-06-02       5
# 126695   691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %%
display(reviews_sample_data)
r_c = reviews_sample_data.groupby('recipe_id')['review'].count()
print(type(r_c))
review_count = pd.merge(recipes_sample_data, reviews_sample_data, left_on='id', right_on='recipe_id')[['recipe_id', 'name']]
display(review_count)
review_count = pd.merge(review_count, r_c, on='recipe_id')
display(review_count)
review_count = review_count.rename(columns={'review': 'review_count'})
review_count = review_count.drop_duplicates().sort_values(by='review_count')
display(review_count)
# Out:
#           index     user_id  recipe_id       date  rating  \
# 0        370476       21752      57993 2003-05-01       5
# 1        624300      431813     142201 2007-09-16       5
# 2        187037      400708     252013 2008-01-10       4
# 3        706134  2001852463     404716 2017-12-11       5
# 4        312179       95810     129396 2008-03-14       5
# ...         ...         ...        ...        ...     ...
# 126691  1013457     1270706     335534 2009-05-17       4
# 126692   158736     2282344       8701 2012-06-03       0
# 126693  1059834      689540     222001 2008-04-08       5
# 126694   453285  2000242659     354979 2015-06-02       5
# 126695   691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
rev = reviews_sample_data.groupby(pd.Grouper(key='date', freq='Y'))['rating'].mean()
display(rev)
rev[rev == rev.min()]
# Out:
# date
# 2000-12-31    3.384615
# 2001-12-31    4.134426
# 2002-12-31    4.481556
# 2003-12-31    4.526940
# 2004-12-31    4.546548
# 2005-12-31    4.563680
# 2006-12-31    4.603673
# 2007-12-31    4.547077
# 2008-12-31    4.484635
# 2009-12-31    4.524728
# 2010-12-31    4.454440
# 2011-12-31    4.302045
# 2012-12-31    4.341427
# 2013-12-31    4.274168
# 2014-12-31    4.110595
# 2015-12-31    4.047145
# 2016-12-31    3.912603
# 2017-12-31    3.353042
# 2018-12-31    3.504076
# Freq: A-DEC, Name: rating, dtype: float64
# date
# 2017-12-31    3.353042
# Freq: A-DEC, Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes_sample_data_1.sort_values(by="name_word_count").to_csv('sorted_recipes_sample_data.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter('merge.xlsx') as writer:
    recipes_group.to_excel(writer, sheet_name='Рецепты с оценками')
    review_count.to_excel(writer, sheet_name='Количество отзывов по рецептам')

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
